# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv2D, Conv3D
from tensorflow.keras.layers import MaxPooling2D, MaxPooling3D
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.losses import binary_crossentropy
from sklearn.metrics import f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from tensorflow.keras.applications.vgg16 import preprocess_input

from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image 
import seaborn as sns
import os
import re
import glob
import cv2
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
from sklearn.model_selection import StratifiedKFold
from sklearn import preprocessing
import tqdm
from numpy import loadtxt
from os import *
from sklearn.utils import class_weight
# Out:
# Using TensorFlow backend.

# %%
def atoi(text):
    return int(text) if text.isdigit() else text
def natural_keys(text):
    return [atoi(c) for c in re.split('(\d+)', text)]

# %%
def draw_confusion_matrix(true,preds):
    conf_matx = confusion_matrix(true, preds)
    sns.heatmap(conf_matx, annot=True,annot_kws={"size": 12},fmt='g', cbar=False, cmap=plt.cm.Blues) #'viridis'
    #plt.savefig('/home/jovyan/conf_matrix.png')
    plt.show()
    
    return conf_matx

# %%
def plot_history(model_history, model_name):
    fig = plt.figure(figsize=(15,5), facecolor='w')
    ax = fig.add_subplot(121)
    ax.plot(model_history.history['loss'])
    ax.plot(model_history.history['val_loss'])
    ax.set(title=model_name + ': Model loss', ylabel='Loss', xlabel='Epoch')
    ax.legend(['Train', 'Val'], loc='upper left')
    ax = fig.add_subplot(122)
    ax.plot(model_history.history['accuracy'])
    ax.plot(model_history.history['val_accuracy'])
    ax.set(title=model_name + ': Model Accuracy; test='+ str(np.round(model_history.history['val_accuracy'][-1], 3)),
           ylabel='Accuracy', xlabel='Epoch')
    ax.legend(['Train', 'Val'], loc='upper left')
    #plt.savefig('/home/jovyan/curve.png')
    plt.show()
    
    return fig

# %%
def resize(x):
    rescaled = []

    for i in x:

        scale_percent = 140 # percent of original size
        width = int(i.shape[1] / (scale_percent / 100))
        height = int(i.shape[0] / (scale_percent / 100))
        dim = (width, height)
        resized = cv2.resize(i, dim, interpolation = cv2.INTER_LANCZOS4)
        rescaled.append(resized)

    x_orig = np.reshape( rescaled, (len( rescaled), resized.shape[1], resized.shape[1], 3))

    return x_orig

# %%
def loadImages(path_data):
    
    p = '/home/jovyan/DATA_MASTER_PROJECT/Check_DIFF_T0_T97/'
    
    
    
    pa_adr = p + 'ADR_cropped/'
    
    pa_control = p + 'CONTROL_cropped/'
    
    pa_hrh = p + 'HRH_cropped/'
    
    image_list = []
    
    
       


    for filename in sorted(path_data, key=natural_keys): 
        
        if 'adr' in filename:
            
            im=cv2.imread(pa_adr + filename)

            imarray = np.array(im)
            

            image_list.append(imarray)
            
        if 'control' in filename:
            
            im=cv2.imread(pa_control + filename)

            imarray = np.array(im)
            

            image_list.append(imarray)
            
        if 'hrh' in filename:
            
            im=cv2.imread(pa_hrh + filename)

            imarray = np.array(im)
            

            image_list.append(imarray)



    x_orig = np.reshape(image_list, (len(image_list), 90, 90, 3))

    return x_orig

# %%
def return_count(x):
    name_wel = []
    for i in sorted(x, key = natural_keys):
        name_wel.append(i.split('_')[0])

    z = sorted(list(set(name_wel)))
    r = list(range(len(z)))

    num = []
    for iz in range(len(z)):
        count = 0
        for i in sorted(x, key=natural_keys):
            if z[iz] in i:
                count += 1
        num.append(count)
    return list(zip(z, r, num))

# %%
def creat_label(y):
    labels = []
    for ix, _ in enumerate(y):
        
        if y[ix][0] == 'adr':
        
            labels.append([[y[ix][0],0]] * y[ix][2])
        
        if y[ix][0] == 'hrh':
            
            labels.append([[y[ix][0],1]] * y[ix][2])
            
        if y[ix][0] == 'control':
            labels.append([[y[ix][0],0]] * y[ix][2])
    
    ler = [i for sub in labels for i in sub ]
    
    _, lab= zip(*ler)

    
    return lab

# %%
def make_labels(data_set):
    fe = return_count(data_set)
    leb = creat_label(fe)
    y = np.array(list(leb))
    return y

# %%
def time_step_acc(tes_data,x):

    results = []            

    x_test = loadImages(tes_data)
    y_test = make_labels(tes_data)
    x_test = resize(x_test)
    x_test = preprocess_input(x_test)

    scores = x.evaluate(x_test, y_test, verbose = 0)
    results.append(scores[1]*100)

    return results

# %%
mid = ['C6', 'F11']
leb = ['D11', 'G4']
mep = ['F2', 'G10']
met = ['G5', 'B10']
oxy = ['G3', 'B8']

cyc = ['E4', 'G6']
dox = ['G8', 'D10']
olo = ['E7', 'B7']
ket = ['E10', 'B11']
orp = ['D8', 'B2']

# %%
tot_well = [mid, leb, mep, met, oxy]
#tot_well = [cyc, dox, olo, ket, orp]

# %%
string_well = ['mid', 'leb', 'mep', 'met', 'oxy']
#string_well = ['cyc', 'dox', 'olo', 'ket', 'orp']

# %%
tot_results_accuracy = []

# %%
rand = list(np.random.randint(1,1000,3))

# %%
for num_ix, rand_num in enumerate(rand):
    for index_t_well, _ in tqdm.tqdm(enumerate(tot_well)):

        time_points = list(map(str, range(1,97,3)))

        new_time = []
        for i in time_points:
            r = '_' + i + '.'
            new_time.append(r)



        path_test = '/home/jovyan/DATA_MASTER_PROJECT/Check_DIFF_T0_T97/ADR_cropped/'

        # NAME OF THE WELLS CORRESPONDING TO THE FRUG THAT YOU WANT IN THE TEST SET 

        wells_drug = [tot_well[index_t_well][0], tot_well[index_t_well][1]] 

        test = []

        for _,_, filenames in os.walk(path_test):

            for filename in sorted(filenames, key = natural_keys):

                for w in wells_drug:
                    for t in new_time:
                        if '{}'.format(w) in filename and '{}tiff'.format(t) in filename:
                            test.append(filename)

        groups_list = ['ADR', 'HRH']#, 'CONTROL']

        fileds_of_view = ['1','2','3','4']

        field_train, field_val = train_test_split(fileds_of_view, test_size=0.2, random_state=rand_num)


        train = []

        validation = []

        group_compounds = []

        for group in tqdm.tqdm(groups_list):

            pa = '/home/jovyan/DATA_MASTER_PROJECT/Check_DIFF_T0_T97/{}_cropped/'.format(group)

            for _,_, filenames in os.walk(pa):

                for filename in sorted(filenames, key = natural_keys):

                    for t in new_time:

                        if '_{}-'.format(wells_drug[0]) not in filename and '_{}-'.format(wells_drug[1]) not in filename and '{}tiff'.format(t) in filename:

                            group_compounds.append(filename)






        for i in group_compounds:

            for f in field_train:
                if '-{}_'.format(f) in i:
                    train.append(i)


            for v in field_val:
                if '-{}_'.format(v) in i:
                    validation.append(i)


        x_train = loadImages(train)
        y_train = make_labels(train)



        x_val = loadImages(validation)
        y_val = make_labels(validation)



        x_train = resize(x_train)


        x_val = resize(x_val)


        weights = class_weight.compute_class_weight('balanced', np.unique(y_train),y_train)


        x_train = preprocess_input(x_train)

        x_val = preprocess_input(x_val)


        es = EarlyStopping(monitor='val_loss', mode='min', verbose=2, patience=3)

        pretrained_model = VGG16(weights='imagenet',include_top=False, input_shape=(64, 64, 3))

        base_model = Model(inputs=pretrained_model.input, outputs=pretrained_model.get_layer('block3_pool').output)

        batch_size = 128

        datagen = ImageDataGenerator()

        datagen.fit(x_train)

        train_gen = datagen.flow(x_train, y_train,batch_size=batch_size )

        dat_val = ImageDataGenerator()

        dat_val.fit(x_val)

        val_gen = dat_val.flow(x_val, y_val,batch_size=batch_size)

        m4 = Sequential()
        m4.add(base_model)


        m4.add(BatchNormalization())
        m4.add(GlobalAveragePooling2D())
        m4.add(BatchNormalization())
        m4.add(Activation('relu'))
        m4.add(Dense(64, activation='relu'))
        m4.add(Dense(1,activation='sigmoid'))


        base_model.trainable = False

        opt = keras.optimizers.Adam(lr=1e-4)

        m4.compile(loss= keras.losses.binary_crossentropy, optimizer=opt, metrics = ['accuracy'])



        epochs = 300

        m4_h = m4.fit(train_gen,
                        steps_per_epoch=(len(x_train)/batch_size),
                        callbacks = [es],
                        epochs=epochs,
                        validation_data = (val_gen), 
                        validation_steps = (len(x_val)/batch_size),
                        class_weight = weights,
                         verbose = 1)

        base_model.trainable = True

        opt = keras.optimizers.Adam(lr=1e-5)

        m4.compile(loss= keras.losses.binary_crossentropy, optimizer=opt, metrics = ['accuracy'])

        epochs = 300

        m4_h = m4.fit(train_gen,
                        steps_per_epoch=(len(x_train)/batch_size),
                        callbacks = [es],
                        epochs=epochs,
                        validation_data = val_gen, 
                        validation_steps = (len(x_val)/batch_size),
                        class_weight = weights,
                        verbose = 1)

        l = []
        for t in new_time:
            for i in test:
                if t in i:
                    l.append((i))


        grouped = {}
        for elem in l:
            key = elem.split('.tiff')[0].split('_')[5]
            grouped.setdefault(key, []).append(elem)
        grouped = grouped.values()

        test_data = list(grouped)

        r = []

        for ix ,_ in enumerate(test_data):
            r.append(time_step_acc(test_data[ix],m4))

        plt.plot(time_points,r)
        plt.savefig('/home/jovyan/{}_accuracy.png'.format(string_well[index_t_well]))

        tot_results_accuracy.append(r)

    #p = '/home/jovyan/save_model_final/'
    #m4.save(p + "{}.h5".format(string_well[index_t_well]))
# Out:
# 0it [00:00, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:05<00:05,  5.01s/it]
# 100%|██████████| 2/2 [00:10<00:00,  5.47s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 479.6015625 steps, validate for 148.09375 steps
# Epoch 1/300
# 480/479 [==============================] - 18s 38ms/step - loss: 0.6564 - accuracy: 0.5931 - val_loss: 0.6554 - val_accuracy: 0.5781
# Epoch 2/300
# 480/479 [==============================] - 15s 30ms/step - loss: 0.6305 - accuracy: 0.6301 - val_loss: 0.6591 - val_accuracy: 0.5774
# Epoch 3/300
# 480/479 [==============================] - 15s 31ms/step - loss: 0.6189 - accuracy: 0.6489 - val_loss: 0.6672 - val_accuracy: 0.5730
# Epoch 4/300
# 480/479 [==============================] - 15s 31ms/step - loss: 0.6100 - accuracy: 0.6591 - val_loss: 0.6681 - val_accuracy: 0.5759
# Epoch 00004: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for
early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 477.2265625 steps, validate for 173.8125 steps
# Epoch 1/300
# 478/477 [==============================] - 33s 68ms/step - loss: 0.5909 - accuracy: 0.6727 - val_loss: 0.6812 - val_accuracy: 0.5935
# Epoch 2/300
# 478/477 [==============================] - 32s 66ms/step - loss: 0.5638 - accuracy: 0.6998 - val_loss: 0.6942 - val_accuracy: 0.6010
# Epoch 3/300
# 478/477 [==============================] - 31s 66ms/step - loss: 0.5419 - accuracy: 0.7221 - val_loss: 0.6842 - val_accuracy: 0.6001
# Epoch 4/300
# 478/477 [==============================] - 31s 66ms/step - loss: 0.5238 - accuracy: 0.7383 - val_loss: 0.6805 - val_accuracy: 0.6072
# Epoch 5/300
# 478/477 [==============================] - 31s 66ms/step - loss: 0.5070 - accuracy: 0.7515 - val_loss: 0.7456 - val_accuracy: 0.5537
# Epoch 6/300
# 478/477 [==============================] - 32s 66ms/step - loss: 0.4921 - accuracy: 0.7641 - val_loss: 0.7101 - val_accuracy: 0.5908
# Epoch 7/300
# 478/477 [==============================] - 31s 66ms/step - loss: 0.4774 - accuracy: 0.7742 - val_loss: 0.7584 - val_accuracy: 0.5682
# Epoch 00007: early stopping
# 4it [26:01, 395.66s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:04<00:04,  4.89s/it]
# 100%|██████████| 2/2 [00:10<00:00,  5.31s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 460.2265625 steps, validate for 182.625 steps
# Epoch 1/300
# 461/460 [==============================] - 15s 33ms/step - loss: 0.6784 - accuracy: 0.5762 - val_loss: 0.7307 - val_accuracy: 0.5471
# Epoch 2/300
# 461/460 [==============================] - 14s 31ms/step - loss: 0.6506 - accuracy: 0.6167 - val_loss: 0.7248 - val_accuracy: 0.5506
# Epoch 3/300
# 461/460 [==============================] - 14s 31ms/step - loss: 0.6380 - accuracy: 0.6337 - val_loss: 0.7180 - val_accuracy: 0.5606
# Epoch 4/300
# 461/460 [==============================] - 14s 31ms/step - loss: 0.6285 - accuracy: 0.6436 - val_loss: 0.7219 - val_accuracy: 0.5604
# Epoch 5/300
# 461/460 [==============================] - 14s 31ms/step - loss: 0.6207 - accuracy: 0.6524 - val_loss: 0.7182 - val_accuracy: 0.5603
# Epoch 6/300
# 461/460 [==============================] - 14s 30ms/step - loss: 0.6141 - accuracy: 0.6600 - val_loss: 0.7228 - val_accuracy: 0.5618
# Epoch 00006: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 460.2265625 steps, validate for 182.625 steps
# Epoch 1/300
# 461/460 [==============================] - 32s 69ms/step - loss: 0.5953 - accuracy: 0.6792 - val_loss: 0.7037 - val_accuracy: 0.5648
# Epoch 2/300
# 461/460 [==============================] - 31s 66ms/step - loss: 0.5673 - accuracy: 0.7063 - val_loss: 0.7088 - val_accuracy: 0.5883
# Epoch 3/300
# 461/460 [==============================] - 30s 66ms/step - loss: 0.5452 - accuracy: 0.7250 - val_loss: 0.7331 - val_accuracy: 0.5819
# Epoch 4/300
# 461/460 [==============================] - 31s 66ms/step - loss: 0.5261 - accuracy: 0.7396 - val_loss: 0.7203 - val_accuracy: 0.5690
# Epoch 00004: early stopping
# 5it [31:46, 381.21s/it]
# 0it [00:00, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:04<00:04,  4.95s/it]
# 100%|██████████| 2/2 [00:10<00:00,  5.42s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 479.6015625 steps, validate for 148.09375 steps
# Epoch 1/300
# 480/479 [==============================] - 15s 32ms/step - loss: 0.6610 - accuracy: 0.5919 - val_loss: 0.6576 - val_accuracy: 0.5802
# Epoch 2/300
# 480/479 [==============================] - 14s 29ms/step - loss: 0.6343 - accuracy: 0.6311 - val_loss: 0.6608 - val_accuracy: 0.5791
# Epoch 3/300
# 480/479 [==============================] - 14s 30ms/step - loss: 0.6224 - accuracy: 0.6476 - val_loss: 0.6660 - val_accuracy: 0.5807
# Epoch 4/300
# 480/479 [==============================] - 14s 30ms/step - loss: 0.6128 - accuracy: 0.6602 - val_loss: 0.6723 - val_accuracy: 0.5790
# Epoch 00004: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 479.6015625 steps, validate for 148.09375 steps
# Epoch 1/300
# 480/479 [==============================] - 32s 66ms/step - loss: 0.5912 - accuracy: 0.6816 - val_loss: 0.6837 - val_accuracy: 0.5759
# Epoch 2/300
# 480/479 [==============================] - 31s 65ms/step - loss: 0.5637 - accuracy: 0.7069 - val_loss: 0.6962 - val_accuracy: 0.5808
# Epoch 3/300
# 480/479 [==============================] - 31s 65ms/step - loss: 0.5420 - accuracy: 0.7247 - val_loss: 0.7239 - val_accuracy: 0.5804
# Epoch 4/300
# 480/479 [==============================] - 31s 65ms/step - loss: 0.5239 - accuracy: 0.7398 - val_loss: 0.7083 - val_accuracy: 0.5858
# Epoch 00004: early stopping
# 1it [05:14, 314.39s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:04<00:04,  4.92s/it]
# 100%|██████████| 2/2 [00:10<00:00,  5.28s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 493.7421875 steps, validate for 155.515625 steps
# Epoch 1/300
# 494/493 [==============================] - 15s 31ms/step - loss: 0.6783 - accuracy: 0.5850 - val_loss: 0.7121 - val_accuracy: 0.5191
# Epoch 2/300
# 494/493 [==============================] - 15s 30ms/step - loss: 0.6492 - accuracy: 0.6263 - val_loss: 0.7159 - val_accuracy: 0.5228
# Epoch 3/300
# 494/493 [==============================] - 14s 29ms/step - loss: 0.6350 - accuracy: 0.6425 - val_loss: 0.7169 - val_accuracy: 0.5334
# Epoch 4/300
# 494/493 [==============================] - 15s 29ms/step - loss: 0.6242 - accuracy: 0.6528 - val_loss: 0.7216 - val_accuracy: 0.5336
# Epoch 00004: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 493.7421875 steps, validate for 155.515625 steps
# Epoch 1/300
# 494/493 [==============================] - 33s 66ms/step - loss: 0.6001 - accuracy: 0.6757 - val_loss: 0.7583 - val_accuracy: 0.5440
# Epoch 2/300
# 494/493 [==============================] - 32s 65ms/step - loss: 0.5692 - accuracy: 0.7033 - val_loss: 0.7345 - val_accuracy: 0.5248
# Epoch 3/300
# 494/493 [==============================] - 32s 65ms/step - loss: 0.5466 - accuracy: 0.7219 - val_loss: 0.7424 - val_accuracy: 0.5364
# Epoch 4/300
# 494/493 [==============================] - 32s 65ms/step - loss: 0.5273 - accuracy: 0.7383 - val_loss: 0.7522 - val_accuracy: 0.5377
# Epoch 5/300
# 494/493 [==============================] - 32s 65ms/step - loss: 0.5149 - accuracy: 0.7465 - val_loss: 0.7388 - val_accuracy: 0.5583
# Epoch 00005: early stopping
# 2it [11:08, 326.25s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:04<00:04,  4.92s/it]
# 100%|██████████| 2/2 [00:10<00:00,  5.38s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 495.4140625 steps, validate for 144.984375 steps
# Epoch 1/300
# 496/495 [==============================] - 15s 31ms/step - loss: 0.6909 - accuracy: 0.5538 - val_loss: 0.7216 - val_accuracy: 0.4927
# Epoch 2/300
# 496/495 [==============================] - 14s 29ms/step - loss: 0.6639 - accuracy: 0.5969 - val_loss: 0.7218 - val_accuracy: 0.5107
# Epoch 3/300
# 496/495 [==============================] - 14s 29ms/step - loss: 0.6516 - accuracy: 0.6173 - val_loss: 0.7289 - val_accuracy: 0.5060
# Epoch 4/300
# 496/495 [==============================] - 14s 29ms/step - loss: 0.6427 - accuracy: 0.6298 - val_loss: 0.7316 - val_accuracy: 0.5103
# Epoch 00004: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 495.4140625 steps, validate for 144.984375 steps
# Epoch 1/300
# 496/495 [==============================] - 33s 66ms/step - loss: 0.6238 - accuracy: 0.6511 - val_loss: 0.7644 - val_accuracy: 0.4948
# Epoch 2/300
# 496/495 [==============================] - 32s 64ms/step - loss: 0.5966 - accuracy: 0.6790 - val_loss: 0.8028 - val_accuracy: 0.4810
# Epoch 3/300
# 496/495 [==============================] - 32s 64ms/step - loss: 0.5759 - accuracy: 0.6987 - val_loss: 0.7701 - val_accuracy: 0.5142
# Epoch 4/300
# 496/495 [==============================] - 32s 64ms/step - loss: 0.5580 - accuracy: 0.7155 - val_loss: 0.8039 - val_accuracy: 0.4943
# Epoch 00004: early stopping
# 3it [16:28, 324.48s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:04<00:04,  4.89s/it]
# 100%|██████████| 2/2 [00:10<00:00,  5.42s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 498.359375 steps, validate for 152.6796875 steps
# Epoch 1/300
# 499/498 [==============================] - 16s 31ms/step - loss: 0.6700 - accuracy: 0.5872 - val_loss: 0.6884 - val_accuracy: 0.5354
# Epoch 2/300
# 499/498 [==============================] - 15s 29ms/step - loss: 0.6438 - accuracy: 0.6232 - val_loss: 0.6900 - val_accuracy: 0.5361
# Epoch 3/300
# 499/498 [==============================] - 14s 29ms/step - loss: 0.6313 - accuracy: 0.6378 - val_loss: 0.7032 - val_accuracy: 0.5275
# Epoch 4/300
# 499/498 [==============================] - 15s 29ms/step - loss: 0.6219 - accuracy: 0.6484 - val_loss: 0.7067 - val_accuracy: 0.5276
# Epoch 00004: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 498.359375 steps, validate for 152.6796875 steps
# Epoch 1/300
# 499/498 [==============================] - 33s 67ms/step - loss: 0.5997 - accuracy: 0.6720 - val_loss: 0.7056 - val_accuracy: 0.5420
# Epoch 2/300
# 499/498 [==============================] - 32s 65ms/step - loss: 0.5708 - accuracy: 0.6992 - val_loss: 0.7525 - val_accuracy: 0.5287
# Epoch 3/300
# 499/498 [==============================] - 32s 64ms/step - loss: 0.5491 - accuracy: 0.7201 - val_loss: 0.7336 - val_accuracy: 0.5552
# Epoch 4/300
# 499/498 [==============================] - 32s 65ms/step - loss: 0.5303 - accuracy: 0.7359 - val_loss: 0.7455 - val_accuracy: 0.5461
# Epoch 00004: early stopping
# 4it [21:51, 324.09s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:04<00:04,  4.72s/it]
# 100%|██████████| 2/2 [00:10<00:00,  5.25s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 492.8125 steps, validate for 150.0390625 steps
# Epoch 1/300
# 493/492 [==============================] - 15s 31ms/step - loss: 0.6838 - accuracy: 0.5670 - val_loss: 0.6956 - val_accuracy: 0.5511
# Epoch 2/300
# 493/492 [==============================] - 14s 29ms/step - loss: 0.6575 - accuracy: 0.6097 - val_loss: 0.7001 - val_accuracy: 0.5549
# Epoch 3/300
# 493/492 [==============================] - 14s 29ms/step - loss: 0.6454 - accuracy: 0.6264 - val_loss: 0.7048 - val_accuracy: 0.5483
# Epoch 4/300
# 493/492 [==============================] - 14s 29ms/step - loss: 0.6367 - accuracy: 0.6378 - val_loss: 0.7079 - val_accuracy: 0.5473
# Epoch 00004: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 492.8125 steps, validate for 150.0390625 steps
# Epoch 1/300
# 493/492 [==============================] - 33s 66ms/step - loss: 0.6150 - accuracy: 0.6608 - val_loss: 0.7024 - val_accuracy: 0.5609
# Epoch 2/300
# 493/492 [==============================] - 32s 65ms/step - loss: 0.5862 - accuracy: 0.6911 - val_loss: 0.7354 - val_accuracy: 0.5374
# Epoch 3/300
# 493/492 [==============================] - 32s 64ms/step - loss: 0.5650 - accuracy: 0.7086 - val_loss: 0.7351 - val_accuracy: 0.5525
# Epoch 4/300
# 493/492 [==============================] - 32s 65ms/step - loss: 0.5465 - accuracy: 0.7250 - val_loss: 0.7257 - val_accuracy: 0.5575
# Epoch 00004: early stopping
# 5it [27:08, 325.78s/it]

# %%
def cv_mean_acc(result_cv, string_well):
    
    l_drug = string_well*3

    acc_mean_cv = []

    for i in result_cv:
        acc_mean_cv.append(np.mean(i))
        
    cv_drug = list(zip(acc_mean_cv, l_drug))
    
    res = sorted(cv_drug, key = lambda x: x[1])
    a , b = zip(*res)
    
    a = list(a)
    
    s = list(np.array_split(a, 5))
    
    cv_score_acc = []
    
    for ix, i in enumerate(s):
        s1 = list(s[ix])
        
        cv_score_acc.append(np.mean(s1))
        
    return list(zip(cv_score_acc, string_well))

# %%
cv_s = cv_mean_acc(tot_results_accuracy, string_well)
cv_s
# Out:
# [(30.589988206823666, 'mid'),
#  (58.746157912537456, 'leb'),
#  (34.634483217572175, 'mep'),
#  (30.781307630240917, 'met'),
#  (45.427593092123665, 'oxy')]

# %%
l_drug = string_well*3

acc_plot = []

for i in tot_results_accuracy:
    acc_plot.append(i)

cv_plot = list(zip(acc_plot, l_drug))

res_plot = sorted(cv_plot, key = lambda x: x[1])

a , b = zip(*res_plot)
    
a = list(a)

s = list(np.array_split(a, 5))

cv_plot = []

for ix, i in enumerate(s):
    s1 = list(s[ix])
    
    cv_plot.append(np.average(s1, axis=0))

# %%
fig = plt.figure(figsize=(10, 5))
for i in cv_plot:
    
    plt.plot(time_points, i)
    plt.show
    plt.savefig('/home/jovyan/cv_score.png')
