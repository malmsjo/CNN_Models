# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten, LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv2D, Conv3D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.losses import binary_crossentropy
from sklearn.metrics import f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras import backend as K
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image 
import seaborn as sns
import os
import re
import glob
import cv2
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
from sklearn.model_selection import StratifiedKFold
from sklearn import preprocessing
import tqdm
from numpy import loadtxt
from os import *
from sklearn.utils import class_weight
# Out:
# Using TensorFlow backend.

# %%
def atoi(text):
    return int(text) if text.isdigit() else text
def natural_keys(text):
    return [atoi(c) for c in re.split('(\d+)', text)]

# %%
def draw_confusion_matrix(true,preds):
    conf_matx = confusion_matrix(true, preds)
    sns.heatmap(conf_matx, annot=True,annot_kws={"size": 12},fmt='g', cbar=False, cmap=plt.cm.Blues) #'viridis'
    #plt.savefig('/home/jovyan/conf_matrix.png')
    plt.show()
    
    return conf_matx

# %%
def plot_history(model_history, model_name):
    fig = plt.figure(figsize=(15,5), facecolor='w')
    ax = fig.add_subplot(121)
    ax.plot(model_history.history['loss'])
    ax.plot(model_history.history['val_loss'])
    ax.set(title=model_name + ': Model loss', ylabel='Loss', xlabel='Epoch')
    ax.legend(['Train', 'Val'], loc='upper left')
    ax = fig.add_subplot(122)
    ax.plot(model_history.history['accuracy'])
    ax.plot(model_history.history['val_accuracy'])
    ax.set(title=model_name + ': Model Accuracy; test='+ str(np.round(model_history.history['val_accuracy'][-1], 3)),
           ylabel='Accuracy', xlabel='Epoch')
    ax.legend(['Train', 'Val'], loc='upper left')
    #plt.savefig('/home/jovyan/curve.png')
    plt.show()
    
    return fig

# %%
def resize(x):
    rescaled = []

    for i in x:

        scale_percent = 140 # percent of original size
        width = int(i.shape[1] / (scale_percent / 100))
        height = int(i.shape[0] / (scale_percent / 100))
        dim = (width, height)
        resized = cv2.resize(i, dim, interpolation = cv2.INTER_LANCZOS4)
        rescaled.append(resized)

    x_orig = np.reshape( rescaled, (len( rescaled), resized.shape[1], resized.shape[1], 3))

    return x_orig

# %%
def loadImages(path_data):
    
    p = '/home/jovyan/DATA_MASTER_PROJECT/Check_DIFF_T0_T97/'
    
    
    
    pa_adr = p + 'ADR_cropped/'
    
    pa_control = p + 'CONTROL_cropped/'
    
    pa_hrh = p + 'HRH_cropped/'
    
    image_list = []
    
    
       


    for filename in sorted(path_data, key=natural_keys): 
        
        if 'adr' in filename:
            
            im=cv2.imread(pa_adr + filename)

            imarray = np.array(im)
            

            image_list.append(imarray)
            
        if 'control' in filename:
            
            im=cv2.imread(pa_control + filename)

            imarray = np.array(im)
            

            image_list.append(imarray)
            
        if 'hrh' in filename:
            
            im=cv2.imread(pa_hrh + filename)

            imarray = np.array(im)
            

            image_list.append(imarray)



    x_orig = np.reshape(image_list, (len(image_list), 90, 90, 3))

    return x_orig

# %%
def return_count(x):
    name_wel = []
    for i in sorted(x, key = natural_keys):
        name_wel.append(i.split('_')[0])

    z = sorted(list(set(name_wel)))
    r = list(range(len(z)))

    num = []
    for iz in range(len(z)):
        count = 0
        for i in sorted(x, key=natural_keys):
            if z[iz] in i:
                count += 1
        num.append(count)
    return list(zip(z, r, num))

# %%
def loadImages_LSTM(path_data,len_t_points):
    

    feat_list = []


    for filename in sorted(glob.glob(path_data), key=natural_keys): 
        feat_list.append(np.load(filename))

    x_orig = np.reshape(feat_list, (len(feat_list),len_t_points, 64))

    return x_orig

# %%
def make_labels(data_set):
    fe = return_count(data_set)
    leb = creat_label(fe)
    y = np.array(list(leb))
    return y

# %%
def make_labels_LSTM(data_set):
    fe = return_count_LSTM(data_set)
    leb = creat_label(fe)
    y = np.array(list(leb))
    return y

# %%
def return_count_LSTM(x):
    name_wel = []
    for _,_,i in os.walk(x):
        for f in i:
            name_wel.append(f.split('_')[2])

    z = sorted(list(set(name_wel)), key=natural_keys)
    r = list(range(len(z)))

    num = []
    for iz in range(len(z)):
        count = 0
        for i in sorted(name_wel, key=natural_keys):
            if z[iz] in i:
                count += 1
        num.append(count)
    return list(zip(z, r, num))

# %%
def creat_label(y):
    labels = []
    for ix, _ in enumerate(y):
        
        if y[ix][0] == 'adr':
        
            labels.append([[y[ix][0],0]] * y[ix][2])
        
        if y[ix][0] == 'hrh':
            
            labels.append([[y[ix][0],1]] * y[ix][2])
        
        if y[ix][0] == 'control':
            
            labels.append([[y[ix][0],2]] * y[ix][2])
    
    ler = [i for sub in labels for i in sub ]
    
    _, lab= zip(*ler)

    
    return lab

# %%
def time_step_acc(tes_data, x):

    results = []            

    x_test = loadImages(tes_data)
    y_test = make_labels(tes_data)
    y_test_1 = keras.utils.to_categorical(y_test, num_classes = 3)
    x_test = resize(x_test)
    x_test = preprocess_input(x_test)

    scores = x.evaluate(x_test, y_test_1, verbose = 1)
    results.append(scores[1]*100)

    return results

# %%
def cv_mean_acc(result_cv, string_well):
    
    l_drug = string_well*3

    acc_mean_cv = []

    for i in result_cv:
        acc_mean_cv.append(np.mean(i))
        
    cv_drug = list(zip(acc_mean_cv, l_drug))
    
    res = sorted(cv_drug, key = lambda x: x[1])
    a , b = zip(*res)
    
    a = list(a)
    
    s = list(np.array_split(a, 5))
    
    cv_score_acc = []
    
    for ix, i in enumerate(s):
        s1 = list(s[ix])
        
        cv_score_acc.append(np.mean(s1))
        
    return list(zip(cv_score_acc, string_well))

# %%
# DATA FOR LSTM PART

p_feat = '/home/jovyan/DATA_MASTER_PROJECT/LSTM/FEAT_FOLDERS/'
train_data = p_feat + 'features_train/*.npy'
val_data = p_feat + 'features_validation/*.npy'
tes_data= p_feat + 'features_test/*.npy'

y_tra_path = '/home/jovyan/DATA_MASTER_PROJECT/LSTM/FEAT_FOLDERS/features_train/'
y_tes_path = '/home/jovyan/DATA_MASTER_PROJECT/LSTM/FEAT_FOLDERS/features_test/'
y_val_path = '/home/jovyan/DATA_MASTER_PROJECT/LSTM/FEAT_FOLDERS/features_validation/'

# %%
mid = ['C6', 'F11']
leb = ['D11', 'G4']
mep = ['F2', 'G10']
met = ['G5', 'B10']
oxy = ['G3', 'B8']

cyc = ['E4', 'G6']
dox = ['G8', 'D10']
olo = ['E7', 'B7']
ket = ['E10', 'B11']
orp = ['D8', 'B2']

# %%
tot_results_accuracy = []

results_lstm = []

# %%
tot_well_adr = [mid, leb, mep, met, oxy]
tot_well_hrh = [cyc, dox, olo, ket, orp]

string_well_adr = ['mid', 'leb', 'mep', 'met', 'oxy']
string_well_hrh = ['cyc', 'dox', 'olo', 'ket', 'orp']

# %%
tot_well = []
string_well = []

# %%
a = 'ADR' # FOR TEST SET
b = 'HRH' # FOR REST
c = 'CONTROL'

if a == 'HRH':
    tot_well = tot_well_hrh
    string_well = string_well_hrh
    
if a == 'ADR':
    tot_well = tot_well_adr
    string_well = string_well_adr

# %%
rand = list(np.random.randint(1,1000,3))

# %%
for num_ix, rand_num in enumerate(rand):
    for index_t_well, _ in tqdm.tqdm(enumerate(tot_well)):

        time_points = list(map(str, range(1,97,3)))

        new_time = []
        for i in time_points:
            r = '_' + i + '.'
            new_time.append(r)



        path_test = '/home/jovyan/DATA_MASTER_PROJECT/Check_DIFF_T0_T97/{}_cropped/'.format(a)

        # NAME OF THE WELLS CORRESPONDING TO THE DRUG THAT YOU WANT IN THE TEST SET 

        wells_drug = [tot_well[index_t_well][0], tot_well[index_t_well][1]] 

        test = []

        for _,_, filenames in os.walk(path_test):

            for filename in sorted(filenames, key = natural_keys):

                for w in wells_drug:
                    for t in new_time:
                        if '{}'.format(w) in filename and '{}tiff'.format(t) in filename:
                            test.append(filename)

        groups_list = ['{}'.format(a), '{}'.format(b), '{}'.format(c)]

        fileds_of_view = ['1','2','3','4']

        field_train, field_val = train_test_split(fileds_of_view, test_size=0.2, random_state=rand_num)


        train = []

        validation = []

        group_compounds = []

        for group in tqdm.tqdm(groups_list):

            pa = '/home/jovyan/DATA_MASTER_PROJECT/Check_DIFF_T0_T97/{}_cropped/'.format(group)

            for _,_, filenames in os.walk(pa):

                for filename in sorted(filenames, key = natural_keys):

                    for t in new_time:

                        if '_{}-'.format(wells_drug[0]) not in filename and '_{}-'.format(wells_drug[1]) not in filename and '{}tiff'.format(t) in filename:

                            group_compounds.append(filename)






        for i in group_compounds:

            for f in field_train:
                if '-{}_'.format(f) in i:
                    train.append(i)


            for v in field_val:
                if '-{}_'.format(v) in i:
                    validation.append(i)


        x_train = loadImages(train)
        y_train = make_labels(train)



        x_val = loadImages(validation)
        y_val = make_labels(validation)



        x_train = resize(x_train)


        x_val = resize(x_val)


        weights = class_weight.compute_class_weight('balanced', np.unique(y_train),y_train)


        x_train = preprocess_input(x_train)

        x_val = preprocess_input(x_val)


        es = EarlyStopping(monitor='val_loss', mode='min', verbose=2, patience=3)

        pretrained_model = VGG16(weights='imagenet',include_top=False, input_shape=(64, 64, 3))

        base_model = Model(inputs=pretrained_model.input, outputs=pretrained_model.get_layer('block3_pool').output)
        
        y_train = keras.utils.to_categorical(y_train)
        
        y_val = keras.utils.to_categorical(y_val)

        batch_size = 128

        datagen = ImageDataGenerator()

        datagen.fit(x_train)

        train_gen = datagen.flow(x_train, y_train,batch_size=batch_size )

        dat_val = ImageDataGenerator()

        dat_val.fit(x_val)

        val_gen = dat_val.flow(x_val, y_val,batch_size=batch_size)

        m4 = Sequential()
        m4.add(base_model)


        m4.add(BatchNormalization())
        m4.add(GlobalAveragePooling2D())
        m4.add(Dense(64, activation='relu'))
        m4.add(BatchNormalization())
        m4.add(Activation('relu'))
        m4.add(Dense(3,activation='softmax'))


        base_model.trainable = False

        opt = keras.optimizers.Adam(lr=1e-4)

        m4.compile(loss= keras.losses.categorical_crossentropy, optimizer=opt, metrics = ['accuracy'])



        epochs = 300

        m4_h = m4.fit(train_gen,
                        steps_per_epoch=(len(x_train)/batch_size),
                        callbacks = [es],
                        epochs=epochs,
                        validation_data = (val_gen), 
                        validation_steps = (len(x_val)/batch_size),
                        class_weight = weights,
                         verbose = 1)

        base_model.trainable = True

        opt = keras.optimizers.Adam(lr=1e-5)

        m4.compile(loss= keras.losses.categorical_crossentropy, optimizer=opt, metrics = ['accuracy'])

        epochs = 300

        m4_h = m4.fit(train_gen,
                        steps_per_epoch=(len(x_train)/batch_size),
                        callbacks = [es],
                        epochs=epochs,
                        validation_data = val_gen, 
                        validation_steps = (len(x_val)/batch_size),
                        class_weight = weights,
                        verbose = 1)

        l = []
        for t in new_time:
            for i in test:
                if t in i:
                    l.append((i))


        grouped = {}
        for elem in l:
            key = elem.split('.tiff')[0].split('_')[5]
            grouped.setdefault(key, []).append(elem)
        grouped = grouped.values()

        test_data = list(grouped)

        r = []

        for ix ,_ in enumerate(test_data):
            r.append(time_step_acc(test_data[ix],m4))

        plt.plot(time_points,r)
        plt.savefig('/home/jovyan/{}_accuracy.png'.format(string_well[index_t_well]))

        tot_results_accuracy.append(r)
        
        
        # RETURN CONFUSIUON MATRIX and CLASSIFICATION REPORT
        
        # Since only one class in test set the accuracy is the F1 score
        
        
        # START LSTM PART
        
        for i, layer in enumerate(m4.layers):
            layer._name = 'layer_' + str(i)



        lstm_model = Model(inputs=m4.input, outputs=m4.get_layer('layer_4').output)
        
        del m4
        K.clear_session()

        data_name = [train,test,validation]

        feat_name = ['train', 'test', 'validation']

        for index_name, _ in enumerate(data_name):

            path =  data_name[index_name]

            name_well = []

            for i in path:
                name_well.append(i.split('_id')[0])

            wells = list(set(name_well))
            wells

            for w in wells:

                time = []


                for filename in sorted(path, key = natural_keys):
                    if w in filename: #PAY ATTENTION ID THE IMAGE IS A TIFF OR PNG IMAGE #########
                        time.append(filename)

                data_id = {}
                n_id = []
                w_n = []

                for i in time:
                    t = i.split('_id_')[1].split('time_')[0]
                    f = i.split('_id_')[0].split('time_')[0]
                    n_id.append(t)
                    w_n.append(f)

                id_cell = set(n_id)


                for ix, i in enumerate(sorted(id_cell, key = natural_keys)):

                    id_name = []
                    dict_1 = {}

                    for t in time:
                        if 'id_{}'.format(i) in t:
                            id_name.append(t)

                    d = {'id':id_name}
                    data = pd.DataFrame(d)

                    dict_1[ix]=data 
                    data_id.update(dict_1) 

                delete = [i for i, j in data_id.items() if len(j) < len(time_points)] # 9 or the length of time span you are traning on 
                for i in delete : del data_id[i]

                len_id = [i for i, j in data_id.items()]

                for le in len_id:    


                    e = pd.DataFrame(data_id[le])

                    coords = e.values.tolist()
                    id_cells = []
                    for i in coords:
                        for j in i:
                            id_cells.append(j)

                    x_orig = loadImages(id_cells)
                    x_orig = resize(x_orig)

                    x_orig = preprocess_input(x_orig)
                    output = lstm_model.predict(x_orig)
                    np.save('/home/jovyan/DATA_MASTER_PROJECT/LSTM//FEAT_FOLDERS/features_{}/features_well_{}_id_{}.npy'.format(feat_name[index_name],w_n[0], le), output)
            print('Saved_feature_{}'.format(feat_name[index_name]))


        x_train_lstm = loadImages_LSTM(train_data, len(time_points))
        y_train_lstm = make_labels_LSTM(y_tra_path)

        x_test_lstm = loadImages_LSTM(tes_data, len(time_points))
        y_test_lstm = make_labels_LSTM(y_tes_path)

        x_val_lstm = loadImages_LSTM(val_data, len(time_points))
        y_val_lstm = make_labels_LSTM(y_val_path)

        weights_lstm = class_weight.compute_class_weight('balanced', np.unique(y_train_lstm),y_train_lstm)
        
        y_train_lstm = keras.utils.to_categorical(y_train_lstm)
        y_test_1_lstm = keras.utils.to_categorical(y_test_lstm, num_classes = 3)
        y_val_lstm = keras.utils.to_categorical(y_val_lstm)


        m = Sequential()
        m.add(LSTM(32, input_shape = (x_train_lstm.shape[1],x_train_lstm.shape[2])))
        m.add(Dropout(0.2))
        m.add(Dense(3, activation='softmax'))


        opt_lstm = keras.optimizers.Adam(lr=1e-4)

        m.compile(loss= keras.losses.categorical_crossentropy, optimizer=opt, metrics = ['accuracy'])

        epochs = 300

        m_h = m.fit(x_train_lstm,y_train_lstm,

                         callbacks = [es],

                        epochs=epochs,
                        validation_data = (x_val_lstm,y_val_lstm), 

                        class_weight = weights_lstm)


        scores_lstm = m.evaluate(x_test_lstm, y_test_1_lstm)
        results_lstm.append([scores_lstm[1]*100, string_well[index_t_well]])
        
        del m
        K.clear_session()

        # DELITE FILES IN FEATURE VECTOR FOLDERS

        folders = glob.glob('/home/jovyan/DATA_MASTER_PROJECT/LSTM/FEAT_FOLDERS/*')

        for fo in folders:
            file = glob.glob(f'{fo}/*')
            for f in file:
                os.remove(f)
# Out:
# 0it [00:00, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#  33%|███▎      | 1/3 [00:05<00:10,  5.47s/it]
#  67%|██████▋   | 2/3 [00:11<00:05,  5.59s/it]
# 100%|██████████| 3/3 [00:14<00:00,  4.71s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 601.6953125 steps, validate for 196.8515625 steps
# Epoch 1/300
# 602/601 [==============================] - 22s 36ms/step - loss: 1.0883 - accuracy: 0.4498 - val_loss: 1.0910 - val_accuracy: 0.4461
# Epoch 2/300
# 602/601 [==============================] - 18s 30ms/step - loss: 1.0027 - accuracy: 0.4987 - val_loss: 1.0711 - val_accuracy: 0.4600
# Epoch 3/300
# 602/601 [==============================] - 18s 30ms/step - loss: 0.9754 - accuracy: 0.5183 - val_loss: 1.0764 - val_accuracy: 0.4594
# Epoch 4/300
# 602/601 [==============================] - 18s 30ms/step - loss: 0.9568 - accuracy: 0.5336 - val_loss: 1.0760 - val_accuracy: 0.4634
# Epoch 5/300
# 602/601 [==============================] - 18s 30ms/step - loss: 0.9426 - accuracy: 0.5462 - val_loss: 1.0812 - val_accuracy: 0.4646
# Epoch 00005: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 601.6953125 steps, validate for 196.8515625 steps
# Epoch 1/300
# 602/601 [==============================] - 42s 70ms/step - loss: 0.9183 - accuracy: 0.5648 - val_loss: 1.0901 - val_accuracy: 0.4736
# Epoch 2/300
# 602/601 [==============================] - 40s 67ms/step - loss: 0.8844 - accuracy: 0.5886 - val_loss: 1.1277 - val_accuracy: 0.4195
# Epoch 3/300
# 602/601 [==============================] - 41s 67ms/step - loss: 0.8587 - accuracy: 0.6069 - val_loss: 1.0789 - val_accuracy: 0.4752
# Epoch 4/300
# 602/601 [==============================] - 41s 67ms/step - loss: 0.8355 - accuracy: 0.6209 - val_loss: 1.1346 - val_accuracy: 0.4609
# Epoch 5/300
# 602/601 [==============================] - 41s 68ms/step - loss: 0.8149 - accuracy: 0.6348 - val_loss: 1.1821 - val_accuracy: 0.4610
# Epoch 6/300
# 602/601 [==============================] - 40s 67ms/step - loss: 0.7965 - accuracy: 0.6478 - val_loss: 1.1210 - val_accuracy: 0.4626
# Epoch 00006: early stopping
# 380/380 [==============================] - 0s 1ms/sample - loss: 1.8180 - accuracy: 0.1342
# 369/369 [==============================] - 0s 453us/sample - loss: 1.7500 - accuracy: 0.1545
# 364/364 [==============================] - 0s 452us/sample - loss: 1.7635 - accuracy: 0.1703
# 360/360 [==============================] - 0s 414us/sample - loss: 1.7745 - accuracy: 0.1250
# 355/355 [==============================] - 0s 443us/sample - loss: 1.7676 - accuracy: 0.1324
# 346/346 [==============================] - 0s 553us/sample - loss: 1.7282 - accuracy: 0.1879
# 343/343 [==============================] - 0s 525us/sample - loss: 1.7480 - accuracy: 0.1487
# 336/336 [==============================] - 0s 468us/sample - loss: 1.6718 - accuracy: 0.2083
# 332/332 [==============================] - 0s 235us/sample - loss: 1.7732 - accuracy: 0.1988
# 328/328 [==============================] - 0s 227us/sample - loss: 1.8612 - accuracy: 0.1829
# 323/323 [==============================] - 0s 250us/sample - loss: 1.8131 - accuracy: 0.1734
# 322/322 [==============================] - 0s 474us/sample - loss: 1.8537 - accuracy: 0.1739
# 313/313 [==============================] - 0s 547us/sample - loss: 1.7530 - accuracy: 0.2236
# 312/312 [==============================] - 0s 517us/sample - loss: 1.8259 - accuracy: 0.1474
# 310/310 [==============================] - 0s 541us/sample - loss: 1.8279 - accuracy: 0.1839
# 308/308 [==============================] - 0s 542us/sample - loss: 1.9452 - accuracy: 0.1688
# 305/305 [==============================] - 0s 238us/sample - loss: 1.8765 - accuracy: 0.1770
# 301/301 [==============================] - 0s 530us/sample - loss: 1.8867 - accuracy: 0.1728
# 299/299 [==============================] - 0s 503us/sample - loss: 1.8793 - accuracy: 0.2007
# 298/298 [==============================] - 0s 495us/sample - loss: 1.9365 - accuracy: 0.1913
# 293/293 [==============================] - 0s 495us/sample - loss: 1.7667 - accuracy: 0.1911
# 291/291 [==============================] - 0s 243us/sample - loss: 1.8248 - accuracy: 0.1787
# 291/291 [==============================] - 0s 244us/sample - loss: 1.8237 - accuracy: 0.1993
# 291/291 [==============================] - 0s 254us/sample - loss: 1.7874 - accuracy: 0.2165
# 292/292 [==============================] - 0s 505us/sample - loss: 1.8662 - accuracy: 0.1575
# 287/287 [==============================] - 0s 615us/sample - loss: 1.9165 - accuracy: 0.1638
# 286/286 [==============================] - 0s 586us/sample - loss: 1.8975 - accuracy: 0.1643
# 286/286 [==============================] - 0s 245us/sample - loss: 1.8245 - accuracy: 0.2098
# 279/279 [==============================] - 0s 229us/sample - loss: 1.7541 - accuracy: 0.2043
# 277/277 [==============================] - 0s 564us/sample - loss: 1.9020 - accuracy: 0.1841
# 277/277 [==============================] - 0s 246us/sample - loss: 1.8382 - accuracy: 0.1805
# 275/275 [==============================] - 0s 592us/sample - loss: 1.9182 - accuracy: 0.1782
# Saved_feature_train
# Saved_feature_test
# Saved_feature_validation
# Train on 1909 samples, validate on 600 samples
# Epoch 1/300
# 1909/1909 [==============================] - 2s 1ms/sample - loss: 1.1334 - accuracy: 0.3525 - val_loss: 1.1354 - val_accuracy: 0.3283
# Epoch 2/300
# 1909/1909 [==============================] - 0s 217us/sample - loss: 1.1094 - accuracy: 0.3656 - val_loss: 1.1243 - val_accuracy: 0.3433
# Epoch 3/300
# 1909/1909 [==============================] - 0s 197us/sample - loss: 1.0844 - accuracy: 0.3971 - val_loss: 1.1167 - val_accuracy: 0.3517
# Epoch 4/300
# 1909/1909 [==============================] - 0s 175us/sample - loss: 1.0719 - accuracy: 0.4170 - val_loss: 1.1101 - val_accuracy: 0.3467
# Epoch 5/300
# 1909/1909 [==============================] - 0s 189us/sample - loss: 1.0581 - accuracy: 0.4206 - val_loss: 1.1052 - val_accuracy: 0.3633
# Epoch 6/300
# 1909/1909 [==============================] - 0s 195us/sample - loss: 1.0538 - accuracy: 0.4411 - val_loss: 1.1008 - val_accuracy: 0.3717
# Epoch 7/300
# 1909/1909 [==============================] - 0s 203us/sample - loss: 1.0480 - accuracy: 0.4610 - val_loss: 1.0969 - val_accuracy: 0.3850
# Epoch 8/300
# 1909/1909 [==============================] - 0s 211us/sample - loss: 1.0425 - accuracy: 0.4594 - val_loss: 1.0934 - val_accuracy: 0.4000
# Epoch 9/300
# 1909/1909 [==============================] - 0s 211us/sample - loss: 1.0358 - accuracy: 0.4584 - val_loss: 1.0903 - val_accuracy: 0.4000
# Epoch 10/300
# 1909/1909 [==============================] - 0s 202us/sample - loss: 1.0293 - accuracy: 0.4620 - val_loss: 1.0873 - val_accuracy: 0.4050
# Epoch 11/300
# 1909/1909 [==============================] - 0s 198us/sample - loss: 1.0269 - accuracy: 0.4715 - val_loss: 1.0846 - val_accuracy: 0.4250
# Epoch 12/300
# 1909/1909 [==============================] - 0s 221us/sample - loss: 1.0143 - accuracy: 0.4840 - val_loss: 1.0821 - val_accuracy: 0.4300
# Epoch 13/300
# 1909/1909 [==============================] - 0s 202us/sample - loss: 1.0170 - accuracy: 0.4825 - val_loss: 1.0797 - val_accuracy: 0.4333
# Epoch 14/300
# 1909/1909 [==============================] - 0s 229us/sample - loss: 1.0127 - accuracy: 0.4935 - val_loss: 1.0775 - val_accuracy: 0.4467
# Epoch 15/300
# 1909/1909 [==============================] - 0s 226us/sample - loss: 1.0070 - accuracy: 0.5081 - val_loss: 1.0755 - val_accuracy: 0.4583
# Epoch 16/300
# 1909/1909 [==============================] - 0s 196us/sample - loss: 1.0044 - accuracy: 0.5102 - val_loss: 1.0736 - val_accuracy: 0.4633
# Epoch 17/300
# 1909/1909 [==============================] - 0s 182us/sample - loss: 0.9987 - accuracy: 0.5102 - val_loss: 1.0717 - val_accuracy: 0.4617
# Epoch 18/300
# 1909/1909 [==============================] - 0s 210us/sample - loss: 1.0014 - accuracy: 0.5149 - val_loss: 1.0700 - val_accuracy: 0.4550
# Epoch 19/300
# 1909/1909 [==============================] - 0s 176us/sample - loss: 0.9904 - accuracy: 0.5196 - val_loss: 1.0682 - val_accuracy: 0.4633
# Epoch 20/300
# 1909/1909 [==============================] - 0s 215us/sample - loss: 0.9945 - accuracy: 0.5202 - val_loss: 1.0665 - val_accuracy: 0.4667
# Epoch 21/300
# 1909/1909 [==============================] - 0s 216us/sample - loss: 0.9944 - accuracy: 0.5233 - val_loss: 1.0650 - val_accuracy: 0.4667
# Epoch 22/300
# 1909/1909 [==============================] - 0s 186us/sample - loss: 0.9868 - accuracy: 0.5296 - val_loss: 1.0635 - val_accuracy: 0.4700
# Epoch 23/300
# 1909/1909 [==============================] - 0s 199us/sample - loss: 0.9772 - accuracy: 0.5312 - val_loss: 1.0619 - val_accuracy: 0.4700
# Epoch 24/300
# 1909/1909 [==============================] - 0s 207us/sample - loss: 0.9793 - accuracy: 0.5364 - val_loss: 1.0603 - val_accuracy: 0.4767
# Epoch 25/300
# 1909/1909 [==============================] - 0s 191us/sample - loss: 0.9722 - accuracy: 0.5521 - val_loss: 1.0590 - val_accuracy: 0.4750
# Epoch 26/300
# 1909/1909 [==============================] - 0s 211us/sample - loss: 0.9683 - accuracy: 0.5401 - val_loss: 1.0577 - val_accuracy: 0.4767
# Epoch 27/300
# 1909/1909 [==============================] - 0s 222us/sample - loss: 0.9670 - accuracy: 0.5458 - val_loss: 1.0563 - val_accuracy: 0.4750
# Epoch 28/300
# 1909/1909 [==============================] - 0s 219us/sample - loss: 0.9700 - accuracy: 0.5443 - val_loss: 1.0550 - val_accuracy: 0.4783
# Epoch 29/300
# 1909/1909 [==============================] - 0s 218us/sample - loss: 0.9600 - accuracy: 0.5542 - val_loss: 1.0539 - val_accuracy: 0.4817
# Epoch 30/300
# 1909/1909 [==============================] - 0s 219us/sample - loss: 0.9606 - accuracy: 0.5621 - val_loss: 1.0525 - val_accuracy: 0.4850
# Epoch 31/300
# 1909/1909 [==============================] - 0s 214us/sample - loss: 0.9591 - accuracy: 0.5563 - val_loss: 1.0514 - val_accuracy: 0.4867
# Epoch 32/300
# 1909/1909 [==============================] - 0s 208us/sample - loss: 0.9509 - accuracy: 0.5605 - val_loss: 1.0502 - val_accuracy: 0.4867
# Epoch 33/300
# 1909/1909 [==============================] - 0s 193us/sample - loss: 0.9506 - accuracy: 0.5689 - val_loss: 1.0490 - val_accuracy: 0.4867
# Epoch 34/300
# 1909/1909 [==============================] - 0s 186us/sample - loss: 0.9510 - accuracy: 0.5610 - val_loss: 1.0478 - val_accuracy: 0.4883
# Epoch 35/300
# 1909/1909 [==============================] - 0s 216us/sample - loss: 0.9460 - accuracy: 0.5616 - val_loss: 1.0468 - val_accuracy: 0.4883
# Epoch 36/300
# 1909/1909 [==============================] - 0s 205us/sample - loss: 0.9519 - accuracy: 0.5558 - val_loss: 1.0457 - val_accuracy: 0.4883
# Epoch 37/300
# 1909/1909 [==============================] - 0s 238us/sample - loss: 0.9408 - accuracy: 0.5678 - val_loss: 1.0447 - val_accuracy: 0.4867
# Epoch 38/300
# 1909/1909 [==============================] - 0s 246us/sample - loss: 0.9327 - accuracy: 0.5799 - val_loss: 1.0436 - val_accuracy: 0.4917
# Epoch 39/300
# 1909/1909 [==============================] - 0s 228us/sample - loss: 0.9437 - accuracy: 0.5736 - val_loss: 1.0425 - val_accuracy: 0.4950
# Epoch 40/300
# 1909/1909 [==============================] - 0s 196us/sample - loss: 0.9287 - accuracy: 0.5773 - val_loss: 1.0416 - val_accuracy: 0.4967
# Epoch 41/300
# 1909/1909 [==============================] - 0s 185us/sample - loss: 0.9264 - accuracy: 0.5877 - val_loss: 1.0405 - val_accuracy: 0.4967
# Epoch 42/300
# 1909/1909 [==============================] - 0s 197us/sample - loss: 0.9277 - accuracy: 0.5919 - val_loss: 1.0396 - val_accuracy: 0.4967
# Epoch 43/300
# 1909/1909 [==============================] - 0s 187us/sample - loss: 0.9320 - accuracy: 0.5815 - val_loss: 1.0387 - val_accuracy: 0.5000
# Epoch 44/300
# 1909/1909 [==============================] - 0s 189us/sample - loss: 0.9287 - accuracy: 0.5841 - val_loss: 1.0377 - val_accuracy: 0.4967
# Epoch 45/300
# 1909/1909 [==============================] - 0s 198us/sample - loss: 0.9246 - accuracy: 0.5862 - val_loss: 1.0369 - val_accuracy: 0.4967
# Epoch 46/300
# 1909/1909 [==============================] - 0s 197us/sample - loss: 0.9183 - accuracy: 0.5862 - val_loss: 1.0360 - val_accuracy: 0.4950
# Epoch 47/300
# 1909/1909 [==============================] - 0s 227us/sample - loss: 0.9196 - accuracy: 0.5914 - val_loss: 1.0351 - val_accuracy: 0.4917
# Epoch 48/300
# 1909/1909 [==============================] - 0s 179us/sample - loss: 0.9157 - accuracy: 0.5935 - val_loss: 1.0343 - val_accuracy: 0.4917
# Epoch 49/300
# 1909/1909 [==============================] - 0s 232us/sample - loss: 0.9153 - accuracy: 0.5883 - val_loss: 1.0336 - val_accuracy: 0.4900
# Epoch 50/300
# 1909/1909 [==============================] - 0s 236us/sample - loss: 0.9111 - accuracy: 0.6019 - val_loss: 1.0328 - val_accuracy: 0.4917
# Epoch 51/300
# 1909/1909 [==============================] - 0s 216us/sample - loss: 0.9071 - accuracy: 0.5993 - val_loss: 1.0319 - val_accuracy: 0.4933
# Epoch 52/300
# 1909/1909 [==============================] - 0s 210us/sample - loss: 0.9059 - accuracy: 0.5946 - val_loss: 1.0312 - val_accuracy: 0.4950
# Epoch 53/300
# 1909/1909 [==============================] - 0s 208us/sample - loss: 0.9027 - accuracy: 0.6071 - val_loss: 1.0303 - val_accuracy: 0.4950
# Epoch 54/300
# 1909/1909 [==============================] - 0s 193us/sample - loss: 0.9035 - accuracy: 0.6035 - val_loss: 1.0296 - val_accuracy: 0.4967
# Epoch 55/300
# 1909/1909 [==============================] - 0s 210us/sample - loss: 0.8991 - accuracy: 0.6019 - val_loss: 1.0287 - val_accuracy: 0.5000
# Epoch 56/300
# 1909/1909 [==============================] - 0s 193us/sample - loss: 0.9009 - accuracy: 0.5925 - val_loss: 1.0280 - val_accuracy: 0.5000
# Epoch 57/300
# 1909/1909 [==============================] - 0s 216us/sample - loss: 0.8956 - accuracy: 0.6118 - val_loss: 1.0274 - val_accuracy: 0.5000
# Epoch 58/300
# 1909/1909 [==============================] - 0s 199us/sample - loss: 0.8943 - accuracy: 0.6139 - val_loss: 1.0265 - val_accuracy: 0.4983
# Epoch 59/300
# 1909/1909 [==============================] - 0s 220us/sample - loss: 0.8906 - accuracy: 0.6061 - val_loss: 1.0258 - val_accuracy: 0.4983
# Epoch 60/300
# 1909/1909 [==============================] - 0s 250us/sample - loss: 0.8892 - accuracy: 0.6108 - val_loss: 1.0250 - val_accuracy: 0.4983
# Epoch 61/300
# 1909/1909 [==============================] - 0s 250us/sample - loss: 0.8866 - accuracy: 0.6166 - val_loss: 1.0245 - val_accuracy: 0.5000
# Epoch 62/300
# 1909/1909 [==============================] - 0s 232us/sample - loss: 0.8898 - accuracy: 0.6050 - val_loss: 1.0237 - val_accuracy: 0.5000
# Epoch 63/300
# 1909/1909 [==============================] - 0s 227us/sample - loss: 0.8796 - accuracy: 0.6234 - val_loss: 1.0232 - val_accuracy: 0.5000
# Epoch 64/300
# 1909/1909 [==============================] - 0s 205us/sample - loss: 0.8787 - accuracy: 0.6228 - val_loss: 1.0224 - val_accuracy: 0.4983
# Epoch 65/300
# 1909/1909 [==============================] - 0s 209us/sample - loss: 0.8758 - accuracy: 0.6260 - val_loss: 1.0218 - val_accuracy: 0.4983
# Epoch 66/300
# 1909/1909 [==============================] - 0s 220us/sample - loss: 0.8720 - accuracy: 0.6234 - val_loss: 1.0212 - val_accuracy: 0.4950
# Epoch 67/300
# 1909/1909 [==============================] - 0s 222us/sample - loss: 0.8747 - accuracy: 0.6186 - val_loss: 1.0206 - val_accuracy: 0.4983
# Epoch 68/300
# 1909/1909 [==============================] - 0s 191us/sample - loss: 0.8835 - accuracy: 0.6150 - val_loss: 1.0201 - val_accuracy: 0.4983
# Epoch 69/300
# 1909/1909 [==============================] - 0s 228us/sample - loss: 0.8724 - accuracy: 0.6155 - val_loss: 1.0194 - val_accuracy: 0.5000
# Epoch 70/300
# 1909/1909 [==============================] - 0s 226us/sample - loss: 0.8672 - accuracy: 0.6239 - val_loss: 1.0189 - val_accuracy: 0.4983
# Epoch 71/300
# 1909/1909 [==============================] - 0s 185us/sample - loss: 0.8649 - accuracy: 0.6223 - val_loss: 1.0183 - val_accuracy: 0.5000
# Epoch 72/300
# 1909/1909 [==============================] - 0s 215us/sample - loss: 0.8668 - accuracy: 0.6145 - val_loss: 1.0178 - val_accuracy: 0.4983
# Epoch 73/300
# 1909/1909 [==============================] - 0s 216us/sample - loss: 0.8592 - accuracy: 0.6354 - val_loss: 1.0172 - val_accuracy: 0.4983
# Epoch 74/300
# 1909/1909 [==============================] - 0s 192us/sample - loss: 0.8594 - accuracy: 0.6396 - val_loss: 1.0168 - val_accuracy: 0.5000
# Epoch 75/300
# 1909/1909 [==============================] - 0s 178us/sample - loss: 0.8580 - accuracy: 0.6244 - val_loss: 1.0163 - val_accuracy: 0.5000
# Epoch 76/300
# 1909/1909 [==============================] - 0s 205us/sample - loss: 0.8596 - accuracy: 0.6338 - val_loss: 1.0159 - val_accuracy: 0.5000
# Epoch 77/300
# 1909/1909 [==============================] - 0s 229us/sample - loss: 0.8558 - accuracy: 0.6323 - val_loss: 1.0153 - val_accuracy: 0.4983
# Epoch 78/300
# 1909/1909 [==============================] - 0s 239us/sample - loss: 0.8514 - accuracy: 0.6296 - val_loss: 1.0149 - val_accuracy: 0.5017
# Epoch 79/300
# 1909/1909 [==============================] - 0s 217us/sample - loss: 0.8504 - accuracy: 0.6328 - val_loss: 1.0145 - val_accuracy: 0.5000
# Epoch 80/300
# 1909/1909 [==============================] - 0s 229us/sample - loss: 0.8425 - accuracy: 0.6317 - val_loss: 1.0141 - val_accuracy: 0.5000
# Epoch 81/300
# 1909/1909 [==============================] - 0s 238us/sample - loss: 0.8494 - accuracy: 0.6333 - val_loss: 1.0136 - val_accuracy: 0.4983
# Epoch 82/300
# 1909/1909 [==============================] - 0s 223us/sample - loss: 0.8464 - accuracy: 0.6255 - val_loss: 1.0132 - val_accuracy: 0.5000
# Epoch 83/300
# 1909/1909 [==============================] - 0s 237us/sample - loss: 0.8416 - accuracy: 0.6469 - val_loss: 1.0127 - val_accuracy: 0.4983
# Epoch 84/300
# 1909/1909 [==============================] - 0s 222us/sample - loss: 0.8436 - accuracy: 0.6338 - val_loss: 1.0124 - val_accuracy: 0.5017
# Epoch 85/300
# 1909/1909 [==============================] - 0s 216us/sample - loss: 0.8492 - accuracy: 0.6338 - val_loss: 1.0121 - val_accuracy: 0.5017
# Epoch 86/300
# 1909/1909 [==============================] - 0s 221us/sample - loss: 0.8435 - accuracy: 0.6312 - val_loss: 1.0118 - val_accuracy: 0.5017
# Epoch 87/300
# 1909/1909 [==============================] - 0s 201us/sample - loss: 0.8440 - accuracy: 0.6302 - val_loss: 1.0115 - val_accuracy: 0.5000
# Epoch 88/300
# 1909/1909 [==============================] - 0s 215us/sample - loss: 0.8402 - accuracy: 0.6386 - val_loss: 1.0110 - val_accuracy: 0.5017
# Epoch 89/300
# 1909/1909 [==============================] - 0s 211us/sample - loss: 0.8342 - accuracy: 0.6359 - val_loss: 1.0108 - val_accuracy: 0.5033
# Epoch 90/300
# 1909/1909 [==============================] - 0s 185us/sample - loss: 0.8289 - accuracy: 0.6527 - val_loss: 1.0105 - val_accuracy: 0.5017
# Epoch 91/300
# 1909/1909 [==============================] - 0s 207us/sample - loss: 0.8277 - accuracy: 0.6485 - val_loss: 1.0101 - val_accuracy: 0.5033
# Epoch 92/300
# 1909/1909 [==============================] - 0s 218us/sample - loss: 0.8198 - accuracy: 0.6700 - val_loss: 1.0099 - val_accuracy: 0.5033
# Epoch 93/300
# 1909/1909 [==============================] - 0s 215us/sample - loss: 0.8251 - accuracy: 0.6511 - val_loss: 1.0097 - val_accuracy: 0.5033
# Epoch 94/300
# 1909/1909 [==============================] - 0s 193us/sample - loss: 0.8237 - accuracy: 0.6396 - val_loss: 1.0093 - val_accuracy: 0.5017
# Epoch 95/300
# 1909/1909 [==============================] - 0s 222us/sample - loss: 0.8172 - accuracy: 0.6627 - val_loss: 1.0091 - val_accuracy: 0.5000
# Epoch 96/300
# 1909/1909 [==============================] - 0s 212us/sample - loss: 0.8211 - accuracy: 0.6511 - val_loss: 1.0089 - val_accuracy: 0.5000
# Epoch 97/300
# 1909/1909 [==============================] - 0s 229us/sample - loss: 0.8155 - accuracy: 0.6485 - val_loss: 1.0086 - val_accuracy: 0.5017
# Epoch 98/300
# 1909/1909 [==============================] - 0s 246us/sample - loss: 0.8153 - accuracy: 0.6433 - val_loss: 1.0083 - val_accuracy: 0.5000
# Epoch 99/300
# 1909/1909 [==============================] - 0s 235us/sample - loss: 0.8143 - accuracy: 0.6611 - val_loss: 1.0081 - val_accuracy: 0.5000
# Epoch 100/300
# 1909/1909 [==============================] - 0s 229us/sample - loss: 0.8163 - accuracy: 0.6553 - val_loss: 1.0080 - val_accuracy: 0.5017
# Epoch 101/300
# 1909/1909 [==============================] - 0s 232us/sample - loss: 0.8085 - accuracy: 0.6632 - val_loss: 1.0079 - val_accuracy: 0.5000
# Epoch 102/300
# 1909/1909 [==============================] - 0s 239us/sample - loss: 0.8130 - accuracy: 0.6496 - val_loss: 1.0077 - val_accuracy: 0.5000
# Epoch 103/300
# 1909/1909 [==============================] - 0s 203us/sample - loss: 0.8063 - accuracy: 0.6548 - val_loss: 1.0074 - val_accuracy: 0.5017
# Epoch 104/300
# 1909/1909 [==============================] - 0s 224us/sample - loss: 0.8059 - accuracy: 0.6616 - val_loss: 1.0072 - val_accuracy: 0.5017
# Epoch 105/300
# 1909/1909 [==============================] - 0s 198us/sample - loss: 0.7994 - accuracy: 0.6642 - val_loss: 1.0070 - val_accuracy: 0.5033
# Epoch 106/300
# 1909/1909 [==============================] - 0s 215us/sample - loss: 0.8019 - accuracy: 0.6579 - val_loss: 1.0068 - val_accuracy: 0.5033
# Epoch 107/300
# 1909/1909 [==============================] - 0s 230us/sample - loss: 0.8004 - accuracy: 0.6716 - val_loss: 1.0066 - val_accuracy: 0.5033
# Epoch 108/300
# 1909/1909 [==============================] - 0s 217us/sample - loss: 0.7895 - accuracy: 0.6747 - val_loss: 1.0064 - val_accuracy: 0.5050
# Epoch 109/300
# 1909/1909 [==============================] - 0s 198us/sample - loss: 0.8017 - accuracy: 0.6642 - val_loss: 1.0063 - val_accuracy: 0.5050
# Epoch 110/300
# 1909/1909 [==============================] - 0s 221us/sample - loss: 0.7955 - accuracy: 0.6763 - val_loss: 1.0063 - val_accuracy: 0.5033
# Epoch 111/300
# 1909/1909 [==============================] - 0s 211us/sample - loss: 0.7908 - accuracy: 0.6742 - val_loss: 1.0061 - val_accuracy: 0.5017
# Epoch 112/300
# 1909/1909 [==============================] - 0s 180us/sample - loss: 0.7990 - accuracy: 0.6642 - val_loss: 1.0061 - val_accuracy: 0.5017
# Epoch 113/300
# 1909/1909 [==============================] - 0s 169us/sample - loss: 0.7885 - accuracy: 0.6710 - val_loss: 1.0061 - val_accuracy: 0.5000
# Epoch 114/300
# 1909/1909 [==============================] - 0s 200us/sample - loss: 0.7856 - accuracy: 0.6721 - val_loss: 1.0061 - val_accuracy: 0.5033
# Epoch 00114: early stopping
# 247/247 [==============================] - 0s 111us/sample - loss: 1.4083 - accuracy: 0.2713
# 1it [14:33, 873.50s/it]
#   0%|          | 0/3 [00:00<?, ?it/s]
#  33%|███▎      | 1/3 [00:05<00:11,  5.73s/it]
#  67%|██████▋   | 2/3 [00:11<00:05,  5.74s/it]
# 100%|██████████| 3/3 [00:14<00:00,  4.70s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 604.3359375 steps, validate for 205.15625 steps
# Epoch 1/300
# 605/604 [==============================] - 19s 31ms/step - loss: 1.1390 - accuracy: 0.4178 - val_loss: 1.0973 - val_accuracy: 0.4390
# Epoch 2/300
# 605/604 [==============================] - 18s 29ms/step - loss: 1.0069 - accuracy: 0.4970 - val_loss: 1.0795 - val_accuracy: 0.4472
# Epoch 3/300
# 605/604 [==============================] - 18s 29ms/step - loss: 0.9792 - accuracy: 0.5171 - val_loss: 1.0751 - val_accuracy: 0.4455
# Epoch 4/300
# 605/604 [==============================] - 18s 30ms/step - loss: 0.9613 - accuracy: 0.5310 - val_loss: 1.0775 - val_accuracy: 0.4477
# Epoch 5/300
# 605/604 [==============================] - 18s 29ms/step - loss: 0.9474 - accuracy: 0.5419 - val_loss: 1.0773 - val_accuracy: 0.4488
# Epoch 6/300
# 605/604 [==============================] - 18s 29ms/step - loss: 0.9361 - accuracy: 0.5491 - val_loss: 1.0805 - val_accuracy: 0.4529
# Epoch 00006: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 604.3359375 steps, validate for 205.15625 steps
# Epoch 1/300
# 605/604 [==============================] - 41s 67ms/step - loss: 0.9151 - accuracy: 0.5653 - val_loss: 1.1283 - val_accuracy: 0.4262
# Epoch 2/300
# 605/604 [==============================] - 40s 66ms/step - loss: 0.8833 - accuracy: 0.5880 - val_loss: 1.1110 - val_accuracy: 0.4280
# Epoch 3/300
# 605/604 [==============================] - 40s 66ms/step - loss: 0.8583 - accuracy: 0.6051 - val_loss: 1.1089 - val_accuracy: 0.4345
# Epoch 4/300
# 605/604 [==============================] - 40s 65ms/step - loss: 0.8363 - accuracy: 0.6194 - val_loss: 1.1330 - val_accuracy: 0.4397
# Epoch 5/300
# 605/604 [==============================] - 40s 66ms/step - loss: 0.8157 - accuracy: 0.6347 - val_loss: 1.1346 - val_accuracy: 0.4252
# Epoch 6/300
# 605/604 [==============================] - 40s 66ms/step - loss: 0.7969 - accuracy: 0.6475 - val_loss: 1.1367 - val_accuracy: 0.4399
# Epoch 00006: early stopping
# 414/414 [==============================] - 0s 643us/sample - loss: 1.1476 - accuracy: 0.3406
# 392/392 [==============================] - 0s 245us/sample - loss: 1.1445 - accuracy: 0.3291
# 382/382 [==============================] - 0s 227us/sample - loss: 1.0612 - accuracy: 0.3796
# 356/356 [==============================] - 0s 239us/sample - loss: 1.0548 - accuracy: 0.4157
# 330/330 [==============================] - 0s 277us/sample - loss: 1.0440 - accuracy: 0.4303
# 317/317 [==============================] - 0s 618us/sample - loss: 1.0489 - accuracy: 0.4385
# 311/311 [==============================] - 0s 256us/sample - loss: 1.0550 - accuracy: 0.4019
# 309/309 [==============================] - 0s 291us/sample - loss: 1.0461 - accuracy: 0.4175
# 294/294 [==============================] - 0s 502us/sample - loss: 1.1165 - accuracy: 0.3776
# 289/289 [==============================] - 0s 425us/sample - loss: 1.1244 - accuracy: 0.3772
# 269/269 [==============================] - 0s 201us/sample - loss: 1.1205 - accuracy: 0.3903
# 262/262 [==============================] - 0s 209us/sample - loss: 1.1603 - accuracy: 0.3626
# 254/254 [==============================] - 0s 222us/sample - loss: 1.0879 - accuracy: 0.3780
# 253/253 [==============================] - 0s 210us/sample - loss: 1.1542 - accuracy: 0.3557
# 252/252 [==============================] - 0s 229us/sample - loss: 1.1326 - accuracy: 0.3810
# 249/249 [==============================] - 0s 228us/sample - loss: 1.1347 - accuracy: 0.3976
# 246/246 [==============================] - 0s 244us/sample - loss: 1.1196 - accuracy: 0.3496
# 244/244 [==============================] - 0s 232us/sample - loss: 1.1649 - accuracy: 0.3361
# 243/243 [==============================] - 0s 216us/sample - loss: 1.1523 - accuracy: 0.3580
# 241/241 [==============================] - 0s 260us/sample - loss: 1.1516 - accuracy: 0.4108
# 239/239 [==============================] - 0s 579us/sample - loss: 1.1527 - accuracy: 0.3431
# 236/236 [==============================] - 0s 223us/sample - loss: 1.1828 - accuracy: 0.3771
# 235/235 [==============================] - 0s 224us/sample - loss: 1.1313 - accuracy: 0.3617
# 229/229 [==============================] - 0s 224us/sample - loss: 1.1829 - accuracy: 0.3537
# 229/229 [==============================] - 0s 213us/sample - loss: 1.1280 - accuracy: 0.3843
# 225/225 [==============================] - 0s 225us/sample - loss: 1.1519 - accuracy: 0.3911
# 223/223 [==============================] - 0s 224us/sample - loss: 1.1758 - accuracy: 0.3543
# 222/222 [==============================] - 0s 213us/sample - loss: 1.1590 - accuracy: 0.3604
# 222/222 [==============================] - 0s 207us/sample - loss: 1.1191 - accuracy: 0.4099
# 223/223 [==============================] - 0s 212us/sample - loss: 1.0996 - accuracy: 0.4036
# 222/222 [==============================] - 0s 199us/sample - loss: 1.0623 - accuracy: 0.4279
# 216/216 [==============================] - 0s 205us/sample - loss: 1.1220 - accuracy: 0.4074
# Saved_feature_train
# Saved_feature_test
# Saved_feature_validation
# Train on 1918 samples, validate on 644 samples
# Epoch 1/300
# 1918/1918 [==============================] - 2s 1ms/sample - loss: 1.1316 - accuracy: 0.3566 - val_loss: 1.1063 - val_accuracy: 0.4022
# Epoch 2/300
# 1918/1918 [==============================] - 0s 198us/sample - loss: 1.1036 - accuracy: 0.3832 - val_loss: 1.0975 - val_accuracy: 0.4022
# Epoch 3/300
# 1918/1918 [==============================] - 0s 226us/sample - loss: 1.0880 - accuracy: 0.3921 - val_loss: 1.0914 - val_accuracy: 0.4208
# Epoch 4/300
# 1918/1918 [==============================] - 0s 211us/sample - loss: 1.0811 - accuracy: 0.4030 - val_loss: 1.0866 - val_accuracy: 0.4348
# Epoch 5/300
# 1918/1918 [==============================] - 0s 227us/sample - loss: 1.0671 - accuracy: 0.4197 - val_loss: 1.0830 - val_accuracy: 0.4317
# Epoch 6/300
# 1918/1918 [==============================] - 0s 222us/sample - loss: 1.0717 - accuracy: 0.4124 - val_loss: 1.0798 - val_accuracy: 0.4394
# Epoch 7/300
# 1918/1918 [==============================] - 0s 229us/sample - loss: 1.0569 - accuracy: 0.4254 - val_loss: 1.0772 - val_accuracy: 0.4472
# Epoch 8/300
# 1918/1918 [==============================] - 0s 213us/sample - loss: 1.0577 - accuracy: 0.4312 - val_loss: 1.0749 - val_accuracy: 0.4488
# Epoch 9/300
# 1918/1918 [==============================] - 0s 233us/sample - loss: 1.0506 - accuracy: 0.4385 - val_loss: 1.0726 - val_accuracy: 0.4488
# Epoch 10/300
# 1918/1918 [==============================] - 0s 243us/sample - loss: 1.0380 - accuracy: 0.4479 - val_loss: 1.0710 - val_accuracy: 0.4472
# Epoch 11/300
# 1918/1918 [==============================] - 0s 224us/sample - loss: 1.0413 - accuracy: 0.4317 - val_loss: 1.0692 - val_accuracy: 0.4503
# Epoch 12/300
# 1918/1918 [==============================] - 0s 219us/sample - loss: 1.0332 - accuracy: 0.4599 - val_loss: 1.0677 - val_accuracy: 0.4519
# Epoch 13/300
# 1918/1918 [==============================] - 0s 221us/sample - loss: 1.0373 - accuracy: 0.4416 - val_loss: 1.0664 - val_accuracy: 0.4441
# Epoch 14/300
# 1918/1918 [==============================] - 0s 234us/sample - loss: 1.0269 - accuracy: 0.4739 - val_loss: 1.0652 - val_accuracy: 0.4441
# Epoch 15/300
# 1918/1918 [==============================] - 0s 218us/sample - loss: 1.0233 - accuracy: 0.4708 - val_loss: 1.0640 - val_accuracy: 0.4394
# Epoch 16/300
# 1918/1918 [==============================] - 0s 220us/sample - loss: 1.0136 - accuracy: 0.4854 - val_loss: 1.0628 - val_accuracy: 0.4379
# Epoch 17/300
# 1918/1918 [==============================] - 0s 206us/sample - loss: 1.0157 - accuracy: 0.4755 - val_loss: 1.0619 - val_accuracy: 0.4394
# Epoch 18/300
# 1918/1918 [==============================] - 0s 226us/sample - loss: 1.0144 - accuracy: 0.4708 - val_loss: 1.0608 - val_accuracy: 0.4441
# Epoch 19/300
# 1918/1918 [==============================] - 0s 213us/sample - loss: 1.0161 - accuracy: 0.4859 - val_loss: 1.0599 - val_accuracy: 0.4441
# Epoch 20/300
# 1918/1918 [==============================] - 0s 215us/sample - loss: 1.0062 - accuracy: 0.4818 - val_loss: 1.0590 - val_accuracy: 0.4488
# Epoch 21/300
# 1918/1918 [==============================] - 0s 223us/sample - loss: 1.0050 - accuracy: 0.4875 - val_loss: 1.0582 - val_accuracy: 0.4519
# Epoch 22/300
# 1918/1918 [==============================] - 0s 230us/sample - loss: 1.0054 - accuracy: 0.4943 - val_loss: 1.0575 - val_accuracy: 0.4519
# Epoch 23/300
# 1918/1918 [==============================] - 0s 203us/sample - loss: 0.9970 - accuracy: 0.4896 - val_loss: 1.0566 - val_accuracy: 0.4565
# Epoch 24/300
# 1918/1918 [==============================] - 0s 217us/sample - loss: 0.9961 - accuracy: 0.4917 - val_loss: 1.0560 - val_accuracy: 0.4581
# Epoch 25/300
# 1918/1918 [==============================] - 0s 234us/sample - loss: 1.0015 - accuracy: 0.4849 - val_loss: 1.0554 - val_accuracy: 0.4596
# Epoch 26/300
# 1918/1918 [==============================] - 0s 239us/sample - loss: 1.0020 - accuracy: 0.4771 - val_loss: 1.0547 - val_accuracy: 0.4612
# Epoch 27/300
# 1918/1918 [==============================] - 0s 222us/sample - loss: 0.9957 - accuracy: 0.4948 - val_loss: 1.0540 - val_accuracy: 0.4658
# Epoch 28/300
# 1918/1918 [==============================] - 0s 229us/sample - loss: 0.9897 - accuracy: 0.5167 - val_loss: 1.0533 - val_accuracy: 0.4674
# Epoch 29/300
# 1918/1918 [==============================] - 0s 211us/sample - loss: 0.9873 - accuracy: 0.5016 - val_loss: 1.0527 - val_accuracy: 0.4720
# Epoch 30/300
# 1918/1918 [==============================] - 0s 199us/sample - loss: 0.9902 - accuracy: 0.5073 - val_loss: 1.0522 - val_accuracy: 0.4705
# Epoch 31/300
# 1918/1918 [==============================] - 0s 181us/sample - loss: 0.9909 - accuracy: 0.4953 - val_loss: 1.0516 - val_accuracy: 0.4720
# Epoch 32/300
# 1918/1918 [==============================] - 0s 197us/sample - loss: 0.9818 - accuracy: 0.5031 - val_loss: 1.0510 - val_accuracy: 0.4720
# Epoch 33/300
# 1918/1918 [==============================] - 0s 187us/sample - loss: 0.9799 - accuracy: 0.5224 - val_loss: 1.0505 - val_accuracy: 0.4720
# Epoch 34/300
# 1918/1918 [==============================] - 0s 191us/sample - loss: 0.9800 - accuracy: 0.5182 - val_loss: 1.0500 - val_accuracy: 0.4736
# Epoch 35/300
# 1918/1918 [==============================] - 0s 190us/sample - loss: 0.9827 - accuracy: 0.5172 - val_loss: 1.0494 - val_accuracy: 0.4720
# Epoch 36/300
# 1918/1918 [==============================] - 0s 174us/sample - loss: 0.9774 - accuracy: 0.5146 - val_loss: 1.0490 - val_accuracy: 0.4752
# Epoch 37/300
# 1918/1918 [==============================] - 0s 173us/sample - loss: 0.9761 - accuracy: 0.5094 - val_loss: 1.0484 - val_accuracy: 0.4767
# Epoch 38/300
# 1918/1918 [==============================] - 0s 222us/sample - loss: 0.9727 - accuracy: 0.5198 - val_loss: 1.0479 - val_accuracy: 0.4752
# Epoch 39/300
# 1918/1918 [==============================] - 0s 205us/sample - loss: 0.9715 - accuracy: 0.5156 - val_loss: 1.0474 - val_accuracy: 0.4752
# Epoch 40/300
# 1918/1918 [==============================] - 0s 219us/sample - loss: 0.9681 - accuracy: 0.5229 - val_loss: 1.0469 - val_accuracy: 0.4720
# Epoch 41/300
# 1918/1918 [==============================] - 0s 235us/sample - loss: 0.9679 - accuracy: 0.5188 - val_loss: 1.0464 - val_accuracy: 0.4736
# Epoch 42/300
# 1918/1918 [==============================] - 0s 215us/sample - loss: 0.9619 - accuracy: 0.5422 - val_loss: 1.0460 - val_accuracy: 0.4752
# Epoch 43/300
# 1918/1918 [==============================] - 0s 226us/sample - loss: 0.9643 - accuracy: 0.5224 - val_loss: 1.0455 - val_accuracy: 0.4783
# Epoch 44/300
# 1918/1918 [==============================] - 0s 190us/sample - loss: 0.9605 - accuracy: 0.5438 - val_loss: 1.0451 - val_accuracy: 0.4798
# Epoch 45/300
# 1918/1918 [==============================] - 0s 190us/sample - loss: 0.9592 - accuracy: 0.5266 - val_loss: 1.0449 - val_accuracy: 0.4783
# Epoch 46/300
# 1918/1918 [==============================] - 0s 195us/sample - loss: 0.9498 - accuracy: 0.5422 - val_loss: 1.0445 - val_accuracy: 0.4798
# Epoch 47/300
# 1918/1918 [==============================] - 0s 201us/sample - loss: 0.9560 - accuracy: 0.5438 - val_loss: 1.0442 - val_accuracy: 0.4798
# Epoch 48/300
# 1918/1918 [==============================] - 0s 223us/sample - loss: 0.9509 - accuracy: 0.5412 - val_loss: 1.0439 - val_accuracy: 0.4829
# Epoch 49/300
# 1918/1918 [==============================] - 0s 185us/sample - loss: 0.9496 - accuracy: 0.5323 - val_loss: 1.0435 - val_accuracy: 0.4845
# Epoch 50/300
# 1918/1918 [==============================] - 0s 232us/sample - loss: 0.9431 - accuracy: 0.5506 - val_loss: 1.0432 - val_accuracy: 0.4845
# Epoch 51/300
# 1918/1918 [==============================] - 0s 193us/sample - loss: 0.9470 - accuracy: 0.5537 - val_loss: 1.0426 - val_accuracy: 0.4860
# Epoch 52/300
# 1918/1918 [==============================] - 0s 209us/sample - loss: 0.9475 - accuracy: 0.5417 - val_loss: 1.0422 - val_accuracy: 0.4907
# Epoch 53/300
# 1918/1918 [==============================] - 0s 217us/sample - loss: 0.9493 - accuracy: 0.5506 - val_loss: 1.0419 - val_accuracy: 0.4907
# Epoch 54/300
# 1918/1918 [==============================] - 0s 204us/sample - loss: 0.9465 - accuracy: 0.5542 - val_loss: 1.0415 - val_accuracy: 0.4907
# Epoch 55/300
# 1918/1918 [==============================] - 0s 204us/sample - loss: 0.9383 - accuracy: 0.5553 - val_loss: 1.0412 - val_accuracy: 0.4922
# Epoch 56/300
# 1918/1918 [==============================] - 0s 226us/sample - loss: 0.9380 - accuracy: 0.5469 - val_loss: 1.0409 - val_accuracy: 0.4922
# Epoch 57/300
# 1918/1918 [==============================] - 0s 199us/sample - loss: 0.9338 - accuracy: 0.5579 - val_loss: 1.0407 - val_accuracy: 0.4907
# Epoch 58/300
# 1918/1918 [==============================] - 0s 205us/sample - loss: 0.9409 - accuracy: 0.5469 - val_loss: 1.0403 - val_accuracy: 0.4922
# Epoch 59/300
# 1918/1918 [==============================] - 0s 208us/sample - loss: 0.9330 - accuracy: 0.5594 - val_loss: 1.0399 - val_accuracy: 0.4907
# Epoch 60/300
# 1918/1918 [==============================] - 0s 215us/sample - loss: 0.9359 - accuracy: 0.5448 - val_loss: 1.0396 - val_accuracy: 0.4907
# Epoch 61/300
# 1918/1918 [==============================] - 0s 226us/sample - loss: 0.9379 - accuracy: 0.5474 - val_loss: 1.0392 - val_accuracy: 0.4907
# Epoch 62/300
# 1918/1918 [==============================] - 0s 196us/sample - loss: 0.9323 - accuracy: 0.5542 - val_loss: 1.0389 - val_accuracy: 0.4907
# Epoch 63/300
# 1918/1918 [==============================] - 0s 225us/sample - loss: 0.9282 - accuracy: 0.5620 - val_loss: 1.0386 - val_accuracy: 0.4907
# Epoch 64/300
# 1918/1918 [==============================] - 0s 201us/sample - loss: 0.9231 - accuracy: 0.5777 - val_loss: 1.0382 - val_accuracy: 0.4891
# Epoch 65/300
# 1918/1918 [==============================] - 0s 189us/sample - loss: 0.9206 - accuracy: 0.5693 - val_loss: 1.0380 - val_accuracy: 0.4891
# Epoch 66/300
# 1918/1918 [==============================] - 0s 183us/sample - loss: 0.9263 - accuracy: 0.5563 - val_loss: 1.0377 - val_accuracy: 0.4907
# Epoch 67/300
# 1918/1918 [==============================] - 0s 215us/sample - loss: 0.9281 - accuracy: 0.5641 - val_loss: 1.0374 - val_accuracy: 0.4907
# Epoch 68/300
# 1918/1918 [==============================] - 0s 212us/sample - loss: 0.9254 - accuracy: 0.5631 - val_loss: 1.0372 - val_accuracy: 0.4907
# Epoch 69/300
# 1918/1918 [==============================] - 0s 165us/sample - loss: 0.9182 - accuracy: 0.5579 - val_loss: 1.0368 - val_accuracy: 0.4922
# Epoch 70/300
# 1918/1918 [==============================] - 0s 217us/sample - loss: 0.9168 - accuracy: 0.5699 - val_loss: 1.0366 - val_accuracy: 0.4922
# Epoch 71/300
# 1918/1918 [==============================] - 0s 188us/sample - loss: 0.9127 - accuracy: 0.5829 - val_loss: 1.0364 - val_accuracy: 0.4953
# Epoch 72/300
# 1918/1918 [==============================] - 0s 205us/sample - loss: 0.9124 - accuracy: 0.5819 - val_loss: 1.0360 - val_accuracy: 0.4891
# Epoch 73/300
# 1918/1918 [==============================] - 0s 226us/sample - loss: 0.9140 - accuracy: 0.5766 - val_loss: 1.0358 - val_accuracy: 0.4891
# Epoch 74/300
# 1918/1918 [==============================] - 0s 209us/sample - loss: 0.9137 - accuracy: 0.5751 - val_loss: 1.0355 - val_accuracy: 0.4891
# Epoch 75/300
# 1918/1918 [==============================] - 0s 210us/sample - loss: 0.9076 - accuracy: 0.5798 - val_loss: 1.0353 - val_accuracy: 0.4876
# Epoch 76/300
# 1918/1918 [==============================] - 0s 199us/sample - loss: 0.9077 - accuracy: 0.5933 - val_loss: 1.0351 - val_accuracy: 0.4891
# Epoch 77/300
# 1918/1918 [==============================] - 0s 199us/sample - loss: 0.9108 - accuracy: 0.5918 - val_loss: 1.0349 - val_accuracy: 0.4891
# Epoch 78/300
# 1918/1918 [==============================] - 0s 220us/sample - loss: 0.9145 - accuracy: 0.5699 - val_loss: 1.0347 - val_accuracy: 0.4891
# Epoch 79/300
# 1918/1918 [==============================] - 0s 234us/sample - loss: 0.9020 - accuracy: 0.5766 - val_loss: 1.0345 - val_accuracy: 0.4876
# Epoch 80/300
# 1918/1918 [==============================] - 0s 212us/sample - loss: 0.9000 - accuracy: 0.5782 - val_loss: 1.0342 - val_accuracy: 0.4860
# Epoch 81/300
# 1918/1918 [==============================] - 0s 206us/sample - loss: 0.9007 - accuracy: 0.5897 - val_loss: 1.0341 - val_accuracy: 0.4891
# Epoch 82/300
# 1918/1918 [==============================] - 0s 209us/sample - loss: 0.9051 - accuracy: 0.5714 - val_loss: 1.0338 - val_accuracy: 0.4891
# Epoch 83/300
# 1918/1918 [==============================] - 0s 174us/sample - loss: 0.9002 - accuracy: 0.5860 - val_loss: 1.0336 - val_accuracy: 0.4891
# Epoch 84/300
# 1918/1918 [==============================] - 0s 221us/sample - loss: 0.8992 - accuracy: 0.5881 - val_loss: 1.0334 - val_accuracy: 0.4907
# Epoch 85/300
# 1918/1918 [==============================] - 0s 209us/sample - loss: 0.8954 - accuracy: 0.5892 - val_loss: 1.0333 - val_accuracy: 0.4891
# Epoch 86/300
# 1918/1918 [==============================] - 0s 232us/sample - loss: 0.8919 - accuracy: 0.5819 - val_loss: 1.0331 - val_accuracy: 0.4876
# Epoch 87/300
# 1918/1918 [==============================] - 0s 234us/sample - loss: 0.8973 - accuracy: 0.5803 - val_loss: 1.0329 - val_accuracy: 0.4891
# Epoch 88/300
# 1918/1918 [==============================] - 0s 223us/sample - loss: 0.8864 - accuracy: 0.5876 - val_loss: 1.0328 - val_accuracy: 0.4907
# Epoch 89/300
# 1918/1918 [==============================] - 0s 212us/sample - loss: 0.8938 - accuracy: 0.5970 - val_loss: 1.0326 - val_accuracy: 0.4938
# Epoch 90/300
# 1918/1918 [==============================] - 0s 214us/sample - loss: 0.8880 - accuracy: 0.6006 - val_loss: 1.0324 - val_accuracy: 0.4953
# Epoch 91/300
# 1918/1918 [==============================] - 0s 204us/sample - loss: 0.8831 - accuracy: 0.5860 - val_loss: 1.0322 - val_accuracy: 0.4922
# Epoch 92/300
# 1918/1918 [==============================] - 0s 198us/sample - loss: 0.8882 - accuracy: 0.5959 - val_loss: 1.0320 - val_accuracy: 0.4922
# Epoch 93/300
# 1918/1918 [==============================] - 0s 203us/sample - loss: 0.8879 - accuracy: 0.5970 - val_loss: 1.0318 - val_accuracy: 0.4922
# Epoch 94/300
# 1918/1918 [==============================] - 0s 174us/sample - loss: 0.8889 - accuracy: 0.5923 - val_loss: 1.0317 - val_accuracy: 0.4891
# Epoch 95/300
# 1918/1918 [==============================] - 0s 224us/sample - loss: 0.8769 - accuracy: 0.6006 - val_loss: 1.0316 - val_accuracy: 0.4907
# Epoch 96/300
# 1918/1918 [==============================] - 0s 212us/sample - loss: 0.8794 - accuracy: 0.5991 - val_loss: 1.0314 - val_accuracy: 0.4907
# Epoch 97/300
# 1918/1918 [==============================] - 0s 197us/sample - loss: 0.8785 - accuracy: 0.6032 - val_loss: 1.0312 - val_accuracy: 0.4891
# Epoch 98/300
# 1918/1918 [==============================] - 0s 225us/sample - loss: 0.8758 - accuracy: 0.6022 - val_loss: 1.0313 - val_accuracy: 0.4891
# Epoch 99/300
# 1918/1918 [==============================] - 0s 208us/sample - loss: 0.8784 - accuracy: 0.6038 - val_loss: 1.0309 - val_accuracy: 0.4907
# Epoch 100/300
# 1918/1918 [==============================] - 0s 229us/sample - loss: 0.8700 - accuracy: 0.6011 - val_loss: 1.0310 - val_accuracy: 0.4891
# Epoch 101/300
# 1918/1918 [==============================] - 0s 211us/sample - loss: 0.8755 - accuracy: 0.6043 - val_loss: 1.0308 - val_accuracy: 0.4891
# Epoch 102/300
# 1918/1918 [==============================] - 0s 214us/sample - loss: 0.8680 - accuracy: 0.6121 - val_loss: 1.0306 - val_accuracy: 0.4891
# Epoch 103/300
# 1918/1918 [==============================] - 0s 231us/sample - loss: 0.8735 - accuracy: 0.6084 - val_loss: 1.0306 - val_accuracy: 0.4829
# Epoch 104/300
# 1918/1918 [==============================] - 0s 232us/sample - loss: 0.8709 - accuracy: 0.5980 - val_loss: 1.0305 - val_accuracy: 0.4829
# Epoch 105/300
# 1918/1918 [==============================] - 0s 231us/sample - loss: 0.8717 - accuracy: 0.6027 - val_loss: 1.0304 - val_accuracy: 0.4829
# Epoch 106/300
# 1918/1918 [==============================] - 0s 212us/sample - loss: 0.8602 - accuracy: 0.6121 - val_loss: 1.0303 - val_accuracy: 0.4798
# Epoch 107/300
# 1918/1918 [==============================] - 0s 194us/sample - loss: 0.8539 - accuracy: 0.6163 - val_loss: 1.0303 - val_accuracy: 0.4798
# Epoch 108/300
# 1918/1918 [==============================] - 0s 182us/sample - loss: 0.8583 - accuracy: 0.6079 - val_loss: 1.0302 - val_accuracy: 0.4798
# Epoch 109/300
# 1918/1918 [==============================] - 0s 191us/sample - loss: 0.8526 - accuracy: 0.6303 - val_loss: 1.0302 - val_accuracy: 0.4783
# Epoch 110/300
# 1918/1918 [==============================] - 0s 205us/sample - loss: 0.8614 - accuracy: 0.6184 - val_loss: 1.0300 - val_accuracy: 0.4798
# Epoch 111/300
# 1918/1918 [==============================] - 0s 205us/sample - loss: 0.8598 - accuracy: 0.6121 - val_loss: 1.0299 - val_accuracy: 0.4814
# Epoch 112/300
# 1918/1918 [==============================] - 0s 181us/sample - loss: 0.8592 - accuracy: 0.6126 - val_loss: 1.0300 - val_accuracy: 0.4829
# Epoch 113/300
# 1918/1918 [==============================] - 0s 199us/sample - loss: 0.8499 - accuracy: 0.6319 - val_loss: 1.0298 - val_accuracy: 0.4829
# Epoch 114/300
# 1918/1918 [==============================] - 0s 180us/sample - loss: 0.8570 - accuracy: 0.6084 - val_loss: 1.0298 - val_accuracy: 0.4845
# Epoch 115/300
# 1918/1918 [==============================] - 0s 227us/sample - loss: 0.8461 - accuracy: 0.6298 - val_loss: 1.0297 - val_accuracy: 0.4829
# Epoch 116/300
# 1918/1918 [==============================] - 0s 229us/sample - loss: 0.8487 - accuracy: 0.6350 - val_loss: 1.0298 - val_accuracy: 0.4829
# Epoch 117/300
# 1918/1918 [==============================] - 0s 207us/sample - loss: 0.8465 - accuracy: 0.6309 - val_loss: 1.0297 - val_accuracy: 0.4845
# Epoch 118/300
# 1918/1918 [==============================] - 0s 233us/sample - loss: 0.8465 - accuracy: 0.6194 - val_loss: 1.0298 - val_accuracy: 0.4845
# Epoch 00118: early stopping
# 194/194 [==============================] - 0s 125us/sample - loss: 1.0946 - accuracy: 0.3505
# 2it [28:23, 860.47s/it]
#   0%|          | 0/3 [00:00<?, ?it/s]
#  33%|███▎      | 1/3 [00:05<00:11,  5.84s/it]
#  67%|██████▋   | 2/3 [00:11<00:05,  5.93s/it]
# 100%|██████████| 3/3 [00:14<00:00,  4.86s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 591.0859375 steps, validate for 201.1015625 steps
# Epoch 1/300
# 592/591 [==============================] - 19s 31ms/step - loss: 1.1349 - accuracy: 0.4225 - val_loss: 1.0922 - val_accuracy: 0.4409
# Epoch 2/300
# 592/591 [==============================] - 18s 30ms/step - loss: 1.0005 - accuracy: 0.5000 - val_loss: 1.0751 - val_accuracy: 0.4466
# Epoch 3/300
# 592/591 [==============================] - 18s 30ms/step - loss: 0.9716 - accuracy: 0.5208 - val_loss: 1.0687 - val_accuracy: 0.4505
# Epoch 4/300
# 592/591 [==============================] - 18s 30ms/step - loss: 0.9533 - accuracy: 0.5348 - val_loss: 1.0692 - val_accuracy: 0.4536
# Epoch 5/300
# 592/591 [==============================] - 17s 29ms/step - loss: 0.9392 - accuracy: 0.5434 - val_loss: 1.0725 - val_accuracy: 0.4546
# Epoch 6/300
# 592/591 [==============================] - 18s 30ms/step - loss: 0.9276 - accuracy: 0.5527 - val_loss: 1.0741 - val_accuracy: 0.4539
# Epoch 00006: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 591.0859375 steps, validate for 201.1015625 steps
# Epoch 1/300
# 592/591 [==============================] - 40s 68ms/step - loss: 0.9052 - accuracy: 0.5694 - val_loss: 1.0849 - val_accuracy: 0.4490
# Epoch 2/300
# 592/591 [==============================] - 39s 67ms/step - loss: 0.8712 - accuracy: 0.5949 - val_loss: 1.0904 - val_accuracy: 0.4397
# Epoch 3/300
# 592/591 [==============================] - 40s 67ms/step - loss: 0.8446 - accuracy: 0.6118 - val_loss: 1.1468 - val_accuracy: 0.4333
# Epoch 4/300
# ...
# Epoch 23/300
# 1980/1980 [==============================] - 0s 234us/sample - loss: 1.0236 - accuracy: 0.4672 - val_loss: 1.0760 - val_accuracy: 0.4070
# Epoch 24/300
# 1980/1980 [==============================] - 0s 221us/sample - loss: 1.0243 - accuracy: 0.4636 - val_loss: 1.0758 - val_accuracy: 0.4107
# Epoch 25/300
# 1980/1980 [==============================] - 0s 214us/sample - loss: 1.0226 - accuracy: 0.4742 - val_loss: 1.0756 - val_accuracy: 0.4088
# Epoch 26/300
# 1980/1980 [==============================] - 0s 204us/sample - loss: 1.0206 - accuracy: 0.4667 - val_loss: 1.0755 - val_accuracy: 0.4070
# Epoch 27/300
# 1980/1980 [==============================] - 0s 219us/sample - loss: 1.0160 - accuracy: 0.4758 - val_loss: 1.0754 - val_accuracy: 0.4070
# Epoch 28/300
# 1980/1980 [==============================] - 0s 216us/sample - loss: 1.0260 - accuracy: 0.4732 - val_loss: 1.0752 - val_accuracy: 0.4107
# Epoch 29/300
# 1980/1980 [==============================] - 0s 236us/sample - loss: 1.0130 - accuracy: 0.4732 - val_loss: 1.0751 - val_accuracy: 0.4088
# Epoch 30/300
# 1980/1980 [==============================] - 0s 222us/sample - loss: 1.0125 - accuracy: 0.4818 - val_loss: 1.0749 - val_accuracy: 0.4088
# Epoch 31/300
# 1980/1980 [==============================] - 0s 204us/sample - loss: 1.0108 - accuracy: 0.4924 - val_loss: 1.0749 - val_accuracy: 0.4088
# Epoch 32/300
# 1980/1980 [==============================] - 0s 222us/sample - loss: 1.0070 - accuracy: 0.4758 - val_loss: 1.0748 - val_accuracy: 0.4107
# Epoch 33/300
# 1980/1980 [==============================] - 0s 211us/sample - loss: 1.0017 - accuracy: 0.4813 - val_loss: 1.0747 - val_accuracy: 0.4088
# Epoch 34/300
# 1980/1980 [==============================] - 0s 196us/sample - loss: 1.0042 - accuracy: 0.4894 - val_loss: 1.0748 - val_accuracy: 0.4088
# Epoch 35/300
# 1980/1980 [==============================] - 0s 192us/sample - loss: 1.0042 - accuracy: 0.4879 - val_loss: 1.0747 - val_accuracy: 0.4107
# Epoch 36/300
# 1980/1980 [==============================] - 0s 195us/sample - loss: 1.0040 - accuracy: 0.4783 - val_loss: 1.0748 - val_accuracy: 0.4107
# Epoch 37/300
# 1980/1980 [==============================] - 0s 195us/sample - loss: 0.9956 - accuracy: 0.4859 - val_loss: 1.0747 - val_accuracy: 0.4088
# Epoch 38/300
# 1980/1980 [==============================] - 0s 216us/sample - loss: 0.9970 - accuracy: 0.4985 - val_loss: 1.0748 - val_accuracy: 0.4088
# Epoch 00038: early stopping
# 233/233 [==============================] - 0s 132us/sample - loss: 1.0526 - accuracy: 0.3863
# 4it [56:35, 823.70s/it]
#   0%|          | 0/3 [00:00<?, ?it/s]
#  33%|███▎      | 1/3 [00:05<00:11,  5.72s/it]
#  67%|██████▋   | 2/3 [00:11<00:05,  5.76s/it]
# 100%|██████████| 3/3 [00:14<00:00,  4.86s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 628.515625 steps, validate for 183.390625 steps
# Epoch 1/300
# 629/628 [==============================] - 19s 30ms/step - loss: 1.1140 - accuracy: 0.4320 - val_loss: 1.1208 - val_accuracy: 0.3854
# Epoch 2/300
# 629/628 [==============================] - 18s 28ms/step - loss: 1.0127 - accuracy: 0.4797 - val_loss: 1.0978 - val_accuracy: 0.3883
# Epoch 3/300
# 629/628 [==============================] - 18s 29ms/step - loss: 0.9851 - accuracy: 0.5018 - val_loss: 1.0938 - val_accuracy: 0.3901
# Epoch 4/300
# 629/628 [==============================] - 19s 29ms/step - loss: 0.9670 - accuracy: 0.5182 - val_loss: 1.0906 - val_accuracy: 0.3966
# Epoch 5/300
# 629/628 [==============================] - 18s 29ms/step - loss: 0.9531 - accuracy: 0.5289 - val_loss: 1.0870 - val_accuracy: 0.4018
# Epoch 6/300
# 629/628 [==============================] - 18s 28ms/step - loss: 0.9415 - accuracy: 0.5400 - val_loss: 1.0821 - val_accuracy: 0.4094
# Epoch 7/300
# 629/628 [==============================] - 18s 29ms/step - loss: 0.9312 - accuracy: 0.5462 - val_loss: 1.0896 - val_accuracy: 0.4066
# Epoch 8/300
# 629/628 [==============================] - 18s 29ms/step - loss: 0.9220 - accuracy: 0.5542 - val_loss: 1.0955 - val_accuracy: 0.4061
# Epoch 9/300
# 629/628 [==============================] - 19s 30ms/step - loss: 0.9139 - accuracy: 0.5606 - val_loss: 1.0890 - val_accuracy: 0.4157
# Epoch 00009: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 628.515625 steps, validate for 183.390625 steps
# Epoch 1/300
# 629/628 [==============================] - 42s 67ms/step - loss: 0.8990 - accuracy: 0.5719 - val_loss: 1.0768 - val_accuracy: 0.4354
# Epoch 2/300
# 629/628 [==============================] - 41s 65ms/step - loss: 0.8721 - accuracy: 0.5903 - val_loss: 1.1399 - val_accuracy: 0.4108
# Epoch 3/300
# 629/628 [==============================] - 41s 65ms/step - loss: 0.8505 - accuracy: 0.6073 - val_loss: 1.0869 - val_accuracy: 0.4352
# Epoch 4/300
# 629/628 [==============================] - 40s 64ms/step - loss: 0.8315 - accuracy: 0.6206 - val_loss: 1.1546 - val_accuracy: 0.4250
# Epoch 00004: early stopping
# 318/318 [==============================] - 0s 767us/sample - loss: 1.0689 - accuracy: 0.3836
# 306/306 [==============================] - 0s 277us/sample - loss: 1.0600 - accuracy: 0.3529
# 301/301 [==============================] - 0s 216us/sample - loss: 1.1196 - accuracy: 0.3422
# 301/301 [==============================] - 0s 230us/sample - loss: 1.1363 - accuracy: 0.3223
# 295/295 [==============================] - 0s 241us/sample - loss: 1.0943 - accuracy: 0.3661
# 295/295 [==============================] - 0s 300us/sample - loss: 1.0780 - accuracy: 0.3729
# 286/286 [==============================] - 0s 318us/sample - loss: 1.1074 - accuracy: 0.3741
# 281/281 [==============================] - 0s 263us/sample - loss: 1.0515 - accuracy: 0.3843
# 278/278 [==============================] - 0s 276us/sample - loss: 1.1223 - accuracy: 0.3525
# 276/276 [==============================] - 0s 270us/sample - loss: 1.0725 - accuracy: 0.3696
# 276/276 [==============================] - 0s 280us/sample - loss: 1.1044 - accuracy: 0.3478
# 270/270 [==============================] - 0s 250us/sample - loss: 1.1328 - accuracy: 0.3333
# 268/268 [==============================] - 0s 271us/sample - loss: 1.0901 - accuracy: 0.3694
# 260/260 [==============================] - 0s 267us/sample - loss: 1.1230 - accuracy: 0.3885
# 257/257 [==============================] - 0s 239us/sample - loss: 1.1393 - accuracy: 0.3385
# 253/253 [==============================] - 0s 275us/sample - loss: 1.0726 - accuracy: 0.4190
# 252/252 [==============================] - 0s 268us/sample - loss: 1.1321 - accuracy: 0.3690
# 253/253 [==============================] - 0s 255us/sample - loss: 1.0957 - accuracy: 0.3874
# 252/252 [==============================] - 0s 258us/sample - loss: 1.1348 - accuracy: 0.3611
# 248/248 [==============================] - 0s 246us/sample - loss: 1.1118 - accuracy: 0.3589
# 245/245 [==============================] - 0s 251us/sample - loss: 1.2296 - accuracy: 0.3061
# 243/243 [==============================] - 0s 258us/sample - loss: 1.0750 - accuracy: 0.3951
# 244/244 [==============================] - 0s 258us/sample - loss: 1.1510 - accuracy: 0.3484
# 242/242 [==============================] - 0s 251us/sample - loss: 1.0712 - accuracy: 0.3430
# 237/237 [==============================] - 0s 238us/sample - loss: 1.1070 - accuracy: 0.3882
# 237/237 [==============================] - 0s 259us/sample - loss: 1.0458 - accuracy: 0.4599
# 233/233 [==============================] - 0s 267us/sample - loss: 1.1006 - accuracy: 0.4034
# 228/228 [==============================] - 0s 280us/sample - loss: 1.0810 - accuracy: 0.3816
# 227/227 [==============================] - 0s 236us/sample - loss: 1.0722 - accuracy: 0.4229
# 223/223 [==============================] - 0s 244us/sample - loss: 1.0021 - accuracy: 0.5067
# 220/220 [==============================] - 0s 251us/sample - loss: 1.0637 - accuracy: 0.4318
# 214/214 [==============================] - 0s 290us/sample - loss: 1.0200 - accuracy: 0.4626
# Saved_feature_train
# Saved_feature_test
# Saved_feature_validation
# Train on 1998 samples, validate on 561 samples
# Epoch 1/300
# 1998/1998 [==============================] - 2s 1ms/sample - loss: 1.2205 - accuracy: 0.2983 - val_loss: 1.1490 - val_accuracy: 0.3387
# Epoch 2/300
# 1998/1998 [==============================] - 0s 197us/sample - loss: 1.1876 - accuracy: 0.3098 - val_loss: 1.1333 - val_accuracy: 0.3369
# Epoch 3/300
# 1998/1998 [==============================] - 0s 199us/sample - loss: 1.1670 - accuracy: 0.3183 - val_loss: 1.1218 - val_accuracy: 0.3369
# Epoch 4/300
# 1998/1998 [==============================] - 0s 195us/sample - loss: 1.1519 - accuracy: 0.3293 - val_loss: 1.1141 - val_accuracy: 0.3405
# Epoch 5/300
# 1998/1998 [==============================] - 0s 186us/sample - loss: 1.1445 - accuracy: 0.3408 - val_loss: 1.1073 - val_accuracy: 0.3512
# Epoch 6/300
# 1998/1998 [==============================] - 0s 173us/sample - loss: 1.1312 - accuracy: 0.3524 - val_loss: 1.1019 - val_accuracy: 0.3708
# Epoch 7/300
# 1998/1998 [==============================] - 0s 192us/sample - loss: 1.1250 - accuracy: 0.3629 - val_loss: 1.0973 - val_accuracy: 0.3708
# Epoch 8/300
# 1998/1998 [==============================] - 0s 182us/sample - loss: 1.1166 - accuracy: 0.3594 - val_loss: 1.0933 - val_accuracy: 0.3850
# Epoch 9/300
# 1998/1998 [==============================] - 0s 205us/sample - loss: 1.1087 - accuracy: 0.3844 - val_loss: 1.0897 - val_accuracy: 0.3868
# Epoch 10/300
# 1998/1998 [==============================] - 0s 201us/sample - loss: 1.1058 - accuracy: 0.3744 - val_loss: 1.0864 - val_accuracy: 0.3868
# Epoch 11/300
# 1998/1998 [==============================] - 0s 218us/sample - loss: 1.1000 - accuracy: 0.3914 - val_loss: 1.0837 - val_accuracy: 0.3868
# Epoch 12/300
# 1998/1998 [==============================] - 0s 213us/sample - loss: 1.0871 - accuracy: 0.3994 - val_loss: 1.0811 - val_accuracy: 0.3993
# Epoch 13/300
# 1998/1998 [==============================] - 0s 196us/sample - loss: 1.0823 - accuracy: 0.3949 - val_loss: 1.0787 - val_accuracy: 0.3975
# Epoch 14/300
# 1998/1998 [==============================] - 0s 172us/sample - loss: 1.0827 - accuracy: 0.3999 - val_loss: 1.0765 - val_accuracy: 0.4064
# Epoch 15/300
# 1998/1998 [==============================] - 0s 194us/sample - loss: 1.0769 - accuracy: 0.4144 - val_loss: 1.0745 - val_accuracy: 0.4029
# Epoch 16/300
# 1998/1998 [==============================] - 0s 204us/sample - loss: 1.0702 - accuracy: 0.4169 - val_loss: 1.0726 - val_accuracy: 0.4082
# Epoch 17/300
# 1998/1998 [==============================] - 0s 207us/sample - loss: 1.0666 - accuracy: 0.4234 - val_loss: 1.0709 - val_accuracy: 0.4135
# Epoch 18/300
# 1998/1998 [==============================] - 0s 192us/sample - loss: 1.0613 - accuracy: 0.4259 - val_loss: 1.0693 - val_accuracy: 0.4100
# Epoch 19/300
# 1998/1998 [==============================] - 0s 194us/sample - loss: 1.0541 - accuracy: 0.4309 - val_loss: 1.0680 - val_accuracy: 0.4118
# Epoch 20/300
# 1998/1998 [==============================] - 0s 184us/sample - loss: 1.0553 - accuracy: 0.4129 - val_loss: 1.0666 - val_accuracy: 0.4153
# Epoch 21/300
# 1998/1998 [==============================] - 0s 191us/sample - loss: 1.0578 - accuracy: 0.4159 - val_loss: 1.0654 - val_accuracy: 0.4135
# Epoch 22/300
# 1998/1998 [==============================] - 0s 197us/sample - loss: 1.0480 - accuracy: 0.4279 - val_loss: 1.0643 - val_accuracy: 0.4153
# Epoch 23/300
# 1998/1998 [==============================] - 0s 197us/sample - loss: 1.0509 - accuracy: 0.4319 - val_loss: 1.0633 - val_accuracy: 0.4118
# Epoch 24/300
# 1998/1998 [==============================] - 0s 198us/sample - loss: 1.0409 - accuracy: 0.4344 - val_loss: 1.0623 - val_accuracy: 0.4135
# Epoch 25/300
# 1998/1998 [==============================] - 0s 214us/sample - loss: 1.0395 - accuracy: 0.4464 - val_loss: 1.0613 - val_accuracy: 0.4135
# Epoch 26/300
# 1998/1998 [==============================] - 0s 200us/sample - loss: 1.0366 - accuracy: 0.4469 - val_loss: 1.0604 - val_accuracy: 0.4135
# Epoch 27/300
# 1998/1998 [==============================] - 0s 197us/sample - loss: 1.0353 - accuracy: 0.4399 - val_loss: 1.0595 - val_accuracy: 0.4153
# Epoch 28/300
# 1998/1998 [==============================] - 0s 200us/sample - loss: 1.0295 - accuracy: 0.4630 - val_loss: 1.0588 - val_accuracy: 0.4171
# Epoch 29/300
# 1998/1998 [==============================] - 0s 210us/sample - loss: 1.0288 - accuracy: 0.4580 - val_loss: 1.0582 - val_accuracy: 0.4189
# Epoch 30/300
# 1998/1998 [==============================] - 0s 199us/sample - loss: 1.0281 - accuracy: 0.4600 - val_loss: 1.0577 - val_accuracy: 0.4153
# Epoch 31/300
# 1998/1998 [==============================] - 0s 194us/sample - loss: 1.0241 - accuracy: 0.4560 - val_loss: 1.0572 - val_accuracy: 0.4135
# Epoch 32/300
# 1998/1998 [==============================] - 0s 211us/sample - loss: 1.0192 - accuracy: 0.4525 - val_loss: 1.0567 - val_accuracy: 0.4118
# Epoch 33/300
# 1998/1998 [==============================] - 0s 220us/sample - loss: 1.0179 - accuracy: 0.4580 - val_loss: 1.0564 - val_accuracy: 0.4100
# Epoch 34/300
# 1998/1998 [==============================] - 0s 227us/sample - loss: 1.0147 - accuracy: 0.4675 - val_loss: 1.0558 - val_accuracy: 0.4118
# Epoch 35/300
# 1998/1998 [==============================] - 0s 205us/sample - loss: 1.0207 - accuracy: 0.4474 - val_loss: 1.0555 - val_accuracy: 0.4118
# Epoch 36/300
# 1998/1998 [==============================] - 0s 209us/sample - loss: 1.0168 - accuracy: 0.4565 - val_loss: 1.0552 - val_accuracy: 0.4118
# Epoch 37/300
# 1998/1998 [==============================] - 0s 204us/sample - loss: 1.0149 - accuracy: 0.4680 - val_loss: 1.0548 - val_accuracy: 0.4118
# Epoch 38/300
# 1998/1998 [==============================] - 0s 200us/sample - loss: 1.0025 - accuracy: 0.4800 - val_loss: 1.0546 - val_accuracy: 0.4153
# Epoch 39/300
# 1998/1998 [==============================] - 0s 200us/sample - loss: 1.0009 - accuracy: 0.4815 - val_loss: 1.0545 - val_accuracy: 0.4118
# Epoch 40/300
# 1998/1998 [==============================] - 0s 215us/sample - loss: 0.9990 - accuracy: 0.4805 - val_loss: 1.0541 - val_accuracy: 0.4100
# Epoch 41/300
# 1998/1998 [==============================] - 0s 215us/sample - loss: 1.0027 - accuracy: 0.4865 - val_loss: 1.0538 - val_accuracy: 0.4100
# Epoch 42/300
# 1998/1998 [==============================] - 0s 217us/sample - loss: 0.9985 - accuracy: 0.4835 - val_loss: 1.0535 - val_accuracy: 0.4046
# Epoch 43/300
# 1998/1998 [==============================] - 0s 197us/sample - loss: 0.9950 - accuracy: 0.4780 - val_loss: 1.0534 - val_accuracy: 0.4100
# Epoch 44/300
# 1998/1998 [==============================] - 0s 194us/sample - loss: 0.9988 - accuracy: 0.4805 - val_loss: 1.0532 - val_accuracy: 0.4118
# Epoch 45/300
# 1998/1998 [==============================] - 0s 190us/sample - loss: 0.9955 - accuracy: 0.4695 - val_loss: 1.0530 - val_accuracy: 0.4118
# Epoch 46/300
# 1998/1998 [==============================] - 0s 190us/sample - loss: 0.9906 - accuracy: 0.4815 - val_loss: 1.0528 - val_accuracy: 0.4100
# Epoch 47/300
# 1998/1998 [==============================] - 0s 196us/sample - loss: 0.9918 - accuracy: 0.4895 - val_loss: 1.0529 - val_accuracy: 0.4118
# Epoch 48/300
# 1998/1998 [==============================] - 0s 197us/sample - loss: 0.9827 - accuracy: 0.4945 - val_loss: 1.0528 - val_accuracy: 0.4118
# Epoch 49/300
# 1998/1998 [==============================] - 0s 191us/sample - loss: 0.9866 - accuracy: 0.4945 - val_loss: 1.0529 - val_accuracy: 0.4118
# Epoch 50/300
# 1998/1998 [==============================] - 0s 205us/sample - loss: 0.9819 - accuracy: 0.5025 - val_loss: 1.0529 - val_accuracy: 0.4064
# Epoch 51/300
# 1998/1998 [==============================] - 0s 191us/sample - loss: 0.9818 - accuracy: 0.4955 - val_loss: 1.0529 - val_accuracy: 0.4064
# Epoch 00051: early stopping
# 197/197 [==============================] - 0s 144us/sample - loss: 1.1121 - accuracy: 0.2893
# 5it [1:09:48, 837.62s/it]

# %%
# ACCURACY SCORE AVERAGE FOR CNN
cv_s = cv_mean_acc(tot_results_accuracy, string_well)
cv_s
# Out:
# [(15.769139731613299, 'cyc'),
#  (34.54069371024767, 'dox'),
#  (45.23978683476647, 'olo'),
#  (29.318059142678976, 'ket'),
#  (30.523039028048515, 'orp')]

# %%
cv_s_mean,_ = zip(*cv_s)

m_cv = np.mean(list(cv_s_mean))
m_cv
# Out:
# 31.078143689470988

# %%
# PLOT OF MEAN ACCURACY FOR EVERY TIME POINT CNN

l_drug = string_well*3

acc_plot = []

for i in tot_results_accuracy:
    acc_plot.append(i)

cv_plot = list(zip(acc_plot, l_drug))

res_plot = sorted(cv_plot, key = lambda x: x[1])

a , b = zip(*res_plot)
    
a = list(a)

s = list(np.array_split(a, 5))

cv_plot = []

for ix, i in enumerate(s):
    s1 = list(s[ix])
    
    cv_plot.append(np.average(s1, axis=0))

# %%
fig = plt.figure(figsize=(10, 5))
for i in cv_plot:
    
    plt.plot(time_points, i)
    plt.show
    plt.savefig('/home/jovyan/cv_score.png')

# %%
results_lstm = sorted(results_lstm, key=lambda x: x[1])
r_lstm , _ = zip(*results_lstm)
    
r_lstm = list(r_lstm)

re_lstm = list(np.array_split(r_lstm, 5))

cv_lstm = []

for ix, i in enumerate(re_lstm):
    r1 = list(re_lstm[ix])
    cv_lstm.append(np.mean(r1))

# %%
cv_lstm = list(zip(cv_lstm, string_well))
cv_lstm
# Out:
# [(20.917678376038868, 'cyc'),
#  (33.676974972089134, 'dox'),
#  (46.78111573060354, 'olo'),
#  (23.899371425310772, 'ket'),
#  (31.64128561814626, 'orp')]

# %%
cv_l_mean,_ = zip(*cv_lstm)

m_cv_l = np.mean(list(cv_l_mean))
m_cv_l
# Out:
# 31.383285224437714

# %%
# BEFORE RUNNING AGAIN

folders = glob.glob('/home/jovyan/DATA_MASTER_PROJECT/LSTM/FEAT_FOLDERS/*')

for fo in folders:
    file = glob.glob(f'{fo}/*')
    for f in file:
        os.remove(f)
