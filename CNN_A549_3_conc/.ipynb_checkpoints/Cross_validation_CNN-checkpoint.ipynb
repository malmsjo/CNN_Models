# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv2D, Conv3D
from tensorflow.keras.layers import MaxPooling2D, MaxPooling3D
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.losses import binary_crossentropy
from sklearn.metrics import f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score

from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image 
import seaborn as sns
import os
import re
import glob
import cv2
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
from sklearn.model_selection import StratifiedKFold
from sklearn import preprocessing
import tqdm
from numpy import loadtxt
from os import *
from sklearn.utils import class_weight
from tensorflow.keras.applications.vgg16 import preprocess_input

# %%
def atoi(text):
    return int(text) if text.isdigit() else text
def natural_keys(text):
    return [atoi(c) for c in re.split('(\d+)', text)]

# %%
def draw_confusion_matrix(true,preds):
    conf_matx = confusion_matrix(true, preds)
    sns.heatmap(conf_matx, annot=True,annot_kws={"size": 12},fmt='g', cbar=False, cmap=plt.cm.Blues) #'viridis'
    #plt.savefig('/home/jovyan/img1.png')
    plt.show()
    
    return conf_matx

# %%
def plot_history(model_history, model_name):
    fig = plt.figure(figsize=(15,5), facecolor='w')
    ax = fig.add_subplot(121)
    ax.plot(model_history.history['loss'])
    ax.plot(model_history.history['val_loss'])
    ax.set(title=model_name + ': Model loss', ylabel='Loss', xlabel='Epoch')
    ax.legend(['Train', 'Val'], loc='upper left')
    ax = fig.add_subplot(122)
    ax.plot(model_history.history['accuracy'])
    ax.plot(model_history.history['val_accuracy'])
    ax.set(title=model_name + ': Model Accuracy; test='+ str(np.round(model_history.history['val_accuracy'][-1], 3)),
           ylabel='Accuracy', xlabel='Epoch')
    ax.legend(['Train', 'Val'], loc='upper left')
    #plt.show()
    
    return fig

# %%
def resize_img(x_o):
    res = []

    for i in tqdm.tqdm(x_o):

        scale_percent = 140 # percent of original size
        width = int(i.shape[1] / (scale_percent / 100))
        height = int(i.shape[0] / (scale_percent / 100))
        dim = (width, height)
        resized = cv2.resize(i, dim, interpolation = cv2.INTER_LANCZOS4)
        res.append(resized)

    x_orig = np.reshape( res, (len( res), resized.shape[1], resized.shape[1], 3))

    return x_orig

# %%
def normalization(data, norm_mean):#, norm_sigma):
    
    x_scaled = np.subtract(data, norm_mean)# / norm_sigma
    data = x_scaled
    
    return data

# %%
def loadImages(path_list,data_list, labels):

    image_list = []
    
    for p in path_list:
    
        for i in tqdm.tqdm(sorted(data_list, key=natural_keys)):

            for filename in glob.glob(p+i):

                im=cv2.imread(filename)

                imarray = np.array(im)

                image_list.append(imarray)

    x_orig = np.reshape(image_list, (len(image_list), 90, 90, 3))



    y_orig = np.array(labels['Category'])

    return x_orig, y_orig

# %%
def creat_label(y):
    labels = []
    for ix, _ in enumerate(y):
        labels.append([[y[ix][0],y[ix][1]]] * y[ix][2])
    
    ler = [i for sub in labels for i in sub ]

    df = pd.DataFrame(ler, columns = ['Type', 'Category'])
    df = df.sort_values(by=['Type'])
    df.to_csv(sep=',',index=False)
    return df

# %%
def return_count(x):
    name_wel = []
    for i in x:
        name_wel.append(i.split('_')[0])

    z = list(set(name_wel))
    r = list(range(len(z)))

    num = []
    for iz in range(len(z)):
        count = 0
        for i in x:
            if z[iz] in i:
                count += 1
        num.append(count)
    return list(zip(z, r, num))

# %%
def change_name(name_list):

    out = []

    controll = ['B3', 'D5','D6','F10']

    adr = ['B5', 'C6', 'C11', 'E5', 'F11', 'D11', 'F7', 'G4', 'B6', 'C3', 'D4',
           'F2','G10', 'B4', 'E9', 'C7', 'E3', 'F8', 'G5', 'B10', 'D2', 'E8', 'G3', 'B8']

    hrh = ['C2','E4','E6','G6','G8','C5','D3','B9','D10','C4','D9','E7','F4','B7','E10',
            'F6','G2','B11','C10','D7','D8','F3','G11','B2']





    for i in name_list:
        for c in controll:
            if c in i:
                out.append('controll_' + i)


        for a in adr:
            if a in i:
                out.append('adr_' + i)

        for h in hrh:
            if h in i:
                out.append('hrh_' + i)

    return out

# %%
rand = list(np.random.randint(1,1000,5))

# %%
rand
# Out:
# [821, 990, 134, 156, 13]

# %%
es = EarlyStopping(monitor='loss', mode='min', verbose=2, patience=3)

# %%
cvscores_1 = []
for rand_num in rand:
    
    pretrained_model = VGG16(weights='imagenet',include_top=False, input_shape=(64, 64, 3))

    base_model = Model(inputs=pretrained_model.input, outputs=pretrained_model.get_layer('block3_pool').output)

    x_tr = []
    x_te = []

    pa = '/home/jovyan/DATA_MASTER_PROJECT/Check_DIFF_T60_T_97/LEBETALOL_cropped/'
    pp = '/home/jovyan/DATA_MASTER_PROJECT/Check_DIFF_T60_T_97/CONTROLL_cropped/'

    list_dir = pa, pp

    for l_dir in list_dir:

        name = []
        for d, di, file in os.walk(l_dir):
            for i in file:
                name.append(i)


        name =sorted(name)


        well = []
        for i in name:
            well.append(i.split('_id')[0])

        well_name = list(set(well))

        well_name = sorted(well_name)

        l = []
        for ix, _ in enumerate(well_name):
            n = []
            for i in name:
                if well_name[ix] in i:
                    n.append(i)
            l.append(n)


        tot_list = []

        for ix, i in enumerate(l):


            id_n = []
            for j in l[ix]:
                id_n.append(j.split('_time')[0].split('_id_')[1])

            id_name = list(set(id_n))

            l1 = []
            for ixd, _ in enumerate(id_name):
                n1 = []
                for na in l[ix]:
                    if 'id_{}_time'.format(id_name[ixd]) in na:
                        n1.append(na)
                l1.append(n1)

            tot_list.append(l1)




        tra = []
        tes = []

        
        train = []
        test = []
        
        for ie in (range(len(tot_list))):

            f_list = tot_list[ie]

            li = list(range((len(f_list))))

            f, s = train_test_split(li, test_size=0.2, random_state=rand_num )


            for i in f:

                tra.append(f_list[i])

            for j in s:
                tes.append(f_list[j])


        train = [i for sub in tra for i in sub]

        test  = [i for sub in tes for i in sub]

        x_tr.append(train)
        x_te.append(test)

    x_train = [i for sub in x_tr for i in sub]

    x_test = [i for sub in x_te for i in sub]

    x_train = sorted(x_train, key = natural_keys)

    x_test = sorted(x_test, key = natural_keys)

    leb_train = change_name(x_train)

    leb_test = change_name(x_test)

    count_train = return_count(leb_train)

    count_test = return_count(leb_test)

    labels_train = creat_label(count_train)

    labels_test = creat_label(count_test)

    X_train, Y_train = loadImages(list_dir,x_train, labels_train)

    X_test, Y_test = loadImages(list_dir,x_test, labels_test)



    X_train = resize_img(X_train)

    X_test = resize_img(X_test)

    


    X_train = preprocess_input(X_train)

    X_test = preprocess_input(X_test)



    batch_size = 128

    datagen = ImageDataGenerator()

    datagen.fit(X_train)

    train_gen = datagen.flow(X_train, Y_train,batch_size=batch_size )


    m4 = Sequential()
    m4.add(base_model)


    m4.add(BatchNormalization())
    m4.add(GlobalAveragePooling2D())
    m4.add(BatchNormalization())
    m4.add(Activation('relu'))
    m4.add(Dense(64, activation='relu'))

    m4.add(Dense(1,activation='sigmoid'))


    base_model.trainable = False

    opt = keras.optimizers.Adam(lr=1e-5)

    m4.compile(loss= keras.losses.binary_crossentropy, optimizer=opt, metrics = ['accuracy'])

    epochs = 100



    m4_h = m4.fit(train_gen,
                    steps_per_epoch=(len(x_train)/batch_size),
                    epochs=epochs,
                  callbacks = [es],
                 verbose = 1)


    base_model.trainable = True

    opt = keras.optimizers.Adam(lr=1e-5)

    m4.compile(loss= keras.losses.binary_crossentropy, optimizer=opt, metrics = ['accuracy'])

    epochs = 50

    m4_h = m4.fit(train_gen,
                    steps_per_epoch=(len(x_train)/batch_size),
                    epochs=epochs,
                  callbacks = [es],
                 verbose = 1)


    scores = m4.evaluate(X_test, Y_test, verbose = 1)

    cvscores_1.append(scores[1] * 100)
# Out:
# 100%|██████████| 20875/20875 [00:07<00:00, 2701.60it/s]
# 100%|██████████| 20875/20875 [00:13<00:00, 1495.58it/s]
# 100%|██████████| 5588/5588 [00:02<00:00, 2432.65it/s]
# 100%|██████████| 5588/5588 [00:03<00:00, 1532.37it/s]
# 100%|██████████| 20875/20875 [00:04<00:00, 4764.57it/s]
# 100%|██████████| 5588/5588 [00:01<00:00, 4659.09it/s]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 163.0859375 steps
# Epoch 1/100
# 164/163 [==============================] - 7s 43ms/step - loss: 0.7690 - accuracy: 0.4701
# Epoch 2/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.6661 - accuracy: 0.5860
# Epoch 3/100
# 164/163 [==============================] - 4s 23ms/step - loss: 0.6187 - accuracy: 0.6161
# Epoch 4/100
# 164/163 [==============================] - 4s 23ms/step - loss: 0.5871 - accuracy: 0.6359
# Epoch 5/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.5634 - accuracy: 0.6522
# Epoch 6/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.5449 - accuracy: 0.6631
# Epoch 7/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.5300 - accuracy: 0.6740
# Epoch 8/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.5176 - accuracy: 0.6857
# Epoch 9/100
# 164/163 [==============================] - 4s 26ms/step - loss: 0.5071 - accuracy: 0.6967
# Epoch 10/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.4979 - accuracy: 0.7050
# Epoch 11/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.4900 - accuracy: 0.7120
# Epoch 12/100
# 164/163 [==============================] - 4s 26ms/step - loss: 0.4829 - accuracy: 0.7174
# Epoch 13/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.4767 - accuracy: 0.7223
# Epoch 14/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4711 - accuracy: 0.7255
# Epoch 15/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.4662 - accuracy: 0.7278
# Epoch 16/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4617 - accuracy: 0.7308
# Epoch 17/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.4576 - accuracy: 0.7342
# Epoch 18/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.4539 - accuracy: 0.7361
# Epoch 19/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.
100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3649 - accuracy: 0.8203
# Epoch 77/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3639 - accuracy: 0.8214
# Epoch 78/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3629 - accuracy: 0.8217
# Epoch 79/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3619 - accuracy: 0.8231
# Epoch 80/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3609 - accuracy: 0.8240
# Epoch 81/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3599 - accuracy: 0.8245
# Epoch 82/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3590 - accuracy: 0.8252
# Epoch 83/100
# 164/163 [==============================] - 4s 23ms/step - loss: 0.3580 - accuracy: 0.8258
# Epoch 84/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3570 - accuracy: 0.8264
# Epoch 85/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3561 - accuracy: 0.8272
# Epoch 86/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3551 - accuracy: 0.8276
# Epoch 87/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3542 - accuracy: 0.8299
# Epoch 88/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3533 - accuracy: 0.8301
# Epoch 89/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3523 - accuracy: 0.8313
# Epoch 90/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3514 - accuracy: 0.8320
# Epoch 91/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3505 - accuracy: 0.8327
# Epoch 92/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3496 - accuracy: 0.8336
# Epoch 93/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3486 - accuracy: 0.8347
# Epoch 94/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3478 - accuracy: 0.8348
# Epoch 95/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3468 - accuracy: 0.8359
# Epoch 96/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3460 - accuracy: 0.8371
# Epoch 97/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3451 - accuracy: 0.8376
# Epoch 98/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3442 - accuracy: 0.8386
# Epoch 99/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3433 - accuracy: 0.8384
# Epoch 100/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3424 - accuracy: 0.8399
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 163.0859375 steps
# Epoch 1/50
# 164/163 [==============================] - 11s 70ms/step - loss: 0.3007 - accuracy: 0.8696
# Epoch 2/50
# 164/163 [==============================] - 10s 61ms/step - loss: 0.2455 - accuracy: 0.9012
# Epoch 3/50
# 164/163 [==============================] - 10s 62ms/step - loss: 0.2098 - accuracy: 0.9220
# Epoch 4/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.1826 - accuracy: 0.9360
# Epoch 5/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.1594 - accuracy: 0.9480
# Epoch 6/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.1417 - accuracy: 0.9569
# Epoch 7/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.1262 - accuracy: 0.9632
# Epoch 8/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.1126 - accuracy: 0.9691
# Epoch 9/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.1013 - accuracy: 0.9744
# Epoch 10/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0912 - accuracy: 0.9775
# Epoch 11/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0828 - accuracy: 0.9816
# Epoch 12/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0746 - accuracy: 0.9844
# Epoch 13/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0679 - accuracy: 0.9861
# Epoch 14/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0623 - accuracy: 0.9880
# Epoch 15/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0550 - accuracy: 0.9914
# Epoch 16/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0498 - accuracy: 0.9925
# Epoch 17/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0450 - accuracy: 0.9940
# Epoch 18/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0407 - accuracy: 0.9955
# Epoch 19/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0361 - accuracy: 0.9966
# Epoch 20/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0329 - accuracy: 0.9976
# Epoch 21/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0298 - accuracy: 0.9979
# Epoch 22/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0265 - accuracy: 0.9984
# Epoch 23/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0242 - accuracy: 0.9992
# Epoch 24/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0220 - accuracy: 0.9991
# Epoch 25/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0195 - accuracy: 0.9996
# Epoch 26/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0173 - accuracy: 0.9997
# Epoch 27/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0158 - accuracy: 0.9998
# Epoch 28/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0143 - accuracy: 0.9999
# Epoch 29/50
# 164/163 [==============================] - 10s 58ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 30/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0115 - accuracy: 0.9999
# Epoch 31/50
# 164/163 [==============================] - 10s 58ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 32/50
# 164/163 [==============================] - 10s 61ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 33/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch
100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.5276 - accuracy: 0.6718
# Epoch 7/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.5168 - accuracy: 0.6832
# Epoch 8/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.5073 - accuracy: 0.6927
# Epoch 9/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4989 - accuracy: 0.7001
# Epoch 10/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4914 - accuracy: 0.7072
# Epoch 11/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4846 - accuracy: 0.7117
# Epoch 12/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.4785 - accuracy: 0.7175
# Epoch 13/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4730 - accuracy: 0.7205
# Epoch 14/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4681 - accuracy: 0.7241
# Epoch 15/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4635 - accuracy: 0.7291
# Epoch 16/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4593 - accuracy: 0.7325
# Epoch 17/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4554 - accuracy: 0.7356
# Epoch 18/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.4519 - accuracy: 0.7393
# Epoch 19/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4486 - accuracy: 0.7417
# Epoch 20/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4455 - accuracy: 0.7448
# Epoch 21/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.4426 - accuracy: 0.7478
# Epoch 22/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4398 - accuracy: 0.7502 0s - loss: 0.4385 -
# Epoch 23/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4372 - accuracy: 0.7528
# Epoch 24/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.4347 - accuracy: 0.7560
# Epoch 25/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4323 - accuracy: 0.7581
# Epoch 26/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4301 - accuracy: 0.7602
# Epoch 27/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.4279 - accuracy: 0.7625
# Epoch 28/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4257 - accuracy: 0.7643
# Epoch 29/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.4237 - accuracy: 0.7674
# Epoch 30/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4217 - accuracy: 0.7695
# Epoch 31/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.4198 - accuracy: 0.7715
# Epoch 32/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4179 - accuracy: 0.7736
# Epoch 33/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.4161 - accuracy: 0.7748
# Epoch 34/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4143 - accuracy: 0.7762
# Epoch 35/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.4125 - accuracy: 0.7779
# Epoch 36/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4109 - accuracy: 0.7800
# Epoch 37/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.4092 - accuracy: 0.7815
# Epoch 38/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4075 - accuracy: 0.7823
# Epoch 39/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.4059 - accuracy: 0.7851
# Epoch 40/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4044 - accuracy: 0.7860
# Epoch 41/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.4028 - accuracy: 0.7873
# Epoch 42/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.4013 - accuracy: 0.7887
# Epoch 43/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3998 - accuracy: 0.7898 0s - loss: 0.3997 - accu
# Epoch 44/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3983 - accuracy: 0.7914
# Epoch 45/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3969 - accuracy: 0.7933
# Epoch 46/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3954 - accuracy: 0.7943
# Epoch 47/100
# 164/163 [==============================] - 4s 23ms/step - loss: 0.3941 - accuracy: 0.7944
# Epoch 48/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3927 - accuracy: 0.7961
# Epoch 49/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3913 - accuracy: 0.7964
# Epoch 50/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3900 - accuracy: 0.7975
# Epoch 51/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3887 - accuracy: 0.7987
# Epoch 52/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3873 - accuracy: 0.7993
# Epoch 53/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3860 - accuracy: 0.8002
# Epoch 54/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3848 - accuracy: 0.8019
# Epoch 55/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3835 - accuracy: 0.8028
# Epoch 56/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3822 - accuracy: 0.8036
# Epoch 57/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3810 - accuracy: 0.8054
# Epoch 58/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3798 - accuracy: 0.8064
# Epoch 59/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3785 - accuracy: 0.8081
# Epoch 60/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3773 - accuracy: 0.8097
# Epoch 61/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3762 - accuracy: 0.8097
# Epoch 62/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3750 - accuracy: 0.8105
# Epoch 63/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3738 - accuracy: 0.8122
# Epoch 64/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3726 - accuracy: 0.8132
# Epoch 65/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3715 - accuracy: 0.8142
# Epoch 66/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3704 - accuracy: 0.8155
# Epoch 67/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3693 - accuracy: 0.8160
# Epoch 68/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3682 - accuracy: 0.8171
# Epoch 69/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3670 - accuracy: 0.8180
# Epoch 70/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3660 - accuracy: 0.8185
# Epoch 71/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3649 - accuracy: 0.8192
# Epoch 72/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3638 - accuracy: 0.8204
# Epoch 73/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3628 - accuracy: 0.8211
# Epoch 74/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3617 - accuracy: 0.8220
# Epoch 75/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3607 - accuracy: 0.8226
# Epoch 76/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3596 - accuracy: 0.8235
# Epoch 77/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3586 - accuracy: 0.8248
# Epoch 78/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3576 - accuracy: 0.8247
# Epoch 79/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3566 - accuracy: 0.8260
# Epoch 80/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3556 - accuracy: 0.8272
# Epoch 81/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3546 - accuracy: 0.8269
# Epoch 82/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3536 - accuracy: 0.8283
# Epoch 83/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3526 - accuracy: 0.8295
# Epoch 84/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3516 - accuracy: 0.8300
# Epoch 85/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3506 - accuracy: 0.8305
# Epoch 86/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3497 - accuracy: 0.8313
# Epoch 87/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3487 - accuracy: 0.8322
# Epoch 88/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3477 - accuracy: 0.8334
# Epoch 89/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3468 - accuracy: 0.8329
# Epoch 90/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3459 - accuracy: 0.8343
# Epoch 91/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3449 - accuracy: 0.8348
# Epoch 92/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3440 - accuracy: 0.8355
# Epoch 93/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3431 - accuracy: 0.8364
# Epoch 94/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3422 - accuracy: 0.8372
# Epoch 95/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3413 - accuracy: 0.8386
# Epoch 96/100
# 164/163 [==============================] - 4s 25ms/step - loss: 0.3404 - accuracy: 0.8383
# Epoch 97/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3395 - accuracy: 0.8396
# Epoch 98/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3386 - accuracy: 0.8402
# Epoch 99/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3377 - accuracy: 0.8403
# Epoch 100/100
# 164/163 [==============================] - 4s 24ms/step - loss: 0.3368 - accuracy: 0.8418
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 163.875 steps
# Epoch 1/50
# 164/163 [==============================] - 11s 67ms/step - loss: 0.2972 - accuracy: 0.8696
# Epoch 2/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.2446 - accuracy: 0.9043
# Epoch 3/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.2096 - accuracy: 0.9207
# Epoch 4/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.1841 - accuracy: 0.9358
# Epoch 5/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.1615 - accuracy: 0.9469
# Epoch 6/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.1436 - accuracy: 0.9562
# Epoch 7/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.1280 - accuracy: 0.9624
# Epoch 8/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.1150 - accuracy: 0.9688
# Epoch 9/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.1035 - accuracy: 0.9723
# Epoch 10/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0941 - accuracy: 0.9760
# Epoch 11/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0853 - accuracy: 0.9794
# Epoch 12/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0766 - accuracy: 0.9837
# Epoch 13/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0700 - accuracy: 0.9856
# Epoch 14/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0633 - accuracy: 0.9874
# Epoch 15/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0575 - accuracy: 0.9896
# Epoch 16/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0524 - accuracy: 0.9910
# Epoch 17/50
# 164/163 [==============================] - 10s 58ms/step - loss: 0.0474 - accuracy: 0.9925
# Epoch 18/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0439 - accuracy: 0.9940
# Epoch 19/50
# 164/163 [==============================] - 10s 58ms/step - loss: 0.0395 - accuracy: 0.9954
# Epoch 20/50
# 164/163 [==============================] - 10s 61ms/step - loss: 0.0363 - accuracy: 0.9960
# Epoch 21/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0324 - accuracy: 0.9973
# Epoch 22/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0292 - accuracy: 0.9981
# Epoch 23/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0264 - accuracy: 0.9987
# Epoch 24/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0240 - accuracy: 0.9989
# Epoch 25/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0216 - accuracy: 0.9993
# Epoch 26/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0197 - accuracy: 0.9996
# Epoch 27/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0180 - accuracy: 0.9996
# Epoch 28/50
# 164/163 [==============================] - 10s 58ms/step - loss: 0.0161 - accuracy: 0.9999
# Epoch 29/50
# 164/163 [==============================] - 10s 58ms/step - loss: 0.0144 - accuracy: 0.9998
# Epoch 30/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 31/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 32/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 33/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0101 - accuracy: 0.9999
# Epoch 34/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 35/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 36/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 37/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 38/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 39/50
# 164/163 [==============================] - 10s 60ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 40/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 41/50
# 164/163 [==============================] - 10s 58ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 42/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 43/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 44/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 45/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 46/50
# 164/163 [==============================] - 10s 58ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 47/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 48/50
# 164/163 [==============================] - 10s 59ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 49/50
# ...
# Epoch 19/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4533 - accuracy: 0.7349
# Epoch 20/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4502 - accuracy: 0.7382
# Epoch 21/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4474 - accuracy: 0.7405
# Epoch 22/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4447 - accuracy: 0.7428
# Epoch 23/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4421 - accuracy: 0.7447
# Epoch 24/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.4397 - accuracy: 0.7475
# Epoch 25/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4373 - accuracy: 0.7508
# Epoch 26/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4350 - accuracy: 0.7528
# Epoch 27/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4329 - accuracy: 0.7549
# Epoch 28/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4308 - accuracy: 0.7565
# Epoch 29/100
# 166/165 [==============================] - 4s 23ms/step - loss: 0.4287 - accuracy: 0.7586
# Epoch 30/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4267 - accuracy: 0.7606
# Epoch 31/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.4248 - accuracy: 0.7621
# Epoch 32/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4228 - accuracy: 0.7635
# Epoch 33/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.4210 - accuracy: 0.7655
# Epoch 34/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4192 - accuracy: 0.7677
# Epoch 35/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4174 - accuracy: 0.7690
# Epoch 36/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4157 - accuracy: 0.7712
# Epoch 37/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4139 - accuracy: 0.7737
# Epoch 38/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4123 - accuracy: 0.7753
# Epoch 39/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.4106 - accuracy: 0.7772
# Epoch 40/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4090 - accuracy: 0.7789 0s - loss: 0.4087 - accuracy:
# Epoch 41/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.4074 - accuracy: 0.7803
# Epoch 42/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.4058 - accuracy: 0.7822
# Epoch 43/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4043 - accuracy: 0.7840
# Epoch 44/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4028 - accuracy: 0.7857
# Epoch 45/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.4013 - accuracy: 0.7872
# Epoch 46/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3998 - accuracy: 0.7891
# Epoch 47/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3983 - accuracy: 0.7897
# Epoch 48/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3969 - accuracy: 0.7913
# Epoch 49/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.3955 - accuracy: 0.7921
# Epoch 50/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3940 - accuracy: 0.7939
# Epoch 51/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3927 - accuracy: 0.7948
# Epoch 52/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3913 - accuracy: 0.7955
# Epoch 53/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3899 - accuracy: 0.7978
# Epoch 54/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.3886 - accuracy: 0.7993
# Epoch 55/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3873 - accuracy: 0.8006
# Epoch 56/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.3860 - accuracy: 0.8019
# Epoch 57/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3847 - accuracy: 0.8024
# Epoch 58/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.3834 - accuracy: 0.8039
# Epoch 59/100
# 166/165 [==============================] - 4s 23ms/step - loss: 0.3821 - accuracy: 0.8051
# Epoch 60/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.3808 - accuracy: 0.8056
# Epoch 61/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3796 - accuracy: 0.8065
# Epoch 62/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.3783 - accuracy: 0.8077
# Epoch 63/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3771 - accuracy: 0.8090
# Epoch 64/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.3759 - accuracy: 0.8099
# Epoch 65/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3746 - accuracy: 0.8110
# Epoch 66/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3735 - accuracy: 0.8112
# Epoch 67/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3722 - accuracy: 0.8126
# Epoch 68/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.3711 - accuracy: 0.8136
# Epoch 69/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3699 - accuracy: 0.8142
# Epoch 70/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3687 - accuracy: 0.8157
# Epoch 71/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.3676 - accuracy: 0.8160
# Epoch 72/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.3664 - accuracy: 0.8167
# Epoch 73/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3653 - accuracy: 0.8177
# Epoch 74/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3642 - accuracy: 0.8186
# Epoch 75/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3630 - accuracy: 0.8190
# Epoch 76/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.3620 - accuracy: 0.8200
# Epoch 77/100
# 166/165 [==============================] - 4s 23ms/step - loss: 0.3608 - accuracy: 0.8211
# Epoch 78/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3597 - accuracy: 0.8220
# Epoch 79/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.3586 - accuracy: 0.8226
# Epoch 80/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3576 - accuracy: 0.8241
# Epoch 81/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.3565 - accuracy: 0.8248 0s - loss: 0.3571 - accuracy:
# Epoch 82/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.3554 - accuracy: 0.8264
# Epoch 83/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3544 - accuracy: 0.8268
# Epoch 84/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3533 - accuracy: 0.8282
# Epoch 85/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3523 - accuracy: 0.8286
# Epoch 86/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3512 - accuracy: 0.8303
# Epoch 87/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3502 - accuracy: 0.8308
# Epoch 88/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3491 - accuracy: 0.8320
# Epoch 89/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3481 - accuracy: 0.8331
# Epoch 90/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3471 - accuracy: 0.8337
# Epoch 91/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3461 - accuracy: 0.8345
# Epoch 92/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3451 - accuracy: 0.8353
# Epoch 93/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.3441 - accuracy: 0.8364
# Epoch 94/100
# 166/165 [==============================] - 4s 23ms/step - loss: 0.3431 - accuracy: 0.8374
# Epoch 95/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3421 - accuracy: 0.8388
# Epoch 96/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3411 - accuracy: 0.8398
# Epoch 97/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3401 - accuracy: 0.8404
# Epoch 98/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3391 - accuracy: 0.8413
# Epoch 99/100
# 166/165 [==============================] - 4s 24ms/step - loss: 0.3382 - accuracy: 0.8418
# Epoch 100/100
# 166/165 [==============================] - 4s 25ms/step - loss: 0.3372 - accuracy: 0.8425
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 165.53125 steps
# Epoch 1/50
# 166/165 [==============================] - 11s 66ms/step - loss: 0.2970 - accuracy: 0.8738
# Epoch 2/50
# 166/165 [==============================] - 10s 59ms/step - loss: 0.2405 - accuracy: 0.9090
# Epoch 3/50
# 166/165 [==============================] - 10s 58ms/step - loss: 0.2027 - accuracy: 0.9281
# Epoch 4/50
# 166/165 [==============================] - 10s 59ms/step - loss: 0.1748 - accuracy: 0.9431
# Epoch 5/50
# 166/165 [==============================] - 10s 58ms/step - loss: 0.1531 - accuracy: 0.9520
# Epoch 6/50
# 166/165 [==============================] - 10s 59ms/step - loss: 0.1348 - accuracy: 0.9602
# Epoch 7/50
# 166/165 [==============================] - 10s 59ms/step - loss: 0.1208 - accuracy: 0.9664
# Epoch 8/50
# 166/165 [==============================] - 10s 59ms/step - loss: 0.1081 - accuracy: 0.9710
# Epoch 9/50
# 166/165 [==============================] - 10s 59ms/step - loss: 0.0971 - accuracy: 0.9767
# Epoch 10/50
# 166/165 [==============================] - 10s 59ms/step - loss: 0.0871 - accuracy: 0.9798
# Epoch 11/50
# 166/165 [==============================] - 10s 60ms/step - loss: 0.0790 - accuracy: 0.9830
# Epoch 12/50
# 166/165 [==============================] - 10s 61ms/step - loss: 0.0718 - accuracy: 0.9862
# Epoch 13/50
# 166/165 [==============================] - 10s 59ms/step - loss: 0.0644 - accuracy: 0.9883
# Epoch 14/50
# 166/165 [==============================] - 10s 60ms/step - loss: 0.0580 - accuracy: 0.9903
# Epoch 15/50
# 166/165 [==============================] - 10s 60ms/step - loss: 0.0532 - accuracy: 0.9911
# Epoch 16/50
# 166/165 [==============================] - 10s 59ms/step - loss: 0.0479 - accuracy: 0.9935
# Epoch 17/50
# 166/165 [==============================] - 10s 59ms/step - loss: 0.0430 - accuracy: 0.9949
# Epoch 18/50
# 166/165 [==============================] - 10s 59ms/step - loss: 0.0389 - accuracy: 0.9964
# Epoch 19/50
# 166/165 [==============================] - 10s 59ms/step - loss: 0.0354 - accuracy: 0.9966
# Epoch 20/50
# 166/165 [==============================] - 10s 60ms/step - loss: 0.0323 - accuracy: 0.9970
# Epoch 21/50
# 166/165 [==============================] - 10s 59ms/step - loss: 0.0287 - accuracy: 0.9981
# Epoch 22/50
# 166/165 [==============================] - 10s 59ms/step - loss: 0.0259 - accuracy: 0.9988
# Epoch 23/50
# 166/165 [==============================] - 10s 58ms/step - loss: 0.0236 - accuracy: 0.9991
# Epoch 24/50
# 166/165 [==============================] - 10s 59ms/step - loss: 0.0210 - accuracy: 0.9992
# Epoch 25/50
# 166/165 [==============================] - 10s 60ms/step - loss: 0.0194 - accuracy: 0.9994
# Epoch 26/50
# 166/165 [==============================] - 10s 59ms/step - loss: 0.0172 - accuracy: 0.9997
# Epoch 27/50
# 166/165 [==============================] - 10s 59ms/step - loss: 0.0157 - accuracy: 0.9997
# Epoch 28/50
# 166/165 [==============================] - 10s 58ms/step - loss: 0.0144 - accuracy: 0.9999
# Epoch 29/50
# 166/165 [==============================] - 10s 60ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 30/50
# 118/165 [====================>.........] - ETA: 2s - loss: 0.0114 - accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-968d8b66f5af> in <module>
#     187                     epochs=epochs,
#     188                   callbacks = [es],
# --> 189                  verbose = 1)
#     190
#     191
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     566
#     567   return pack_sequence_as(
# --> 568       structure[0], [func(*x) for x in entries],
#     569       expand_composites=expand_composites)
#     570
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/util/nest.py in <listcomp>(.0)
#     566
#     567   return pack_sequence_as(
# --> 568       structure[0], [func(*x) for x in entries],
#     569       expand_composites=expand_composites)
#     570
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in _non_none_constant_value(v)
#     128
#     129 def _non_none_constant_value(v):
# --> 130   constant_value = tensor_util.constant_value(v)
#     131   return constant_value if constant_value is not None else v
#     132
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/tensor_util.py in constant_value(tensor, partial)
#     820   """
#     821   if isinstance(tensor, ops.EagerTensor):
# --> 822     return tensor.numpy()
#     823   if not is_tensor(tensor):
#     824     return tensor
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py in numpy(self)
#     940     """
#     941     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 942     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     943     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     944
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py in _numpy(self)
#     906     # pylint: disable=protected-access
#     907     try:
# --> 908       return self._numpy_internal()
#     909     except core._NotOkStatusException as e:
#     910       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:

# %%
cvscores_1

# %%
        
        
        

#plot_history(m4_h, 'first')
test_preds = m4.predict(X_test)

t= []
for i in (test_preds):
    if i > 0.5:
        t.append(1)
    else:
        t.append(0)

draw_confusion_matrix(Y_test, t)

# %%
print(classification_report(Y_test, t))
