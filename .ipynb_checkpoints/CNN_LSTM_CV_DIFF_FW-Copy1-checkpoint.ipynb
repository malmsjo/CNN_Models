# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten, LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv2D, Conv3D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.losses import binary_crossentropy
from sklearn.metrics import f1_score
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras import backend as K
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image 
import seaborn as sns
import os
import re
import glob
import cv2
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
from sklearn.model_selection import StratifiedKFold
from sklearn import preprocessing
import tqdm
from numpy import loadtxt
from os import *
from sklearn.utils import class_weight
# Out:
# Using TensorFlow backend.

# %%
def atoi(text):
    return int(text) if text.isdigit() else text
def natural_keys(text):
    return [atoi(c) for c in re.split('(\d+)', text)]

# %%
def draw_confusion_matrix(true,preds):
    conf_matx = confusion_matrix(true, preds)
    sns.heatmap(conf_matx, annot=True,annot_kws={"size": 12},fmt='g', cbar=False, cmap=plt.cm.Blues) #'viridis'
    #plt.savefig('/home/jovyan/conf_matrix.png')
    plt.show()
    
    return conf_matx

# %%
def plot_history(model_history, model_name):
    fig = plt.figure(figsize=(15,5), facecolor='w')
    ax = fig.add_subplot(121)
    ax.plot(model_history.history['loss'])
    ax.plot(model_history.history['val_loss'])
    ax.set(title=model_name + ': Model loss', ylabel='Loss', xlabel='Epoch')
    ax.legend(['Train', 'Val'], loc='upper left')
    ax = fig.add_subplot(122)
    ax.plot(model_history.history['accuracy'])
    ax.plot(model_history.history['val_accuracy'])
    ax.set(title=model_name + ': Model Accuracy; test='+ str(np.round(model_history.history['val_accuracy'][-1], 3)),
           ylabel='Accuracy', xlabel='Epoch')
    ax.legend(['Train', 'Val'], loc='upper left')
    #plt.savefig('/home/jovyan/curve.png')
    plt.show()
    
    return fig

# %%
def resize(x):
    rescaled = []

    for i in x:

        scale_percent = 140 # percent of original size
        width = int(i.shape[1] / (scale_percent / 100))
        height = int(i.shape[0] / (scale_percent / 100))
        dim = (width, height)
        resized = cv2.resize(i, dim, interpolation = cv2.INTER_LANCZOS4)
        rescaled.append(resized)

    x_orig = np.reshape( rescaled, (len( rescaled), resized.shape[1], resized.shape[1], 3))

    return x_orig

# %%
def loadImages(path_data):
    
    p = '/home/jovyan/DATA_MASTER_PROJECT/IMG_A549_high_con/'
    
    
    
    pa_adr = p + 'ADR_cropped/'
    
    pa_control = p + 'CONTROL_cropped/'
    
    pa_hrh = p + 'HRH_cropped/'
    
    pa_dmso = p + 'DMSO_cropped/'
    
    image_list = []
    
    
       


    for filename in sorted(path_data, key=natural_keys): 
        
        if 'adr' in filename:
            
            im=cv2.imread(pa_adr + filename)

            imarray = np.array(im)
            

            image_list.append(imarray)
            
        if 'control' in filename:
            
            im=cv2.imread(pa_control + filename)

            imarray = np.array(im)
            

            image_list.append(imarray)
            
        if 'hrh' in filename:
            
            im=cv2.imread(pa_hrh + filename)

            imarray = np.array(im)
            

            image_list.append(imarray)
            
        if 'dmso' in filename:
            
            im=cv2.imread(pa_dmso + filename)

            imarray = np.array(im)
            

            image_list.append(imarray)



    x_orig = np.reshape(image_list, (len(image_list), 90, 90, 3))

    return x_orig

# %%
def return_count(x):
    name_wel = []
    for i in sorted(x, key = natural_keys):
        name_wel.append(i.split('_')[0])

    z = sorted(list(set(name_wel)))
    r = list(range(len(z)))

    num = []
    for iz in range(len(z)):
        count = 0
        for i in sorted(x, key=natural_keys):
            if z[iz] in i:
                count += 1
        num.append(count)
    return list(zip(z, r, num))

# %%
def loadImages_LSTM(path_data,len_t_points):
    

    feat_list = []


    for filename in sorted(glob.glob(path_data), key=natural_keys): 
        feat_list.append(np.load(filename))

    x_orig = np.reshape(feat_list, (len(feat_list),len_t_points, 64))

    return x_orig

# %%
def make_labels(data_set):
    fe = return_count(data_set)
    leb = creat_label(fe)
    y = np.array(list(leb))
    return y

# %%
def make_labels_LSTM(data_set):
    fe = return_count_LSTM(data_set)
    leb = creat_label(fe)
    y = np.array(list(leb))
    return y

# %%
def return_count_LSTM(x):
    name_wel = []
    for _,_,i in os.walk(x):
        for f in i:
            name_wel.append(f.split('_')[2])

    z = sorted(list(set(name_wel)), key=natural_keys)
    r = list(range(len(z)))

    num = []
    for iz in range(len(z)):
        count = 0
        for i in sorted(name_wel, key=natural_keys):
            if z[iz] in i:
                count += 1
        num.append(count)
    return list(zip(z, r, num))

# %%
def creat_label(y):
    labels = []
    for ix, _ in enumerate(y):
        
        if y[ix][0] == 'adr':
        
            labels.append([[y[ix][0],0]] * y[ix][2])
        
        if y[ix][0] == 'hrh':
            
            labels.append([[y[ix][0],1]] * y[ix][2])
        
        if y[ix][0] == 'control':
            
            labels.append([[y[ix][0],1]] * y[ix][2])
            
        if y[ix][0] == 'dmso':
            
            labels.append([[y[ix][0],1]] * y[ix][2])
    
    ler = [i for sub in labels for i in sub ]
    
    _, lab= zip(*ler)

    
    return lab

# %%
def time_step_acc(tes_data, x):

    results = []            

    x_test = loadImages(tes_data)
    y_test = make_labels(tes_data)
    x_test = resize(x_test)
    x_test = preprocess_input(x_test)

    scores = x.evaluate(x_test, y_test, verbose = 1)
    results.append(scores[1]*100)

    return results

# %%
def cv_mean_acc(result_cv, string_well):
    
    l_drug = string_well*3

    acc_mean_cv = []

    for i in result_cv:
        acc_mean_cv.append(np.mean(i))
        
    cv_drug = list(zip(acc_mean_cv, l_drug))
    
    res = sorted(cv_drug, key = lambda x: x[1])
    a , b = zip(*res)
    
    a = list(a)
    
    s = list(np.array_split(a, len(string_well)))
    
    cv_score_acc = []
    
    for ix, i in enumerate(s):
        s1 = list(s[ix])
        
        cv_score_acc.append(np.mean(s1))
        
    return list(zip(cv_score_acc, string_well))

# %%
# DATA FOR LSTM PART

p_feat = '/home/jovyan/DATA_MASTER_PROJECT/LSTM/FEAT_FOLDERS/'
train_data = p_feat + 'features_train/*.npy'
val_data = p_feat + 'features_validation/*.npy'
tes_data= p_feat + 'features_test/*.npy'

y_tra_path = '/home/jovyan/DATA_MASTER_PROJECT/LSTM/FEAT_FOLDERS/features_train/'
y_tes_path = '/home/jovyan/DATA_MASTER_PROJECT/LSTM/FEAT_FOLDERS/features_test/'
y_val_path = '/home/jovyan/DATA_MASTER_PROJECT/LSTM/FEAT_FOLDERS/features_validation/'

# %%
met = ['F10']
mid = ['D5']
oxy = ['F6']
nap = ['B3']
dip = ['F2']
met_1 = ['B7']
lab = ['D10']
car = ['G2']
mep = ['B11']
nef = ['C10']
tri = ['B2']
dox = ['F8']


cycl = ['C4']
dime =  ['F7']
cypr  = ['G9']
lora = [ 'E5']
doxy = ['D4']
oloa = ['E2']
hydr = ['F5']
orph = ['E7']
cinn = ['B10']
desl = ['F3']
chlo =  ['D2']
trim = ['E9']
mian= ['E8']
fexo= ['B5']
chlo_1 = ['E3']
trip= ['C5']
desi= ['E4']
levo= ['C3']
diphe_1= ['C7']
diphe_2= ['F11']
emed= ['G6']
ceti= ['D11']
trip_1= ['F9']
doxe=['C2']
chlo_2= ['D6']
flun = ['C9']
keto= ['D7']

# %%
tot_results_accuracy = []

results_lstm = []

# %%
tot_well_adr = [met,mid,oxy,nap,dip,met_1,lab,car,mep,nef,tri,dox]
tot_well_hrh = [cycl, dime, cypr,lora,doxy,oloa,cinn,desl,chlo,trim,mian,fexo,chlo_1,trip,desi,levo,
                
                diphe_1,diphe_2,emed,ceti,trip_1,doxe,chlo_2,flun,keto]

string_well_adr = ['met', 'mid', 'oxy', 'nap', 'dip','met_1','lab','car','mep','nef','tri','dox']
string_well_hrh = ['cycl', 'dime', 'cypr', 'lora', 'doxy','oloa','cinn','desl','chlo','trim','mian','fexo','chlo_1','trip','desi',
                  'levo','diphe_1','diphe_2','emed','ceti','trip_1','doxe','chlo_2','flun','keto']

# %%
tot_well = []
string_well = []

# %%
a = 'HRH' # FOR TEST SET
b = 'ADR' # FOR REST

if a == 'HRH':
    tot_well = tot_well_hrh
    string_well = string_well_hrh
    
if a == 'ADR':
    tot_well = tot_well_adr
    string_well = string_well_adr

# %%
rand = list(np.random.randint(1,1000,3))

# %%
for num_ix, rand_num in enumerate(rand):
    for index_t_well, _ in tqdm.tqdm(enumerate(tot_well)):

        time_points = list(map(str, range(1,34)))

        new_time = []
        for i in time_points:
            r = '_' + i + '.'
            new_time.append(r)



        path_test = '/home/jovyan/DATA_MASTER_PROJECT/IMG_A549_high_con/{}_cropped/'.format(a)

        # NAME OF THE WELLS CORRESPONDING TO THE DRUG THAT YOU WANT IN THE TEST SET 

        wells_drug = [tot_well[index_t_well][0]] 

        test = []

        for _,_, filenames in os.walk(path_test):

            for filename in sorted(filenames, key = natural_keys):

                for w in wells_drug:
                    for t in new_time:
                        if '{}'.format(w) in filename and '{}tiff'.format(t) in filename:
                            test.append(filename)

        groups_list = ['{}'.format(a), '{}'.format(b)]

        fileds_of_view = ['1','2','3','4','5']

        field_train, field_val = train_test_split(fileds_of_view, test_size=0.2, random_state=rand_num)


        train = []

        validation = []

        group_compounds = []

        for group in tqdm.tqdm(groups_list):

            pa = '/home/jovyan/DATA_MASTER_PROJECT/IMG_A549_high_con/{}_cropped/'.format(group)

            for _,_, filenames in os.walk(pa):

                for filename in sorted(filenames, key = natural_keys):

                    for t in new_time:

                        if '_{}-'.format(wells_drug[0]) not in filename  and '{}tiff'.format(t) in filename:

                            group_compounds.append(filename)






        for i in group_compounds:

            for f in field_train:
                if '-{}_'.format(f) in i:
                    train.append(i)


            for v in field_val:
                if '-{}_'.format(v) in i:
                    validation.append(i)


        x_train = loadImages(train)
        y_train = make_labels(train)



        x_val = loadImages(validation)
        y_val = make_labels(validation)



        x_train = resize(x_train)


        x_val = resize(x_val)


        weights = class_weight.compute_class_weight('balanced', np.unique(y_train),y_train)


        x_train = preprocess_input(x_train)

        x_val = preprocess_input(x_val)


        es = EarlyStopping(monitor='val_loss', mode='min', verbose=2, patience=3)

        pretrained_model = VGG16(weights='imagenet',include_top=False, input_shape=(64, 64, 3))

        base_model = Model(inputs=pretrained_model.input, outputs=pretrained_model.get_layer('block3_pool').output)

        batch_size = 512

        datagen = ImageDataGenerator()

        datagen.fit(x_train)

        train_gen = datagen.flow(x_train, y_train,batch_size=batch_size )

        dat_val = ImageDataGenerator()

        dat_val.fit(x_val)

        val_gen = dat_val.flow(x_val, y_val,batch_size=batch_size)

        m4 = Sequential()
        m4.add(base_model)


        m4.add(BatchNormalization())
        m4.add(GlobalAveragePooling2D())
        m4.add(Dense(64, activation='relu'))
        m4.add(BatchNormalization())
        m4.add(Activation('relu'))
        m4.add(Dense(1,activation='sigmoid'))


        base_model.trainable = False

        opt = keras.optimizers.Adam(lr=1e-3)

        m4.compile(loss= keras.losses.binary_crossentropy, optimizer=opt, metrics = ['accuracy'])



        epochs = 300

        m4_h = m4.fit(train_gen,
                        steps_per_epoch=(len(x_train)/batch_size),
                        callbacks = [es],
                        epochs=epochs,
                        validation_data = (val_gen), 
                        validation_steps = (len(x_val)/batch_size),
                        class_weight = weights,
                         verbose = 1)

        base_model.trainable = True

        opt = keras.optimizers.Adam(lr=1e-4)

        m4.compile(loss= keras.losses.binary_crossentropy, optimizer=opt, metrics = ['accuracy'])

        epochs = 300

        m4_h = m4.fit(train_gen,
                        steps_per_epoch=(len(x_train)/batch_size),
                        callbacks = [es],
                        epochs=epochs,
                        validation_data = val_gen, 
                        validation_steps = (len(x_val)/batch_size),
                        class_weight = weights,
                        verbose = 1)

        l = []
        for t in new_time:
            for i in test:
                if t in i:
                    l.append((i))


        grouped = {}
        for elem in l:
            key = elem.split('.tiff')[0].split('_')[5]
            grouped.setdefault(key, []).append(elem)
        grouped = grouped.values()

        test_data = list(grouped)

        r = []

        for ix ,_ in enumerate(test_data):
            r.append(time_step_acc(test_data[ix],m4))

        plt.plot(time_points,r)
        plt.savefig('/home/jovyan/IMG_CNN_FINAL/{}_accuracy.png'.format(string_well[index_t_well]))

        tot_results_accuracy.append(r)
        
        for i, layer in enumerate(m4.layers):
            layer._name = 'layer_' + str(i)



        lstm_model = Model(inputs=m4.input, outputs=m4.get_layer('layer_4').output)

        del m4
        K.clear_session()
        
        data_name = [train,test,validation]

        feat_name = ['train', 'test', 'validation']

        for index_name, _ in enumerate(data_name):

            path =  data_name[index_name]

            name_well = []

            for i in path:
                name_well.append(i.split('_id')[0])

            wells = list(set(name_well))
            wells

            for w in wells:

                time = []


                for filename in sorted(path, key = natural_keys):
                    if w in filename: #PAY ATTENTION ID THE IMAGE IS A TIFF OR PNG IMAGE #########
                        time.append(filename)

                data_id = {}
                n_id = []
                w_n = []

                for i in time:
                    t = i.split('_id_')[1].split('time_')[0]
                    f = i.split('_id_')[0].split('time_')[0]
                    n_id.append(t)
                    w_n.append(f)

                id_cell = set(n_id)


                for ix, i in enumerate(sorted(id_cell, key = natural_keys)):

                    id_name = []
                    dict_1 = {}

                    for t in time:
                        if 'id_{}'.format(i) in t:
                            id_name.append(t)

                    d = {'id':id_name}
                    data = pd.DataFrame(d)

                    dict_1[ix]=data 
                    data_id.update(dict_1) 

                delete = [i for i, j in data_id.items() if len(j) < len(time_points)] # 9 or the length of time span you are traning on 
                for i in delete : del data_id[i]

                len_id = [i for i, j in data_id.items()]

                for le in len_id:    


                    e = pd.DataFrame(data_id[le])

                    coords = e.values.tolist()
                    id_cells = []
                    for i in coords:
                        for j in i:
                            id_cells.append(j)

                    x_orig = loadImages(id_cells)
                    x_orig = resize(x_orig)

                    x_orig = preprocess_input(x_orig)
                    output = lstm_model.predict(x_orig)
                    np.save('/home/jovyan/DATA_MASTER_PROJECT/LSTM//FEAT_FOLDERS/features_{}/features_well_{}_id_{}.npy'.format(feat_name[index_name],w_n[0], le), output)
            print('Saved_feature_{}'.format(feat_name[index_name]))


        x_train_lstm = loadImages_LSTM(train_data, len(time_points))
        y_train_lstm = make_labels_LSTM(y_tra_path)

        x_test_lstm = loadImages_LSTM(tes_data, len(time_points))
        y_test_lstm = make_labels_LSTM(y_tes_path)

        x_val_lstm = loadImages_LSTM(val_data, len(time_points))
        y_val_lstm = make_labels_LSTM(y_val_path)

        weights_lstm = class_weight.compute_class_weight('balanced', np.unique(y_train_lstm),y_train_lstm)


        m = Sequential()
        m.add(LSTM(32, input_shape = (x_train_lstm.shape[1],x_train_lstm.shape[2])))
        m.add(Dropout(0.2))
        m.add(Dense(1, activation='sigmoid'))


        opt_lstm = keras.optimizers.Adam(lr=1e-4)

        m.compile(loss= keras.losses.binary_crossentropy, optimizer=opt, metrics = ['accuracy'])

        epochs = 300

        m_h = m.fit(x_train_lstm,y_train_lstm,

                         callbacks = [es],

                        epochs=epochs,
                        validation_data = (x_val_lstm,y_val_lstm), 

                        class_weight = weights_lstm)


        scores_lstm = m.evaluate(x_test_lstm, y_test_lstm)
        results_lstm.append([scores_lstm[1]*100, string_well[index_t_well]])
        
        del m
        K.clear_session()

        # DELITE FILES IN FEATURE VECTOR FOLDERS

        folders = glob.glob('/home/jovyan/DATA_MASTER_PROJECT/LSTM/FEAT_FOLDERS/*')

        for fo in folders:
            file = glob.glob(f'{fo}/*')
            for f in file:
                os.remove(f)
# Out:
# 0it [00:00, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:03<00:03,  3.61s/it]
# 100%|██████████| 2/2 [00:05<00:00,  2.61s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 232.857421875 steps, validate for 61.69140625 steps
# Epoch 1/300
# 233/232 [==============================] - 29s 125ms/step - loss: 0.6103 - accuracy: 0.6689 - val_loss: 0.6285 - val_accuracy: 0.6820
# Epoch 2/300
# 233/232 [==============================] - 24s 104ms/step - loss: 0.5680 - accuracy: 0.7019 - val_loss: 0.6247 - val_accuracy: 0.6822
# Epoch 3/300
# 233/232 [==============================] - 25s 106ms/step - loss: 0.5437 - accuracy: 0.7197 - val_loss: 0.6458 - val_accuracy: 0.6737
# Epoch 4/300
# 233/232 [==============================] - 24s 105ms/step - loss: 0.5215 - accuracy: 0.7359 - val_loss: 0.6594 - val_accuracy: 0.6579
# Epoch 5/300
# 233/232 [==============================] - 25s 107ms/step - loss: 0.5025 - accuracy: 0.7503 - val_loss: 0.6878 - val_accuracy: 0.6402
# Epoch 00005: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 232.857421875 steps, validate for 61.69140625 steps
# Epoch 1/300
# 233/232 [==============================] - 60s 259ms/step - loss: 0.4820 - accuracy: 0.7644 - val_loss: 0.8098 - val_accuracy: 0.6534
# Epoch 2/300
# 233/232 [==============================] - 58s 249ms/step - loss: 0.4214 - accuracy: 0.8051 - val_loss: 0.7237 - val_accuracy: 0.6287
# Epoch 3/300
# 233/232 [==============================] - 58s 249ms/step - loss: 0.3749 - accuracy: 0.8338 - val_loss: 0.8070 - val_accuracy: 0.6455
# Epoch 4/300
# 233/232 [==============================] - 57s 244ms/step - loss: 0.3334 - accuracy: 0.8583 - val_loss: 0.9861 - val_accuracy: 0.5206
# Epoch 5/300
# 233/232 [==============================] - 58s 249ms/step - loss: 0.2972 - accuracy: 0.8794 - val_loss: 1.0039 - val_accuracy: 0.5525
# Epoch 00005: early stopping
# 202/202 [==============================] - 0s 2ms/sample - loss: 0.7183 - accuracy: 0.6188
# 196/196 [==============================] - 0s 604us/sample - loss: 0.7590 - accuracy: 0.6173
# 193/193 [==============================] - 0s 589us/sample - loss: 0.7491 - accuracy: 0.6010
# 190/190 [==============================] - 0s 916us/sample - loss: 0.7115 - accuracy: 0.6053
# 190/190 [==============================] - 0s 214us/sample - loss: 0.6536 - accuracy: 0.6579
# 187/187 [==============================] - 0s 741us/sample - loss: 0.6565 - accuracy: 0.6791
# 184/184 [==============================] - 0s 692us/sample - loss: 0.5989 - accuracy: 0.7120
# 183/183 [==============================] - 0s 692us/sample - loss: 0.6340 - accuracy: 0.7104
# 182/182 [==============================] - 0s 724us/sample - loss: 0.6975 - accuracy: 0.6593
# 181/181 [==============================] - 0s 713us/sample - loss: 0.7233 - accuracy: 0.6409
# 177/177 [==============================] - 0s 701us/sample - loss: 0.6667 - accuracy: 0.6836
# 178/178 [==============================] - 0s 701us/sample - loss: 0.6074 - accuracy: 0.7191
# 178/178 [==============================] - 0s 241us/sample - loss: 0.6173 - accuracy: 0.7191
# 176/176 [==============================] - 0s 728us/sample - loss: 0.6770 - accuracy: 0.6818
# 175/175 [==============================] - 0s 716us/sample - loss: 0.5915 - accuracy: 0.7086
# 176/176 [==============================] - 0s 243us/sample - loss: 0.6121 - accuracy: 0.6932
# 173/173 [==============================] - 0s 712us/sample - loss: 0.6225 - accuracy: 0.7399
# 172/172 [==============================] - 0s 708us/sample - loss: 0.6660 - accuracy: 0.6919
# 171/171 [==============================] - 0s 702us/sample - loss: 0.6763 - accuracy: 0.7018
# 171/171 [==============================] - 0s 217us/sample - loss: 0.5790 - accuracy: 0.7368
# 171/171 [==============================] - 0s 211us/sample - loss: 0.4679 - accuracy: 0.7953
# 170/170 [==============================] - 0s 238us/sample - loss: 0.6303 - accuracy: 0.7059
# 171/171 [==============================] - 0s 224us/sample - loss: 0.5575 - accuracy: 0.7485
# 170/170 [==============================] - 0s 240us/sample - loss: 0.6267 - accuracy: 0.7059
# 170/170 [==============================] - 0s 225us/sample - loss: 0.6290 - accuracy: 0.7000
# 171/171 [==============================] - 0s 267us/sample - loss: 0.5908 - accuracy: 0.7076
# 168/168 [==============================] - 0s 738us/sample - loss: 0.5283 - accuracy: 0.7321
# 169/169 [==============================] - 0s 711us/sample - loss: 0.6402 - accuracy: 0.6864
# 169/169 [==============================] - 0s 255us/sample - loss: 0.6589 - accuracy: 0.6982
# 167/167 [==============================] - 0s 692us/sample - loss: 0.6597 - accuracy: 0.7186
# 168/168 [==============================] - 0s 252us/sample - loss: 0.5245 - accuracy: 0.7440
# 169/169 [==============================] - 0s 244us/sample - loss: 0.5924 - accuracy: 0.7396
# 166/166 [==============================] - 0s 666us/sample - loss: 0.6248 - accuracy: 0.7289
# Saved_feature_train
# Saved_feature_test
# Saved_feature_validation
# Train on 3167 samples, validate on 834 samples
# Epoch 1/300
# 3167/3167 [==============================] - 3s 827us/sample - loss: 0.5877 - accuracy: 0.6865 - val_loss: 0.6148 - val_accuracy: 0.6655
# Epoch 2/300
# 3167/3167 [==============================] - 1s 244us/sample - loss: 0.4623 - accuracy: 0.7944 - val_loss: 0.6180 - val_accuracy: 0.6727
# Epoch 3/300
# 3167/3167 [==============================] - 1s 247us/sample - loss: 0.3566 - accuracy: 0.8715 - val_loss: 0.6519 - val_accuracy: 0.6559
# Epoch 4/300
# 3167/3167 [==============================] - 1s 237us/sample - loss: 0.2561 - accuracy: 0.9211 - val_loss: 0.7302 - val_accuracy: 0.6343
# Epoch 00004: early stopping
# 159/159 [==============================] - 0s 123us/sample - loss: 0.2755 - accuracy: 0.9057
# 1it [19:37, 1177.78s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:03<00:03,  3.47s/it]
# 100%|██████████| 2/2 [00:05<00:00,  2.65s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 235.5078125 steps, validate for 60.708984375 steps
# Epoch 1/300
# 236/235 [==============================] - 25s 108ms/step - loss: 0.6076 - accuracy: 0.6694 - val_loss: 0.6446 - val_accuracy: 0.6756
# Epoch 2/300
# 236/235 [==============================] - 24s 103ms/step - loss: 0.5627 - accuracy: 0.7068 - val_loss: 0.6291 - val_accuracy: 0.6759
# Epoch 3/300
# 236/235 [==============================] - 24s 101ms/step - loss: 0.5421 - accuracy: 0.7226 - val_loss: 0.6673 - val_accuracy: 0.6404
# Epoch 4/300
# 236/235 [==============================] - 24s 100ms/step - loss: 0.5244 - accuracy: 0.7345 - val_loss: 0.6701 - val_accuracy: 0.6468
# Epoch 5/300
# 236/235 [==============================] - 24s 101ms/step - loss: 0.5072 - accuracy: 0.7467 - val_loss: 0.6751 - val_accuracy: 0.6617
# Epoch 00005: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 235.5078125 steps, validate for 60.708984375 steps
# Epoch 1/300
# 236/235 [==============================] - 59s 249ms/step - loss: 0.4861 - accuracy: 0.7622 - val_loss: 0.7950 - val_accuracy: 0.6491
# Epoch 2/300
# 236/235 [==============================] - 56s 239ms/step - loss: 0.4255 - accuracy: 0.8027 - val_loss: 0.8310 - val_accuracy: 0.6602
# Epoch 3/300
# 236/235 [==============================] - 57s 242ms/step - loss: 0.3777 - accuracy: 0.8322 - val_loss: 0.8456 - val_accuracy: 0.5798
# Epoch 4/300
# 236/235 [==============================] - 57s 240ms/step - loss: 0.3346 - accuracy: 0.8575 - val_loss: 0.8044 - val_accuracy: 0.6177
# Epoch 00004: early stopping
# 167/167 [==============================] - 0s 2ms/sample - loss: 0.6959 - accuracy: 0.6467
# 164/164 [==============================] - 0s 263us/sample - loss: 0.6549 - accuracy: 0.6402
# 162/162 [==============================] - 0s 726us/sample - loss: 0.6369 - accuracy: 0.6543
# 162/162 [==============================] - 0s 318us/sample - loss: 0.6659 - accuracy: 0.6420
# 162/162 [==============================] - 0s 231us/sample - loss: 0.6117 - accuracy: 0.7037
# 161/161 [==============================] - 0s 250us/sample - loss: 0.5643 - accuracy: 0.7205
# 162/162 [==============================] - 0s 232us/sample - loss: 0.5734 - accuracy: 0.7099
# 162/162 [==============================] - 0s 265us/sample - loss: 0.5849 - accuracy: 0.7222
# 157/157 [==============================] - 0s 920us/sample - loss: 0.5431 - accuracy: 0.7580
# 158/158 [==============================] - 0s 288us/sample - loss: 0.5415 - accuracy: 0.7342
# 157/157 [==============================] - 0s 234us/sample - loss: 0.5274 - accuracy: 0.7389
# 157/157 [==============================] - 0s 238us/sample - loss: 0.5208 - accuracy: 0.7006
# 157/157 [==============================] - 0s 237us/sample - loss: 0.5963 - accuracy: 0.7134
# 155/155 [==============================] - 0s 226us/sample - loss: 0.4829 - accuracy: 0.7613
# 152/152 [==============================] - 0s 236us/sample - loss: 0.5856 - accuracy: 0.6974
# 153/153 [==============================] - 0s 883us/sample - loss: 0.6108 - accuracy: 0.7059
# 150/150 [==============================] - 0s 268us/sample - loss: 0.5914 - accuracy: 0.7067
# 149/149 [==============================] - 0s 229us/sample - loss: 0.5342 - accuracy: 0.6913
# 147/147 [==============================] - 0s 899us/sample - loss: 0.5079 - accuracy: 0.7687
# 147/147 [==============================] - 0s 233us/sample - loss: 0.5313 - accuracy: 0.7483
# 146/146 [==============================] - 0s 228us/sample - loss: 0.5200 - accuracy: 0.7603
# 145/145 [==============================] - 0s 227us/sample - loss: 0.5315 - accuracy: 0.7241
# 145/145 [==============================] - 0s 231us/sample - loss: 0.5985 - accuracy: 0.7034
# 144/144 [==============================] - 0s 245us/sample - loss: 0.5414 - accuracy: 0.7431
# 141/141 [==============================] - 0s 246us/sample - loss: 0.5334 - accuracy: 0.7447
# 140/140 [==============================] - 0s 249us/sample - loss: 0.5591 - accuracy: 0.6786
# 140/140 [==============================] - 0s 261us/sample - loss: 0.6557 - accuracy: 0.6500
# 140/140 [==============================] - 0s 290us/sample - loss: 0.6614 - accuracy: 0.6929
# 140/140 [==============================] - 0s 279us/sample - loss: 0.6657 - accuracy: 0.6571
# 140/140 [==============================] - 0s 280us/sample - loss: 0.6656 - accuracy: 0.6429
# 141/141 [==============================] - 0s 246us/sample - loss: 0.5948 - accuracy: 0.6738
# 139/139 [==============================] - 0s 249us/sample - loss: 0.6463 - accuracy: 0.6978
# 138/138 [==============================] - 0s 306us/sample - loss: 0.5989 - accuracy: 0.7536
# Saved_feature_train
# Saved_feature_test
# Saved_feature_validation
# Train on 3204 samples, validate on 822 samples
# Epoch 1/300
# 3204/3204 [==============================] - 3s 842us/sample - loss: 0.5763 - accuracy: 0.7076 - val_loss: 0.6512 - val_accuracy: 0.6509
# Epoch 2/300
# 3204/3204 [==============================] - 1s 206us/sample - loss: 0.4461 - accuracy: 0.8105 - val_loss: 0.6583 - val_accuracy: 0.6448
# Epoch 3/300
# 3204/3204 [==============================] - 1s 213us/sample - loss: 0.3520 - accuracy: 0.8733 - val_loss: 0.7082 - val_accuracy: 0.6423
# Epoch 4/300
# 3204/3204 [==============================] - 1s 236us/sample - loss: 0.2678 - accuracy: 0.9164 - val_loss: 0.7883 - val_accuracy: 0.6350
# Epoch 00004: early stopping
# 134/134 [==============================] - 0s 166us/sample - loss: 0.5322 - accuracy: 0.7015
# 2it [38:19, 1160.87s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:03<00:03,  3.69s/it]
# 100%|██████████| 2/2 [00:05<00:00,  2.65s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 237.8984375 steps, validate for 62.39453125 steps
# Epoch 1/300
# 238/237 [==============================] - 26s 110ms/step - loss: 0.6119 - accuracy: 0.6671 - val_loss: 0.6331 - val_accuracy: 0.6849
# Epoch 2/300
# 238/237 [==============================] - 24s 101ms/step - loss: 0.5613 - accuracy: 0.7091 - val_loss: 0.6303 - val_accuracy: 0.6771
# Epoch 3/300
# 238/237 [==============================] - 24s 100ms/step - loss: 0.5398 - accuracy: 0.7239 - val_loss: 0.6329 - val_accuracy: 0.6837
# Epoch 4/300
# 238/237 [==============================] - 24s 102ms/step - loss: 0.5198 - accuracy: 0.7386 - val_loss: 0.6525 - val_accuracy: 0.6615
# Epoch 5/300
# 238/237 [==============================] - 24s 102ms/step - loss: 0.5020 - accuracy: 0.7515 - val_loss: 0.6779 - val_accuracy: 0.6352
# Epoch 00005: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 237.8984375 steps, validate for 62.39453125 steps
# Epoch 1/300
# 238/237 [==============================] - 60s 250ms/step - loss: 0.4798 - accuracy: 0.7662 - val_loss: 0.8068 - val_accuracy: 0.5887
# Epoch 2/300
# 238/237 [==============================] - 57s 240ms/step - loss: 0.4202 - accuracy: 0.8045 - val_loss: 0.8968 - val_accuracy: 0.5224
# Epoch 3/300
# 238/237 [==============================] - 57s 240ms/step - loss: 0.3739 - accuracy: 0.8334 - val_loss: 0.8908 - val_accuracy: 0.5514
# Epoch 4/300
# 238/237 [==============================] - 58s 244ms/step - loss: 0.3319 - accuracy: 0.8594 - val_loss: 0.9554 - val_accuracy: 0.5356
# Epoch 00004: early stopping
# 106/106 [==============================] - 0s 2ms/sample - loss: 1.0004 - accuracy: 0.5849
# 107/107 [==============================] - 0s 238us/sample - loss: 1.0056 - accuracy: 0.5140
# 106/106 [==============================] - 0s 283us/sample - loss: 0.9820 - accuracy: 0.5566
# 104/104 [==============================] - 0s 244us/sample - loss: 1.0682 - accuracy: 0.5577
# 103/103 [==============================] - 0s 257us/sample - loss: 0.9996 - accuracy: 0.5437
# 102/102 [==============================] - 0s 249us/sample - loss: 1.0399 - accuracy: 0.5490
# 100/100 [==============================] - 0s 231us/sample - loss: 0.9801 - accuracy: 0.4800
# 99/99 [==============================] - 0s 854us/sample - loss: 0.9421 - accuracy: 0.5354
# 97/97 [==============================] - 0s 308us/sample - loss: 0.9590 - accuracy: 0.6082
# 98/98 [==============================] - 0s 320us/sample - loss: 0.9846 - accuracy: 0.5816
# 98/98 [==============================] - 0s 257us/sample - loss: 0.9880 - accuracy: 0.5816
# 92/92 [==============================] - 0s 1ms/sample - loss: 1.0886 - accuracy: 0.5543
# 95/95 [==============================] - 0s 1ms/sample - loss: 1.0408 - accuracy: 0.5158
# 94/94 [==============================] - 0s 226us/sample - loss: 0.9905 - accuracy: 0.5532
# 90/90 [==============================] - 0s 1ms/sample - loss: 0.9800 - accuracy: 0.5667
# 91/91 [==============================] - 0s 231us/sample - loss: 1.0564 - accuracy: 0.5275
# 87/87 [==============================] - 0s 255us/sample - loss: 1.0743 - accuracy: 0.5977
# 87/87 [==============================] - 0s 229us/sample - loss: 1.2179 - accuracy: 0.5172
# 87/87 [==============================] - 0s 240us/sample - loss: 1.2100 - accuracy: 0.5402
# 77/77 [==============================] - 0s 345us/sample - loss: 1.0342 - accuracy: 0.5325
# 77/77 [==============================] - 0s 397us/sample - loss: 1.5311 - accuracy: 0.4416
# 75/75 [==============================] - 0s 278us/sample - loss: 1.5431 - accuracy: 0.4267
# 75/75 [==============================] - 0s 280us/sample - loss: 1.3692 - accuracy: 0.4533
# 75/75 [==============================] - 0s 260us/sample - loss: 1.5473 - accuracy: 0.4667
# 75/75 [==============================] - 0s 241us/sample - loss: 1.3173 - accuracy: 0.4533
# 75/75 [==============================] - 0s 258us/sample - loss: 1.4613 - accuracy: 0.4533
# 75/75 [==============================] - 0s 266us/sample - loss: 1.6081 - accuracy: 0.4000
# 75/75 [==============================] - 0s 245us/sample - loss: 1.6413 - accuracy: 0.4133
# 74/74 [==============================] - 0s 254us/sample - loss: 1.2899 - accuracy: 0.4865
# 75/75 [==============================] - 0s 249us/sample - loss: 1.3213 - accuracy: 0.3867
# 74/74 [==============================] - 0s 232us/sample - loss: 1.4471 - accuracy: 0.4459
# 74/74 [==============================] - 0s 358us/sample - loss: 1.4057 - accuracy: 0.4595
# 74/74 [==============================] - 0s 292us/sample - loss: 1.5385 - accuracy: 0.4189
# Saved_feature_train
# Saved_feature_test
# Saved_feature_validation
# Train on 3246 samples, validate on 847 samples
# Epoch 1/300
# 3246/3246 [==============================] - 2s 740us/sample - loss: 0.5798 - accuracy: 0.7015 - val_loss: 0.6334 - val_accuracy: 0.6564
# Epoch 2/300
# 3246/3246 [==============================] - 1s 225us/sample - loss: 0.4743 - accuracy: 0.7745 - val_loss: 0.6437 - val_accuracy: 0.6482
# Epoch 3/300
# 3246/3246 [==============================] - 1s 211us/sample - loss: 0.3891 - accuracy: 0.8441 - val_loss: 0.6783 - val_accuracy: 0.6588
# Epoch 4/300
# 3246/3246 [==============================] - 1s 220us/sample - loss: 0.3030 - accuracy: 0.8934 - val_loss: 0.7436 - val_accuracy: 0.6588
# Epoch 00004: early stopping
# 67/67 [==============================] - 0s 167us/sample - loss: 0.5742 - accuracy: 0.6418
# 3it [57:06, 1150.78s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:03<00:03,  3.29s/it]
# 100%|██████████| 2/2 [00:04<00:00,  2.50s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 233.125 steps, validate for 60.96484375 steps
# Epoch 1/300
# 234/233 [==============================] - 25s 107ms/step - loss: 0.6218 - accuracy: 0.6575 - val_loss: 0.6277 - val_accuracy: 0.6783
# Epoch 2/300
# 234/233 [==============================] - 24s 101ms/step - loss: 0.5671 - accuracy: 0.7041 - val_loss: 0.6367 - val_accuracy: 0.6643
# Epoch 3/300
# 234/233 [==============================] - 24s 101ms/step - loss: 0.5451 - accuracy: 0.7175 - val_loss: 0.6464 - val_accuracy: 0.6565
# Epoch 4/300
# 234/233 [==============================] - 24s 101ms/step - loss: 0.5264 - accuracy: 0.7321 - val_loss: 0.6559 - val_accuracy: 0.6459
# Epoch 00004: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 233.125 steps, validate for 60.96484375 steps
# Epoch 1/300
# 234/233 [==============================] - 58s 247ms/step - loss: 0.4998 - accuracy: 0.7503 - val_loss: 1.1571 - val_accuracy: 0.4019
# Epoch 2/300
# 234/233 [==============================] - 56s 241ms/step - loss: 0.4393 - accuracy: 0.7926 - val_loss: 0.8094 - val_accuracy: 0.5859
# Epoch 3/300
# 234/233 [==============================] - 56s 241ms/step - loss: 0.3886 - accuracy: 0.8266 - val_loss: 0.7761 - val_accuracy: 0.6061
# Epoch 4/300
# 234/233 [==============================] - 56s 238ms/step - loss: 0.3451 - accuracy: 0.8523 - val_loss: 0.7852 - val_accuracy: 0.6049
# Epoch 5/300
# 234/233 [==============================] - 57s 245ms/step - loss: 0.3027 - accuracy: 0.8764 - val_loss: 0.8577 - val_accuracy: 0.5750
# Epoch 6/300
# 234/233 [==============================] - 56s 241ms/step - loss: 0.2648 - accuracy: 0.8966 - val_loss: 0.8795 - val_accuracy: 0.6038
# Epoch 00006: early stopping
# 207/207 [==============================] - 0s 1ms/sample - loss: 0.6245 - accuracy: 0.7295
# 204/204 [==============================] - 0s 310us/sample - loss: 0.7081 - accuracy: 0.7157
# 205/205 [==============================] - 0s 286us/sample - loss: 0.5900 - accuracy: 0.7902
# 202/202 [==============================] - 0s 202us/sample - loss: 0.5381 - accuracy: 0.7673
# 201/201 [==============================] - 0s 232us/sample - loss: 0.6314 - accuracy: 0.7164
# 200/200 [==============================] - 0s 231us/sample - loss: 0.6034 - accuracy: 0.7500
# 196/196 [==============================] - 0s 206us/sample - loss: 0.5445 - accuracy: 0.7602
# 195/195 [==============================] - 0s 243us/sample - loss: 0.6382 - accuracy: 0.7333
# 193/193 [==============================] - 0s 252us/sample - loss: 0.5801 - accuracy: 0.7461
# 189/189 [==============================] - 0s 240us/sample - loss: 0.5391 - accuracy: 0.7831
# 186/186 [==============================] - 0s 236us/sample - loss: 0.6029 - accuracy: 0.7419
# 187/187 [==============================] - 0s 224us/sample - loss: 0.5562 - accuracy: 0.7754
# 185/185 [==============================] - 0s 247us/sample - loss: 0.5858 - accuracy: 0.7838
# 184/184 [==============================] - 0s 223us/sample - loss: 0.5698 - accuracy: 0.7989
# 182/182 [==============================] - 0s 253us/sample - loss: 0.5865 - accuracy: 0.7747
# 183/183 [==============================] - 0s 262us/sample - loss: 0.6310 - accuracy: 0.7432
# 182/182 [==============================] - 0s 245us/sample - loss: 0.6011 - accuracy: 0.7143
# 181/181 [==============================] - 0s 229us/sample - loss: 0.5994 - accuracy: 0.7293
# 182/182 [==============================] - 0s 262us/sample - loss: 0.6613 - accuracy: 0.7033
# 180/180 [==============================] - 0s 805us/sample - loss: 0.6371 - accuracy: 0.6944
# 179/179 [==============================] - 0s 245us/sample - loss: 0.6203 - accuracy: 0.7207
# 176/176 [==============================] - 0s 218us/sample - loss: 0.6650 - accuracy: 0.7045
# 174/174 [==============================] - 0s 674us/sample - loss: 0.6768 - accuracy: 0.7069
# 174/174 [==============================] - 0s 230us/sample - loss: 0.7942 - accuracy: 0.6782
# 174/174 [==============================] - 0s 245us/sample - loss: 0.6669 - accuracy: 0.7011
# 172/172 [==============================] - 0s 234us/sample - loss: 0.7432 - accuracy: 0.6686
# 174/174 [==============================] - 0s 240us/sample - loss: 0.6329 - accuracy: 0.7471
# 172/172 [==============================] - 0s 232us/sample - loss: 0.5952 - accuracy: 0.7209
# 171/171 [==============================] - 0s 218us/sample - loss: 0.6495 - accuracy: 0.7310
# 171/171 [==============================] - 0s 226us/sample - loss: 0.6563 - accuracy: 0.7135
# 170/170 [==============================] - 0s 232us/sample - loss: 0.6465 - accuracy: 0.6941
# 169/169 [==============================] - 0s 242us/sample - loss: 0.7026 - accuracy: 0.7219
# 169/169 [==============================] - 0s 235us/sample - loss: 0.7400 - accuracy: 0.6272
# Saved_feature_train
# Saved_feature_test
# Saved_feature_validation
# Train on 3173 samples, validate on 825 samples
# Epoch 1/300
# 3173/3173 [==============================] - 2s 735us/sample - loss: 0.5368 - accuracy: 0.7422 - val_loss: 0.6318 - val_accuracy: 0.6485
# Epoch 2/300
# 3173/3173 [==============================] - 1s 231us/sample - loss: 0.3489 - accuracy: 0.8708 - val_loss: 0.6775 - val_accuracy: 0.6388
# Epoch 3/300
# 3173/3173 [==============================] - 1s 209us/sample - loss: 0.2239 - accuracy: 0.9348 - val_loss: 0.7830 - val_accuracy: 0.6461
# Epoch 4/300
# 3173/3173 [==============================] - 1s 226us/sample - loss: 0.1408 - accuracy: 0.9644 - val_loss: 0.8944 - val_accuracy: 0.6388
# Epoch 00004: early stopping
# 162/162 [==============================] - 0s 156us/sample - loss: 0.5175 - accuracy: 0.7840
# 4it [1:17:12, 1167.33s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:03<00:03,  3.40s/it]
# 100%|██████████| 2/2 [00:05<00:00,  2.58s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 237.6953125 steps, validate for 60.4609375 steps
# Epoch 1/300
# 238/237 [==============================] - 26s 108ms/step - loss: 0.5985 - accuracy: 0.6797 - val_loss: 0.6331 - val_accuracy: 0.6696
# Epoch 2/300
# 238/237 [==============================] - 24s 101ms/step - loss: 0.5601 - accuracy: 0.7079 - val_loss: 0.6423 - val_accuracy: 0.6657
# Epoch 3/300
# 238/237 [==============================] - 24s 100ms/step - loss: 0.5370 - accuracy: 0.7254 - val_loss: 0.6693 - val_accuracy: 0.6524
# Epoch 4/300
# 238/237 [==============================] - 24s 100ms/step - loss: 0.5169 - accuracy: 0.7396 - val_loss: 0.6793 - val_accuracy: 0.6443
# Epoch 00004: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 237.6953125 steps, validate for 60.4609375 steps
# Epoch 1/300
# 238/237 [==============================] - 59s 249ms/step - loss: 0.4930 - accuracy: 0.7569 - val_loss: 0.7313 - val_accuracy: 0.6240
# Epoch 2/300
# 238/237 [==============================] - 58s 245ms/step - loss: 0.4315 - accuracy: 0.7992 - val_loss: 0.7738 - val_accuracy: 0.6485
# Epoch 3/300
# 238/237 [==============================] - 57s 240ms/step - loss: 0.3828 - accuracy: 0.8296 - val_loss: 0.9097 - val_accuracy: 0.5224
# Epoch 4/300
# 238/237 [==============================] - 57s 240ms/step - loss: 0.3381 - accuracy: 0.8560 - val_loss: 0.8208 - val_accuracy: 0.6008
# Epoch 00004: early stopping
# 139/139 [==============================] - 0s 2ms/sample - loss: 0.4250 - accuracy: 0.8129
# 135/135 [==============================] - 0s 266us/sample - loss: 0.4088 - accuracy: 0.8370
# 131/131 [==============================] - 0s 258us/sample - loss: 0.4551 - accuracy: 0.8168
# 130/130 [==============================] - 0s 234us/sample - loss: 0.4456 - accuracy: 0.7846
# 129/129 [==============================] - 0s 246us/sample - loss: 0.4419 - accuracy: 0.8527
# 130/130 [==============================] - 0s 248us/sample - loss: 0.4505 - accuracy: 0.8231
# 128/128 [==============================] - 0s 2ms/sample - loss: 0.4917 - accuracy: 0.7812
# 128/128 [==============================] - 0s 217us/sample - loss: 0.4319 - accuracy: 0.8516
# 126/126 [==============================] - 0s 237us/sample - loss: 0.3978 - accuracy: 0.8254
# 128/128 [==============================] - 0s 219us/sample - loss: 0.4240 - accuracy: 0.8047
# 127/127 [==============================] - 0s 265us/sample - loss: 0.4348 - accuracy: 0.8031
# 126/126 [==============================] - 0s 236us/sample - loss: 0.4596 - accuracy: 0.7778
# 125/125 [==============================] - 0s 232us/sample - loss: 0.4336 - accuracy: 0.8080
# 126/126 [==============================] - 0s 264us/sample - loss: 0.4341 - accuracy: 0.7619
# 124/124 [==============================] - 0s 256us/sample - loss: 0.4875 - accuracy: 0.7742
# 123/123 [==============================] - 0s 246us/sample - loss: 0.4507 - accuracy: 0.8130
# 121/121 [==============================] - 0s 285us/sample - loss: 0.4633 - accuracy: 0.7769
# 119/119 [==============================] - 0s 252us/sample - loss: 0.4636 - accuracy: 0.7983
# 121/121 [==============================] - 0s 426us/sample - loss: 0.4873 - accuracy: 0.8099
# 118/118 [==============================] - 0s 253us/sample - loss: 0.4879 - accuracy: 0.7712
# 117/117 [==============================] - 0s 303us/sample - loss: 0.5069 - accuracy: 0.8034
# 117/117 [==============================] - 0s 245us/sample - loss: 0.5232 - accuracy: 0.7265
# 114/114 [==============================] - 0s 276us/sample - loss: 0.4898 - accuracy: 0.7544
# 113/113 [==============================] - 0s 243us/sample - loss: 0.4731 - accuracy: 0.7699
# 113/113 [==============================] - 0s 396us/sample - loss: 0.5053 - accuracy: 0.7611
# 112/112 [==============================] - 0s 278us/sample - loss: 0.5131 - accuracy: 0.7589
# 112/112 [==============================] - 0s 389us/sample - loss: 0.5413 - accuracy: 0.7500
# 110/110 [==============================] - 0s 256us/sample - loss: 0.5193 - accuracy: 0.7364
# 110/110 [==============================] - 0s 283us/sample - loss: 0.4917 - accuracy: 0.8000
# 109/109 [==============================] - 0s 279us/sample - loss: 0.5499 - accuracy: 0.7339
# 110/110 [==============================] - 0s 288us/sample - loss: 0.5046 - accuracy: 0.7727
# 109/109 [==============================] - 0s 298us/sample - loss: 0.6288 - accuracy: 0.6881
# 107/107 [==============================] - 0s 261us/sample - loss: 0.5830 - accuracy: 0.7383
# Saved_feature_train
# Saved_feature_test
# Saved_feature_validation
# Train on 3239 samples, validate on 818 samples
# Epoch 1/300
# 3239/3239 [==============================] - 3s 775us/sample - loss: 0.5566 - accuracy: 0.7243 - val_loss: 0.6511 - val_accuracy: 0.6467
# Epoch 2/300
# 3239/3239 [==============================] - 1s 239us/sample - loss: 0.4250 - accuracy: 0.8178 - val_loss: 0.6699 - val_accuracy: 0.6418
# Epoch 3/300
# 3239/3239 [==============================] - 1s 246us/sample - loss: 0.3313 - accuracy: 0.8691 - val_loss: 0.7239 - val_accuracy: 0.6320
# Epoch 4/300
# 3239/3239 [==============================] - 1s 209us/sample - loss: 0.2454 - accuracy: 0.9145 - val_loss: 0.8133 - val_accuracy: 0.6161
# Epoch 00004: early stopping
# 103/103 [==============================] - 0s 169us/sample - loss: 0.3388 - accuracy: 0.8641
# 5it [1:35:33, 1147.59s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:03<00:03,  3.98s/it]
# 100%|██████████| 2/2 [00:05<00:00,  2.76s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 237.470703125 steps, validate for 62.638671875 steps
# Epoch 1/300
# 238/237 [==============================] - 26s 109ms/step - loss: 0.5980 - accuracy: 0.6821 - val_loss: 0.6154 - val_accuracy: 0.6904
# Epoch 2/300
# 238/237 [==============================] - 24s 101ms/step - loss: 0.5607 - accuracy: 0.7081 - val_loss: 0.6356 - val_accuracy: 0.6698
# Epoch 3/300
# 238/237 [==============================] - 24s 100ms/step - loss: 0.5381 - accuracy: 0.7238 - val_loss: 0.6465 - val_accuracy: 0.6711
# Epoch 4/300
# 238/237 [==============================] - 24s 101ms/step - loss: 0.5179 - accuracy: 0.7382 - val_loss: 0.6658 - val_accuracy: 0.6565
# Epoch 00004: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 237.470703125 steps, validate for 62.638671875 steps
# Epoch 1/300
# 238/237 [==============================] - 61s 254ms/step - loss: 0.4949 - accuracy: 0.7551 - val_loss: 0.7309 - val_accuracy: 0.6430
# Epoch 2/300
# 238/237 [==============================] - 57s 242ms/step - loss: 0.4375 - accuracy: 0.7942 - val_loss: 0.7414 - val_accuracy: 0.6240
# Epoch 3/300
# 238/237 [==============================] - 57s 238ms/step - loss: 0.3892 - accuracy: 0.8258 - val_loss: 0.7796 - val_accuracy: 0.5937
# Epoch 4/300
# 238/237 [==============================] - 57s 238ms/step - loss: 0.3442 - accuracy: 0.8532 - val_loss: 0.7995 - val_accuracy: 0.6658
# Epoch 00004: early stopping
# 112/112 [==============================] - 0s 2ms/sample - loss: 0.5893 - accuracy: 0.8304
# 103/103 [==============================] - 0s 247us/sample - loss: 0.4505 - accuracy: 0.8252
# 98/98 [==============================] - 0s 487us/sample - loss: 0.5087 - accuracy: 0.8571
# 97/97 [==============================] - 0s 295us/sample - loss: 0.4092 - accuracy: 0.8557
# 96/96 [==============================] - 0s 2ms/sample - loss: 0.4146 - accuracy: 0.8021
# 96/96 [==============================] - 0s 222us/sample - loss: 0.4329 - accuracy: 0.8333
# 96/96 [==============================] - 0s 215us/sample - loss: 0.3377 - accuracy: 0.9167
# 92/92 [==============================] - 0s 251us/sample - loss: 0.3150 - accuracy: 0.8913
# 91/91 [==============================] - 0s 314us/sample - loss: 0.3259 - accuracy: 0.9121
# 92/92 [==============================] - 0s 250us/sample - loss: 0.3640 - accuracy: 0.8478
# 91/91 [==============================] - 0s 224us/sample - loss: 0.3355 - accuracy: 0.8791
# 90/90 [==============================] - 0s 242us/sample - loss: 0.3114 - accuracy: 0.8889
# 90/90 [==============================] - 0s 252us/sample - loss: 0.3033 - accuracy: 0.8667
# 89/89 [==============================] - 0s 264us/sample - loss: 0.3214 - accuracy: 0.8764
# 89/89 [==============================] - 0s 268us/sample - loss: 0.3532 - accuracy: 0.8876
# 88/88 [==============================] - 0s 256us/sample - loss: 0.3459 - accuracy: 0.8636
# 88/88 [==============================] - 0s 242us/sample - loss: 0.3911 - accuracy: 0.8182
# 88/88 [==============================] - 0s 269us/sample - loss: 0.3422 - accuracy: 0.8523
# 89/89 [==============================] - 0s 252us/sample - loss: 0.3303 - accuracy: 0.8652
# 87/87 [==============================] - 0s 255us/sample - loss: 0.3625 - accuracy: 0.8736
# 88/88 [==============================] - 0s 254us/sample - loss: 0.3787 - accuracy: 0.8523
# 88/88 [==============================] - 0s 242us/sample - loss: 0.2990 - accuracy: 0.9091
# 86/86 [==============================] - 0s 261us/sample - loss: 0.3237 - accuracy: 0.8605
# 86/86 [==============================] - 0s 241us/sample - loss: 0.4088 - accuracy: 0.8256
# 87/87 [==============================] - 0s 263us/sample - loss: 0.3773 - accuracy: 0.8276
# 87/87 [==============================] - 0s 287us/sample - loss: 0.3771 - accuracy: 0.8506
# 86/86 [==============================] - 0s 268us/sample - loss: 0.3779 - accuracy: 0.8488
# 87/87 [==============================] - 0s 261us/sample - loss: 0.3608 - accuracy: 0.8391
# 85/85 [==============================] - 0s 274us/sample - loss: 0.3846 - accuracy: 0.8353
# 87/87 [==============================] - 0s 301us/sample - loss: 0.3862 - accuracy: 0.8161
# 86/86 [==============================] - 0s 276us/sample - loss: 0.3462 - accuracy: 0.8605
# 86/86 [==============================] - 0s 261us/sample - loss: 0.4527 - accuracy: 0.7791
# 86/86 [==============================] - 0s 285us/sample - loss: 0.3752 - accuracy: 0.8256
# Saved_feature_train
# Saved_feature_test
# Saved_feature_validation
# Train on 3230 samples, validate on 848 samples
# Epoch 1/300
# 3230/3230 [==============================] - 3s 796us/sample - loss: 0.6023 - accuracy: 0.6653 - val_loss: 0.6198 - val_accuracy: 0.6557
# Epoch 2/300
# 3230/3230 [==============================] - 1s 192us/sample - loss: 0.4789 - accuracy: 0.7805 - val_loss: 0.6231 - val_accuracy: 0.6592
# Epoch 3/300
# 3230/3230 [==============================] - 1s 206us/sample - loss: 0.3869 - accuracy: 0.8359 - val_loss: 0.6616 - val_accuracy: 0.6533
# Epoch 4/300
# 3230/3230 [==============================] - 1s 205us/sample - loss: 0.2941 - accuracy: 0.8870 - val_loss: 0.7401 - val_accuracy: 0.6285
# Epoch 00004: early stopping
# 82/82 [==============================] - 0s 188us/sample - loss: 0.6572 - accuracy: 0.6585
# 6it [1:53:58, 1134.65s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:03<00:03,  3.47s/it]
# 100%|██████████| 2/2 [00:04<00:00,  2.50s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 235.216796875 steps, validate for 61.306640625 steps
# Epoch 1/300
# 236/235 [==============================] - 25s 105ms/step - loss: 0.5977 - accuracy: 0.6822 - val_loss: 0.6241 - val_accuracy: 0.6804
# Epoch 2/300
# 236/235 [==============================] - 24s 100ms/step - loss: 0.5590 - accuracy: 0.7107 - val_loss: 0.6272 - val_accuracy: 0.6795
# Epoch 3/300
# 236/235 [==============================] - 24s 104ms/step - loss: 0.5351 - accuracy: 0.7266 - val_loss: 0.6453 - val_accuracy: 0.6682
# Epoch 4/300
# 236/235 [==============================] - 24s 101ms/step - loss: 0.5156 - accuracy: 0.7405 - val_loss: 0.6778 - val_accuracy: 0.6380
# Epoch 00004: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 235.216796875 steps, validate for 61.306640625 steps
# Epoch 1/300
# 236/235 [==============================] - 58s 246ms/step - loss: 0.4909 - accuracy: 0.7597 - val_loss: 0.7362 - val_accuracy: 0.6293
# Epoch 2/300
# 236/235 [==============================] - 57s 242ms/step - loss: 0.4287 - accuracy: 0.8022 - val_loss: 0.8055 - val_accuracy: 0.5792
# Epoch 3/300
# 236/235 [==============================] - 57s 243ms/step - loss: 0.3801 - accuracy: 0.8320 - val_loss: 0.7660 - val_accuracy: 0.6686
# Epoch 4/300
# 236/235 [==============================] - 57s 242ms/step - loss: 0.3365 - accuracy: 0.8561 - val_loss: 0.8055 - val_accuracy: 0.5802
# Epoch 00004: early stopping
# 162/162 [==============================] - 0s 2ms/sample - loss: 1.0862 - accuracy: 0.4383
# 160/160 [==============================] - 0s 1ms/sample - loss: 1.1945 - accuracy: 0.4062
# 158/158 [==============================] - 0s 227us/sample - loss: 1.2551 - accuracy: 0.3544
# 155/155 [==============================] - 0s 206us/sample - loss: 1.2524 - accuracy: 0.3613
# 153/153 [==============================] - 0s 214us/sample - loss: 1.3413 - accuracy: 0.2876
# 153/153 [==============================] - 0s 226us/sample - loss: 1.2955 - accuracy: 0.3072
# 150/150 [==============================] - 0s 244us/sample - loss: 1.2551 - accuracy: 0.4000
# 150/150 [==============================] - 0s 210us/sample - loss: 1.3883 - accuracy: 0.3267
# 152/152 [==============================] - 0s 219us/sample - loss: 1.4631 - accuracy: 0.2895
# 150/150 [==============================] - 0s 248us/sample - loss: 1.4873 - accuracy: 0.2733
# 150/150 [==============================] - 0s 248us/sample - loss: 1.5788 - accuracy: 0.2667
# 147/147 [==============================] - 0s 219us/sample - loss: 1.4220 - accuracy: 0.2857
# 148/148 [==============================] - 0s 256us/sample - loss: 1.4212 - accuracy: 0.2500
# 146/146 [==============================] - 0s 259us/sample - loss: 1.4606 - accuracy: 0.3219
# 145/145 [==============================] - 0s 254us/sample - loss: 1.4289 - accuracy: 0.3310
# 146/146 [==============================] - 0s 260us/sample - loss: 1.4715 - accuracy: 0.3082
# 145/145 [==============================] - 0s 254us/sample - loss: 1.4593 - accuracy: 0.3103
# 143/143 [==============================] - 0s 246us/sample - loss: 1.5690 - accuracy: 0.2727
# 141/141 [==============================] - 0s 255us/sample - loss: 1.5453 - accuracy: 0.2624
# 141/141 [==============================] - 0s 258us/sample - loss: 1.5899 - accuracy: 0.3050
# 142/142 [==============================] - 0s 265us/sample - loss: 1.6355 - accuracy: 0.2958
# 142/142 [==============================] - 0s 251us/sample - loss: 1.7513 - accuracy: 0.2746
# 143/143 [==============================] - 0s 245us/sample - loss: 1.5834 - accuracy: 0.3007
# 140/140 [==============================] - 0s 251us/sample - loss: 1.5600 - accuracy: 0.3500
# 143/143 [==============================] - 0s 246us/sample - loss: 1.5962 - accuracy: 0.3007
# 142/142 [==============================] - 0s 393us/sample - loss: 1.6338 - accuracy: 0.3028
# 141/141 [==============================] - 0s 256us/sample - loss: 1.6119 - accuracy: 0.2908
# 140/140 [==============================] - 0s 249us/sample - loss: 1.6413 - accuracy: 0.2929
# 140/140 [==============================] - 0s 246us/sample - loss: 1.7849 - accuracy: 0.2643
# 139/139 [==============================] - 0s 244us/sample - loss: 1.6362 - accuracy: 0.2806
# 138/138 [==============================] - 0s 264us/sample - loss: 1.7948 - accuracy: 0.2609
# 139/139 [==============================] - 0s 243us/sample - loss: 1.7283 - accuracy: 0.2878
# 139/139 [==============================] - 0s 267us/sample - loss: 1.6053 - accuracy: 0.2806
# Saved_feature_train
# Saved_feature_test
# Saved_feature_validation
# Train on 3199 samples, validate on 831 samples
# Epoch 1/300
# 3199/3199 [==============================] - 2s 761us/sample - loss: 0.6172 - accuracy: 0.6593 - val_loss: 0.6227 - val_accuracy: 0.6643
# Epoch 2/300
# 3199/3199 [==============================] - 1s 216us/sample - loss: 0.4809 - accuracy: 0.7918 - val_loss: 0.6199 - val_accuracy: 0.6594
# Epoch 3/300
# 3199/3199 [==============================] - 1s 201us/sample - loss: 0.3916 - accuracy: 0.8525 - val_loss: 0.6435 - val_accuracy: 0.6582
# Epoch 4/300
# 3199/3199 [==============================] - 1s 198us/sample - loss: 0.3062 - accuracy: 0.8897 - val_loss: 0.6941 - val_accuracy: 0.6462
# Epoch 5/300
# 3199/3199 [==============================] - 1s 222us/sample - loss: 0.2453 - accuracy: 0.9181 - val_loss: 0.7615 - val_accuracy: 0.6510
# Epoch 00005: early stopping
# 130/130 [==============================] - 0s 133us/sample - loss: 1.1967 - accuracy: 0.3692
# 7it [2:12:15, 1123.26s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:03<00:03,  3.33s/it]
# 100%|██████████| 2/2 [00:05<00:00,  2.54s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 237.7890625 steps, validate for 61.90234375 steps
# Epoch 1/300
# 238/237 [==============================] - 26s 109ms/step - loss: 0.6047 - accuracy: 0.6747 - val_loss: 0.6218 - val_accuracy: 0.6817
# Epoch 2/300
# 238/237 [==============================] - 24s 100ms/step - loss: 0.5654 - accuracy: 0.7067 - val_loss: 0.6208 - val_accuracy: 0.6823
# Epoch 3/300
# 238/237 [==============================] - 24s 102ms/step - loss: 0.5428 - accuracy: 0.7227 - val_loss: 0.6312 - val_accuracy: 0.6687
# Epoch 4/300
# 238/237 [==============================] - 24s 100ms/step - loss: 0.5225 - accuracy: 0.7365 - val_loss: 0.6450 - val_accuracy: 0.6631
# Epoch 5/300
# 238/237 [==============================] - 24s 102ms/step - loss: 0.5050 - accuracy: 0.7480 - val_loss: 0.6579 - val_accuracy: 0.6606
# Epoch 00005: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 237.7890625 steps, validate for 61.90234375 steps
# Epoch 1/300
# 238/237 [==============================] - 60s 250ms/step - loss: 0.4837 - accuracy: 0.7634 - val_loss: 0.9926 - val_accuracy: 0.4938
# Epoch 2/300
# 238/237 [==============================] - 56s 237ms/step - loss: 0.4241 - accuracy: 0.8053 - val_loss: 0.8320 - val_accuracy: 0.6557
# Epoch 3/300
# 238/237 [==============================] - 57s 239ms/step - loss: 0.3782 - accuracy: 0.8328 - val_loss: 0.9026 - val_accuracy: 0.5364
# Epoch 4/300
# 238/237 [==============================] - 57s 237ms/step - loss: 0.3366 - accuracy: 0.8570 - val_loss: 0.8341 - val_accuracy: 0.5845
# Epoch 5/300
# 238/237 [==============================] - 57s 238ms/step - loss: 0.2988 - accuracy: 0.8781 - val_loss: 0.8605 - val_accuracy: 0.6658
# Epoch 00005: early stopping
# 118/118 [==============================] - 0s 2ms/sample - loss: 0.0882 - accuracy: 0.9831
# 116/116 [==============================] - 0s 343us/sample - loss: 0.0855 - accuracy: 0.9914
# 114/114 [==============================] - 0s 242us/sample - loss: 0.1038 - accuracy: 0.9737
# 112/112 [==============================] - 0s 216us/sample - loss: 0.1057 - accuracy: 0.9821
# 110/110 [==============================] - 0s 258us/sample - loss: 0.0967 - accuracy: 1.0000
# 109/109 [==============================] - 0s 287us/sample - loss: 0.0905 - accuracy: 0.9908
# 108/108 [==============================] - 0s 261us/sample - loss: 0.1341 - accuracy: 0.9630
# 105/105 [==============================] - 0s 375us/sample - loss: 0.1368 - accuracy: 0.9619
# 102/102 [==============================] - 0s 306us/sample - loss: 0.1210 - accuracy: 0.9804
# 101/101 [==============================] - 0s 927us/sample - loss: 0.1274 - accuracy: 0.9703
# 99/99 [==============================] - 0s 281us/sample - loss: 0.1261 - accuracy: 0.9697
# 96/96 [==============================] - 0s 2ms/sample - loss: 0.1215 - accuracy: 0.9896
# 94/94 [==============================] - 0s 272us/sample - loss: 0.1489 - accuracy: 0.9681
# 94/94 [==============================] - 0s 256us/sample - loss: 0.1452 - accuracy: 0.9681
# 93/93 [==============================] - 0s 289us/sample - loss: 0.1429 - accuracy: 0.9785
# 92/92 [==============================] - 0s 273us/sample - loss: 0.1809 - accuracy: 0.9457
# 93/93 [==============================] - 0s 298us/sample - loss: 0.1803 - accuracy: 0.9247
# 93/93 [==============================] - 0s 289us/sample - loss: 0.1599 - accuracy: 0.9785
# 92/92 [==============================] - 0s 269us/sample - loss: 0.1539 - accuracy: 0.9783
# 92/92 [==============================] - 0s 257us/sample - loss: 0.1733 - accuracy: 0.9565
# 91/91 [==============================] - 0s 256us/sample - loss: 0.1542 - accuracy: 0.9780
# 92/92 [==============================] - 0s 259us/sample - loss: 0.1478 - accuracy: 0.9783
# 91/91 [==============================] - 0s 264us/sample - loss: 0.2044 - accuracy: 0.9451
# 90/90 [==============================] - 0s 265us/sample - loss: 0.2083 - accuracy: 0.9333
# 89/89 [==============================] - 0s 272us/sample - loss: 0.1871 - accuracy: 0.9663
# 88/88 [==============================] - 0s 258us/sample - loss: 0.1847 - accuracy: 0.9545
# 89/89 [==============================] - 0s 285us/sample - loss: 0.1811 - accuracy: 0.9551
# 89/89 [==============================] - 0s 296us/sample - loss: 0.1539 - accuracy: 0.9663
# 89/89 [==============================] - 0s 272us/sample - loss: 0.1835 - accuracy: 0.9438
# 90/90 [==============================] - 0s 266us/sample - loss: 0.1964 - accuracy: 0.9333
# 90/90 [==============================] - 0s 260us/sample - loss: 0.1986 - accuracy: 0.9333
# 91/91 [==============================] - 0s 287us/sample - loss: 0.1770 - accuracy: 0.9560
# 89/89 [==============================] - 0s 286us/sample - loss: 0.2040 - accuracy: 0.9438
# Saved_feature_train
# Saved_feature_test
# Saved_feature_validation
# Train on 3236 samples, validate on 837 samples
# Epoch 1/300
# 3236/3236 [==============================] - 2s 738us/sample - loss: 0.6044 - accuracy: 0.6749 - val_loss: 0.6211 - val_accuracy: 0.6774
# Epoch 2/300
# 3236/3236 [==============================] - 1s 250us/sample - loss: 0.4119 - accuracy: 0.8356 - val_loss: 0.6383 - val_accuracy: 0.6691
# Epoch 3/300
# 3236/3236 [==============================] - 1s 241us/sample - loss: 0.2872 - accuracy: 0.9017 - val_loss: 0.7102 - val_accuracy: 0.6440
# Epoch 4/300
# 3236/3236 [==============================] - 1s 212us/sample - loss: 0.1977 - accuracy: 0.9462 - val_loss: 0.8006 - val_accuracy: 0.6368
# Epoch 00004: early stopping
# 87/87 [==============================] - 0s 135us/sample - loss: 0.3713 - accuracy: 0.8276
# 8it [2:32:00, 1141.82s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:03<00:03,  3.39s/it]
# 100%|██████████| 2/2 [00:05<00:00,  2.55s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 236.873046875 steps, validate for 62.224609375 steps
# Epoch 1/300
# 237/236 [==============================] - 26s 109ms/step - loss: 0.5969 - accuracy: 0.6808 - val_loss: 0.6265 - val_accuracy: 0.6875
# Epoch 2/300
# 237/236 [==============================] - 24s 100ms/step - loss: 0.5612 - accuracy: 0.7070 - val_loss: 0.6265 - val_accuracy: 0.6829
# Epoch 3/300
# 237/236 [==============================] - 24s 100ms/step - loss: 0.5390 - accuracy: 0.7230 - val_loss: 0.6442 - val_accuracy: 0.6752
# Epoch 4/300
# 237/236 [==============================] - 24s 99ms/step - loss: 0.5188 - accuracy: 0.7397 - val_loss: 0.6625 - val_accuracy: 0.6643
# Epoch 00004: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# ...
# 70/70 [==============================] - 0s 252us/sample - loss: 1.1344 - accuracy: 0.5286
# 70/70 [==============================] - 0s 295us/sample - loss: 1.0512 - accuracy: 0.5000
# 71/71 [==============================] - 0s 294us/sample - loss: 1.0717 - accuracy: 0.5211
# 72/72 [==============================] - 0s 322us/sample - loss: 1.1764 - accuracy: 0.4861
# 73/73 [==============================] - 0s 435us/sample - loss: 1.1761 - accuracy: 0.4384
# 70/70 [==============================] - 0s 346us/sample - loss: 1.0675 - accuracy: 0.5286
# 70/70 [==============================] - 0s 278us/sample - loss: 1.2801 - accuracy: 0.4000
# 68/68 [==============================] - 0s 300us/sample - loss: 1.2840 - accuracy: 0.3824
# 66/66 [==============================] - 0s 293us/sample - loss: 1.3202 - accuracy: 0.4848
# 67/67 [==============================] - 0s 309us/sample - loss: 1.1958 - accuracy: 0.4478
# 66/66 [==============================] - 0s 346us/sample - loss: 1.0546 - accuracy: 0.5000
# 65/65 [==============================] - 0s 330us/sample - loss: 1.0971 - accuracy: 0.4923
# 64/64 [==============================] - 0s 3ms/sample - loss: 1.1215 - accuracy: 0.5000
# 64/64 [==============================] - 0s 276us/sample - loss: 1.1943 - accuracy: 0.4688
# 65/65 [==============================] - 0s 322us/sample - loss: 1.0768 - accuracy: 0.5077
# 64/64 [==============================] - 0s 263us/sample - loss: 1.1107 - accuracy: 0.5000
# 63/63 [==============================] - 0s 257us/sample - loss: 0.9188 - accuracy: 0.5873
# 64/64 [==============================] - 0s 225us/sample - loss: 0.9270 - accuracy: 0.5625
# 64/64 [==============================] - 0s 248us/sample - loss: 0.8781 - accuracy: 0.5938
# 64/64 [==============================] - 0s 253us/sample - loss: 1.0145 - accuracy: 0.4844
# Saved_feature_train
# Saved_feature_test
# Saved_feature_validation
# Train on 3253 samples, validate on 847 samples
# Epoch 1/300
# 3253/3253 [==============================] - 3s 773us/sample - loss: 0.5356 - accuracy: 0.7396 - val_loss: 0.6492 - val_accuracy: 0.6434
# Epoch 2/300
# 3253/3253 [==============================] - 1s 206us/sample - loss: 0.2925 - accuracy: 0.9158 - val_loss: 0.7710 - val_accuracy: 0.6269
# Epoch 3/300
# 3253/3253 [==============================] - 1s 199us/sample - loss: 0.1407 - accuracy: 0.9690 - val_loss: 0.9263 - val_accuracy: 0.6092
# Epoch 4/300
# 3253/3253 [==============================] - 1s 197us/sample - loss: 0.0938 - accuracy: 0.9803 - val_loss: 1.0400 - val_accuracy: 0.6021
# Epoch 00004: early stopping
# 60/60 [==============================] - 0s 151us/sample - loss: 0.6656 - accuracy: 0.6667
# 10it [3:13:56, 1200.19s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:03<00:03,  3.60s/it]
# 100%|██████████| 2/2 [00:05<00:00,  2.66s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 237.267578125 steps, validate for 62.25390625 steps
# Epoch 1/300
# 238/237 [==============================] - 25s 107ms/step - loss: 0.6118 - accuracy: 0.6665 - val_loss: 0.6301 - val_accuracy: 0.6858
# Epoch 2/300
# 238/237 [==============================] - 24s 101ms/step - loss: 0.5641 - accuracy: 0.7059 - val_loss: 0.6369 - val_accuracy: 0.6737
# Epoch 3/300
# 238/237 [==============================] - 24s 100ms/step - loss: 0.5418 - accuracy: 0.7223 - val_loss: 0.6504 - val_accuracy: 0.6610
# Epoch 4/300
# 238/237 [==============================] - 24s 101ms/step - loss: 0.5236 - accuracy: 0.7352 - val_loss: 0.6640 - val_accuracy: 0.6609
# Epoch 00004: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 237.267578125 steps, validate for 62.25390625 steps
# Epoch 1/300
# 238/237 [==============================] - 59s 247ms/step - loss: 0.4980 - accuracy: 0.7549 - val_loss: 0.7881 - val_accuracy: 0.5442
# Epoch 2/300
# 238/237 [==============================] - 57s 241ms/step - loss: 0.4380 - accuracy: 0.7961 - val_loss: 0.7965 - val_accuracy: 0.6083
# Epoch 3/300
# 238/237 [==============================] - 56s 237ms/step - loss: 0.3890 - accuracy: 0.8262 - val_loss: 0.8014 - val_accuracy: 0.5892
# Epoch 4/300
# 238/237 [==============================] - 58s 242ms/step - loss: 0.3472 - accuracy: 0.8502 - val_loss: 0.7738 - val_accuracy: 0.6164
# Epoch 5/300
# 238/237 [==============================] - 58s 244ms/step - loss: 0.3068 - accuracy: 0.8742 - val_loss: 0.8426 - val_accuracy: 0.6134
# Epoch 6/300
# 238/237 [==============================] - 57s 239ms/step - loss: 0.2675 - accuracy: 0.8943 - val_loss: 0.9045 - val_accuracy: 0.6040
# Epoch 7/300
# 238/237 [==============================] - 56s 237ms/step - loss: 0.2325 - accuracy: 0.9133 - val_loss: 0.8742 - val_accuracy: 0.6021
# Epoch 00007: early stopping
# 127/127 [==============================] - 0s 2ms/sample - loss: 0.7120 - accuracy: 0.6378
# 126/126 [==============================] - 0s 260us/sample - loss: 0.8480 - accuracy: 0.6270
# 126/126 [==============================] - 0s 244us/sample - loss: 0.6757 - accuracy: 0.7143
# 126/126 [==============================] - 0s 227us/sample - loss: 0.6405 - accuracy: 0.6825
# 118/118 [==============================] - 0s 212us/sample - loss: 0.6317 - accuracy: 0.7203
# 110/110 [==============================] - 0s 245us/sample - loss: 0.6360 - accuracy: 0.7182
# 108/108 [==============================] - 0s 309us/sample - loss: 0.7847 - accuracy: 0.6759
# 103/103 [==============================] - 0s 250us/sample - loss: 0.6235 - accuracy: 0.7767
# 100/100 [==============================] - 0s 362us/sample - loss: 0.6550 - accuracy: 0.6900
# 98/98 [==============================] - 0s 315us/sample - loss: 0.7142 - accuracy: 0.6837
# 98/98 [==============================] - 0s 270us/sample - loss: 0.6592 - accuracy: 0.7449
# 97/97 [==============================] - 0s 331us/sample - loss: 0.7183 - accuracy: 0.6907
# 97/97 [==============================] - 0s 305us/sample - loss: 0.7477 - accuracy: 0.6701
# 96/96 [==============================] - 0s 2ms/sample - loss: 0.5729 - accuracy: 0.7188
# 97/97 [==============================] - 0s 294us/sample - loss: 0.6315 - accuracy: 0.6804
# 96/96 [==============================] - 0s 226us/sample - loss: 0.6482 - accuracy: 0.7188
# 94/94 [==============================] - 0s 264us/sample - loss: 0.5651 - accuracy: 0.7872
# 94/94 [==============================] - 0s 245us/sample - loss: 0.5609 - accuracy: 0.7766
# 92/92 [==============================] - 0s 259us/sample - loss: 0.5903 - accuracy: 0.6957
# 94/94 [==============================] - 0s 227us/sample - loss: 0.6610 - accuracy: 0.7660
# 92/92 [==============================] - 0s 264us/sample - loss: 0.4552 - accuracy: 0.8152
# 90/90 [==============================] - 0s 275us/sample - loss: 0.5098 - accuracy: 0.8000
# 92/92 [==============================] - 0s 266us/sample - loss: 0.4651 - accuracy: 0.7935
# 92/92 [==============================] - 0s 246us/sample - loss: 0.5152 - accuracy: 0.7174
# 94/94 [==============================] - 0s 256us/sample - loss: 0.4458 - accuracy: 0.7979
# 93/93 [==============================] - 0s 296us/sample - loss: 0.5776 - accuracy: 0.6989
# 94/94 [==============================] - 0s 259us/sample - loss: 0.5655 - accuracy: 0.7234
# 93/93 [==============================] - 0s 304us/sample - loss: 0.5348 - accuracy: 0.7312
# 91/91 [==============================] - 0s 267us/sample - loss: 0.4351 - accuracy: 0.7802
# 92/92 [==============================] - 0s 256us/sample - loss: 0.5982 - accuracy: 0.7717
# 90/90 [==============================] - 0s 256us/sample - loss: 0.6334 - accuracy: 0.7000
# 89/89 [==============================] - 0s 276us/sample - loss: 0.5558 - accuracy: 0.7865
# 89/89 [==============================] - 0s 308us/sample - loss: 0.5785 - accuracy: 0.7753
# Saved_feature_train
# Saved_feature_test
# Saved_feature_validation
# Train on 3236 samples, validate on 849 samples
# Epoch 1/300
# 3236/3236 [==============================] - 3s 776us/sample - loss: 0.5318 - accuracy: 0.7367 - val_loss: 0.6363 - val_accuracy: 0.6620
# Epoch 2/300
# 3236/3236 [==============================] - 1s 211us/sample - loss: 0.2999 - accuracy: 0.9005 - val_loss: 0.7102 - val_accuracy: 0.6443
# Epoch 3/300
# 3236/3236 [==============================] - 1s 204us/sample - loss: 0.1604 - accuracy: 0.9651 - val_loss: 0.8460 - val_accuracy: 0.6396
# Epoch 4/300
# 3236/3236 [==============================] - 1s 221us/sample - loss: 0.0939 - accuracy: 0.9830 - val_loss: 0.9742 - val_accuracy: 0.6431
# Epoch 00004: early stopping
# 75/75 [==============================] - 0s 179us/sample - loss: 0.2821 - accuracy: 0.8933
# 11it [3:35:09, 1221.89s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:03<00:03,  3.43s/it]
# 100%|██████████| 2/2 [00:05<00:00,  2.55s/it]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 236.06640625 steps, validate for 61.451171875 steps
# Epoch 1/300
# 237/236 [==============================] - 25s 104ms/step - loss: 0.6053 - accuracy: 0.6729 - val_loss: 0.6169 - val_accuracy: 0.6806
# Epoch 2/300
# 237/236 [==============================] - 23s 98ms/step - loss: 0.5643 - accuracy: 0.7032 - val_loss: 0.6296 - val_accuracy: 0.6754
# Epoch 3/300
# 237/236 [==============================] - 23s 97ms/step - loss: 0.5415 - accuracy: 0.7206 - val_loss: 0.6365 - val_accuracy: 0.6671
# Epoch 4/300
# 237/236 [==============================] - 24s 99ms/step - loss: 0.5222 - accuracy: 0.7348 - val_loss: 0.6797 - val_accuracy: 0.6342
# Epoch 00004: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 236.06640625 steps, validate for 61.451171875 steps
# Epoch 1/300
# 237/236 [==============================] - 58s 243ms/step - loss: 0.4975 - accuracy: 0.7527 - val_loss: 0.7246 - val_accuracy: 0.6421
# Epoch 2/300
# 237/236 [==============================] - 58s 244ms/step - loss: 0.4380 - accuracy: 0.7945 - val_loss: 0.7108 - val_accuracy: 0.6437
# Epoch 3/300
# 139/236 [================>.............] - ETA: 22s - loss: 0.3971 - accuracy: 0.8219
# /home/jovyan/.local/lib/python3.6/site-packages/keras/callbacks/callbacks.py:846: RuntimeWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-3521dc2cd6ae> in <module>
#     162                         validation_steps = (len(x_val)/batch_size),
#     163                         class_weight = weights,
# --> 164                         verbose = 1)
#     165
#     166         l = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     597       # In this case we have created variables on the first call, so we run the
#     598       # defunned version which is guaranteed to never create variables.
# --> 599       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     600     elif self._stateful_fn is not None:
#     601       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    2361     with self._lock:
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#    2365   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
# ACCURACY SCORE AVERAGE FOR CNN
cv_s = cv_mean_acc(tot_results_accuracy, string_well)
cv_s

# %%
cv_s_mean,_ = zip(*cv_s)

m_cv = np.mean(list(cv_s_mean))
m_cv

# %%
# PLOT OF MEAN ACCURACY FOR EVERY TIME POINT CNN

l_drug = string_well*3

acc_plot = []

for i in tot_results_accuracy:
    acc_plot.append(i)

cv_plot = list(zip(acc_plot, l_drug))

res_plot = sorted(cv_plot, key = lambda x: x[1])

a , b = zip(*res_plot)
    
a = list(a)

s = list(np.array_split(a, len(string_well)))

cv_plot = []

for ix, i in enumerate(s):
    s1 = list(s[ix])
    
    cv_plot.append(np.average(s1, axis=0))

# %%
fig = plt.figure(figsize=(10, 5))
for i in cv_plot:
    
    plt.plot(time_points, i)
    plt.show
    plt.savefig('/home/jovyan/cv_score.png')

# %%
results_lstm = sorted(results_lstm, key=lambda x: x[1])
r_lstm , _ = zip(*results_lstm)
    
r_lstm = list(r_lstm)

re_lstm = list(np.array_split(r_lstm, len(string_well)))

cv_lstm = []

for ix, i in enumerate(re_lstm):
    r1 = list(re_lstm[ix])
    cv_lstm.append(np.mean(r1))

# %%
cv_lstm = list(zip(cv_lstm, string_well))
cv_lstm

# %%
cv_l_mean,_ = zip(*cv_lstm)

m_cv_l = np.mean(list(cv_l_mean))
m_cv_l

# %%
# BEFORE RUNNING AGAIN

folders = glob.glob('/home/jovyan/DATA_MASTER_PROJECT/LSTM/FEAT_FOLDERS/*')

for fo in folders:
    file = glob.glob(f'{fo}/*')
    for f in file:
        os.remove(f)
