# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv2D, Conv3D
from tensorflow.keras.layers import MaxPooling2D, MaxPooling3D
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras import optimizers
from tensorflow.keras import regularizers
from sklearn.metrics import f1_score
#from keras import backend as K
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image 
import seaborn as sns
import os
import re
import glob
import cv2
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
from sklearn import preprocessing
import tqdm
from numpy import loadtxt
from sklearn.utils import class_weight
# Out:
# Using TensorFlow backend.

# %%
def atoi(text):
    return int(text) if text.isdigit() else text
def natural_keys(text):
    return [atoi(c) for c in re.split('(\d+)', text)]

# %%
def draw_confusion_matrix(true,preds):
    conf_matx = confusion_matrix(true, preds)
    sns.heatmap(conf_matx, annot=True,annot_kws={"size": 12},fmt='g', cbar=False, cmap=plt.cm.Blues) #'viridis'
    #plt.savefig('/home/jovyan/img1.png')
    plt.show()
    
    return conf_matx

# %%
def plot_history(model_history, model_name):
    fig = plt.figure(figsize=(15,5), facecolor='w')
    ax = fig.add_subplot(121)
    ax.plot(model_history.history['loss'])
    ax.plot(model_history.history['val_loss'])
    ax.set(title=model_name + ': Model loss', ylabel='Loss', xlabel='Epoch')
    ax.legend(['Train', 'Val'], loc='upper left')
    ax = fig.add_subplot(122)
    ax.plot(model_history.history['accuracy'])
    ax.plot(model_history.history['val_accuracy'])
    ax.set(title=model_name + ': Model Accuracy; test='+ str(np.round(model_history.history['val_accuracy'][-1], 3)),
           ylabel='Accuracy', xlabel='Epoch')
    ax.legend(['Train', 'Val'], loc='upper left')
    #plt.savefig('/home/jovyan/img2.png')
    plt.show()
   
    
    return fig

# %%
def loadImages(path_data, path_labels):

    image_list = []
    

    for filename in sorted(glob.glob(path_data), key=natural_keys): 
        im=cv2.imread(filename)
        #gray_image = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
        imarray = np.array(im)
        imarray = imarray.astype('float32')
        image_list.append(imarray)

    x_orig = np.reshape(image_list, (len(image_list), 90, 90, 3))
    
    path = path_labels    
    labels = pd.read_csv(path, usecols=["Type", "Category"],
                       sep="," )
    y_orig = np.array(labels['Category'])

    return x_orig, y_orig

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=2, patience=3)

# %%
train_data = '/home/jovyan/DATA_MASTER_PROJECT/A549/Differente_fields_of_view/train_cr/*.tiff'
train_lab='/home/jovyan/DATA_MASTER_PROJECT/A549/Differente_fields_of_view/train_labels.csv'


test_data='/home/jovyan/DATA_MASTER_PROJECT/A549/Differente_fields_of_view/cropped_test/*.tiff'
test_lab='/home/jovyan/DATA_MASTER_PROJECT/A549/Differente_fields_of_view/labels_test.csv'

# %% [markdown]
# # Train and validation set

# %%
x_orig_1, y_orig_1 = tqdm.tqdm(loadImages(train_data, train_lab))
x_orig_1.shape, y_orig_1.shape
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 4908.49it/s]
# ((9732, 90, 90, 3), (9732,))

# %%
x_orig_1 = x_orig_1/255

# %%
x_train_1, x_val, y_train_1, y_val = train_test_split(x_orig_1, y_orig_1, test_size=0.2, random_state=999 )
x_train_1.shape, x_val.shape, y_train_1.shape, y_val.shape
# Out:
# ((7785, 90, 90, 3), (1947, 90, 90, 3), (7785,), (1947,))

# %% [markdown]
# # Test set

# %%
x_test, y_test = loadImages(test_data, test_lab)
x_test.shape, y_test.shape
# Out:
# ((3102, 90, 90, 3), (3102,))

# %%
x_test = x_test/255

# %%
#Show n rabdom images to check for quality

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i], cmap=plt.cm.binary)
    #plt.xlabel(class_names[y_orig_1[i]])
plt.show()

# %%
unique, counts = np.unique(y_train_1, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0: 2155, 1: 3254, 2: 2376}

# %%
unique, counts = np.unique(y_val, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0: 537, 1: 825, 2: 585}

# %%
weights = class_weight.compute_class_weight('balanced', np.unique(y_train_1),y_train_1)
print('weights = ' + str(weights))
# Out:
# weights = [1.20417633 0.79748002 1.09217172]

# %%
y_train_1 = keras.utils.to_categorical(y_train_1)
y_test_1 = keras.utils.to_categorical(y_test)
y_val = keras.utils.to_categorical(y_val)

y_train_1.shape, y_test_1.shape, y_val.shape
# Out:
# ((7785, 3), (3102, 3), (1947, 3))

# %%
batch_size = 32

# %%
datagen = ImageDataGenerator()

datagen.fit(x_train_1)

train_gen = datagen.flow(x_train_1, y_train_1, batch_size=batch_size)

# %%
dat_val = ImageDataGenerator()

dat_val.fit(x_val)

val_gen = dat_val.flow(x_val, y_val, batch_size=batch_size)

# %%
input_shape = (90,90,3)

# %%
m = Sequential()
m.add(Conv2D(filters=8, kernel_size=3, strides=1, padding='same', activation='relu', input_shape = input_shape))
m.add(MaxPooling2D())

m.add(Conv2D(filters=16, kernel_size=3, strides=1, padding='same', activation='relu'))
m.add(MaxPooling2D())

m.add(Conv2D(filters=32, kernel_size=3, strides=1, padding='same', activation='relu'))
m.add(MaxPooling2D())

m.add(Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu'))
m.add(MaxPooling2D())

m.add(Flatten())

m.add(Dense(128, activation='relu'))


m.add(Dense(3,activation='softmax'))
m.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 90, 90, 8)         224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 45, 45, 8)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 45, 45, 16)        1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 22, 22, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 22, 22, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 11, 11, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               204928
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 229,843
# Trainable params: 229,843
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = keras.optimizers.Adam(lr=1e-3)

m.compile(loss= keras.losses.categorical_crossentropy, optimizer=opt, metrics = ['accuracy'])

# %%
epochs = 100

m_h = m.fit(train_gen,
                steps_per_epoch=(len(x_train_1)/batch_size),
                callbacks = [es],
                epochs=epochs,
                validation_data = val_gen, 
                validation_steps = (len(x_val)/batch_size),
                class_weight = weights)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 243.28125 steps, validate for 60.84375 steps
# Epoch 1/100
# 244/243 [==============================] - 5s 19ms/step - loss: 1.0724 - accuracy: 0.4139 - val_loss: 1.0584 - val_accuracy: 0.4227
# Epoch 2/100
# 244/243 [==============================] - 2s 8ms/step - loss: 1.0473 - accuracy: 0.4308 - val_loss: 1.1040 - val_accuracy: 0.4278
# Epoch 3/100
# 244/243 [==============================] - 2s 8ms/step - loss: 1.0313 - accuracy: 0.4441 - val_loss: 1.0126 - val_accuracy: 0.4545
# Epoch 4/100
# 244/243 [==============================] - 2s 9ms/step - loss: 1.0048 - accuracy: 0.4742 - val_loss: 0.9994 - val_accuracy: 0.4710
# Epoch 5/100
# 244/243 [==============================] - 2s 8ms/step - loss: 0.9722 - accuracy: 0.5017 - val_loss: 0.9881 - val_accuracy: 0.4951
# Epoch 6/100
# 244/243 [==============================] - 2s 8ms/step - loss: 0.9155 - accuracy: 0.5423 - val_loss: 0.9603 - val_accuracy: 0.5234
# Epoch 7/100
# 244/243 [==============================] - 2s 7ms/step - loss: 0.8601 - accuracy: 0.5909 - val_loss: 0.9435 - val_accuracy: 0.5413
# Epoch 8/100
# 244/243 [==============================] - 2s 8ms/step - loss: 0.7882 - accuracy: 0.6283 - val_loss: 0.9396 - val_accuracy: 0.5639
# Epoch 9/100
# 244/243 [==============================] - 2s 8ms/step - loss: 0.7087 - accuracy: 0.6763 - val_loss: 0.9000 - val_accuracy: 0.6107
# Epoch 10/100
# 244/243 [==============================] - 2s 7ms/step - loss: 0.6381 - accuracy: 0.7156 - val_loss: 0.9306 - val_accuracy: 0.6184
# Epoch 11/100
# 244/243 [==============================] - 2s 8ms/step - loss: 0.5550 - accuracy: 0.7603 - val_loss: 0.9213 - val_accuracy: 0.6420
# Epoch 12/100
# 244/243 [==============================] - 2s 7ms/step - loss: 0.4874 - accuracy: 0.7941 - val_loss: 0.9976 - val_accuracy: 0.6292
# Epoch 00012: early stopping

# %%
plot_history(m_h, 'first')

# %%
scores = m.evaluate(x_test, y_test_1)
print("\n%s: %.2f%%" % (m.metrics_names[1], scores[1]*100))
# Out:
# 3102/3102 [==============================] - 1s 162us/sample - loss: 2.8932 - accuracy: 0.3569
#
# accuracy: 35.69%

# %%
test_preds = m4.predict(x_test)

# %%
preds_df = pd.DataFrame(test_preds)
predicted_labels = preds_df.idxmax(axis=1)

# %%
draw_confusion_matrix(y_test, predicted_labels)

# %%
print(classification_report(y_test, predicted_labels))

# %%
# p = '/home/jovyan/Saved_Models/'
# m4.save(p + "CNN_A59_modell.h5")
